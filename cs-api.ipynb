# %% [markdown]
# #### 1. Test Skills Matcher API GET request using the default request JSON from API Explorer
# #### 2. Submit custom survey answers
#
# ---

# %%
import pandas as pd
import requests 
from bs4 import BeautifulSoup
import yaml
import os
import json
# Out:
# /Users/alexsocarras/tech_impact/career-onestop/venv/lib/python3.9/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# #### 1. Test Skills Matcher API GET request using the default request JSON from API Explorer
#
# The API explorer provides an example request to the skillsmatcher endpoint which we use now to test our first GET request through Python.
# You can also submit requests to this endpoint via the API explorer -- the response you'll get there matches this one.

# %%
with open("api-key.yaml", "r") as file:
  api_key = yaml.full_load(file)

url = f"https://api.careeronestop.org/v1/skillsmatcher/{api_key['cs']['user-id']}"

with open(os.path.join("data","skills-submit-api", "example-request.json"), "r") as file:
  request_body = json.load(file)

headers = {
  "Authorization": f"Bearer {api_key['cs']['token-key']}"
}

# %%
response = requests.post(url, json=request_body, headers=headers)
response = response.json() # This matches the response we generated using the API Explorer

response
# Out:
# {'SKARankList': [{'OnetCode': '29-1229.04',
#    'Score': 0.579203491091142,
#    'Rank': 1,
#    'Outlook': 'Below Average',
#    'AnnualWages': 223410.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Physical Medicine and Rehabilitation Physicians',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1141.02',
#    'Score': 0.5451239172983321,
#    'Rank': 2,
#    'Outlook': 'Bright',
#    'AnnualWages': 81220.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Advanced Practice Psychiatric Nurses',
#    'EduCode': 3.0},
#   {'OnetCode': '29-1299.01',
#    'Score': 0.5427063472592409,
#    'Rank': 3,
#    'Outlook': 'Below Average',
#    'AnnualWages': 106230.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Naturopathic Physicians',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1291.00',
#    'Score': 0.5307120733164209,
#    'Rank': 4,
#    'Outlook': 'Average',
#    'AnnualWages': 72220.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Acupuncturists',
#    'EduCode': 2.0},
#   {'OnetCode': '25-1061.00',
#    'Score': 0.5237403200197621,
#    'Rank': 5,
#    'Outlook': 'Bright',
#    'AnnualWages': 85000.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Anthropology and Archeology Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1218.00',
#    'Score': 0.5118401881275619,
#    'Rank': 6,
#    'Outlook': 'Below Average',
#    'AnnualWages': 999999.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Obstetricians and Gynecologists',
#    'EduCode': 2.0},
#   {'OnetCode': '25-1071.00',
#    'Score': 0.51054082035112,
#    'Rank': 7,
#    'Outlook': 'Bright',
#    'AnnualWages': 100300.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Health Specialties Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '25-2022.00',
#    'Score': 0.497882736389359,
#    'Rank': 8,
#    'Outlook': 'Average',
#    'AnnualWages': 61810.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Middle School Teachers, Except Special and Career/Technical Education',
#    'EduCode': 3.0},
#   {'OnetCode': '29-1011.00',
#    'Score': 0.49679868843827096,
#    'Rank': 9,
#    'Outlook': 'Bright',
#    'AnnualWages': 75380.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Chiropractors',
#    'EduCode': 2.0},
#   {'OnetCode': '25-1193.00',
#    'Score': 0.49630978881560495,
#    'Rank': 10,
#    'Outlook': 'Average',
#    'AnnualWages': 72650.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Recreation and Fitness Studies Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '39-3092.00',
#    'Score': 0.495182719515101,
#    'Rank': 11,
#    'Outlook': 'Bright',
#    'AnnualWages': 48470.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Costume Attendants',
#    'EduCode': 7.0},
#   {'OnetCode': '29-9099.01',
#    'Score': 0.48797125183573903,
#    'Rank': 12,
#    'Outlook': 'Average',
#    'AnnualWages': 60160.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Midwives',
#    'EduCode': 6.0},
#   {'OnetCode': '39-4011.00',
#    'Score': 0.487691849450431,
#    'Rank': 13,
#    'Outlook': 'Average',
#    'AnnualWages': 49910.0,
#    'TypicalEducation': "Associate's degree",
#    'OccupationTitle': 'Embalmers',
#    'EduCode': 4.0},
#   {'OnetCode': '29-1229.03',
#    'Score': 0.485166668620227,
#    'Rank': 14,
#    'Outlook': 'Below Average',
#    'AnnualWages': 223410.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Urologists',
#    'EduCode': 2.0},
#   {'OnetCode': '19-5012.00',
#    'Score': 0.48501796234828903,
#    'Rank': 15,
#    'Outlook': 'Average',
#    'AnnualWages': 57970.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Occupational Health and Safety Technicians',
#    'EduCode': 7.0},
#   {'OnetCode': '13-1041.06',
#    'Score': 0.48239438338414703,
#    'Rank': 16,
#    'Outlook': 'Average',
#    'AnnualWages': 71690.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Coroners',
#    'EduCode': 3.0},
#   {'OnetCode': '29-9092.00',
#    'Score': 0.480146602829598,
#    'Rank': 17,
#    'Outlook': 'Bright',
#    'AnnualWages': 89990.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Genetic Counselors',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1141.04',
#    'Score': 0.47896882862260404,
#    'Rank': 18,
#    'Outlook': 'Bright',
#    'AnnualWages': 81220.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Clinical Nurse Specialists',
#    'EduCode': 3.0},
#   {'OnetCode': '29-1161.00',
#    'Score': 0.478713852664624,
#    'Rank': 19,
#    'Outlook': 'Bright',
#    'AnnualWages': 120880.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Nurse Midwives',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1129.01',
#    'Score': 0.478071768687837,
#    'Rank': 20,
#    'Outlook': 'Bright',
#    'AnnualWages': 60800.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Art Therapists',
#    'EduCode': 3.0},
#   {'OnetCode': '29-1125.00',
#    'Score': 0.476879613936595,
#    'Rank': 21,
#    'Outlook': 'Average',
#    'AnnualWages': 51330.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Recreational Therapists',
#    'EduCode': 3.0},
#   {'OnetCode': '29-1229.01',
#    'Score': 0.47352314527085404,
#    'Rank': 22,
#    'Outlook': 'Below Average',
#    'AnnualWages': 223410.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Allergists and Immunologists',
#    'EduCode': 2.0},
#   {'OnetCode': '51-2021.00',
#    'Score': 0.473367718193553,
#    'Rank': 23,
#    'Outlook': 'Below Average',
#    'AnnualWages': 43160.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Coil Winders, Tapers, and Finishers',
#    'EduCode': 7.0},
#   {'OnetCode': '19-3091.00',
#    'Score': 0.471454404233699,
#    'Rank': 24,
#    'Outlook': 'Average',
#    'AnnualWages': 63940.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Anthropologists and Archeologists',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1129.02',
#    'Score': 0.470475691560396,
#    'Rank': 25,
#    'Outlook': 'Bright',
#    'AnnualWages': 60800.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Music Therapists',
#    'EduCode': 3.0},
#   {'OnetCode': '25-1066.00',
#    'Score': 0.468342155484347,
#    'Rank': 26,
#    'Outlook': 'Bright',
#    'AnnualWages': 78810.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Psychology Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '31-9097.00',
#    'Score': 0.467745276420662,
#    'Rank': 27,
#    'Outlook': 'Bright',
#    'AnnualWages': 38530.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Phlebotomists',
#    'EduCode': 6.0},
#   {'OnetCode': '29-1216.00',
#    'Score': 0.45998788675796903,
#    'Rank': 28,
#    'Outlook': 'Below Average',
#    'AnnualWages': 214460.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'General Internal Medicine Physicians',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1217.00',
#    'Score': 0.458376451841869,
#    'Rank': 29,
#    'Outlook': 'Below Average',
#    'AnnualWages': 224260.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Neurologists',
#    'EduCode': 2.0},
#   {'OnetCode': '39-5092.00',
#    'Score': 0.45543820233502097,
#    'Rank': 30,
#    'Outlook': 'Bright',
#    'AnnualWages': 31130.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Manicurists and Pedicurists',
#    'EduCode': 6.0},
#   {'OnetCode': '29-1122.00',
#    'Score': 0.45346837526078704,
#    'Rank': 31,
#    'Outlook': 'Bright',
#    'AnnualWages': 93180.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Occupational Therapists',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1229.02',
#    'Score': 0.45328363416214495,
#    'Rank': 32,
#    'Outlook': 'Below Average',
#    'AnnualWages': 223410.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Hospitalists',
#    'EduCode': 2.0},
#   {'OnetCode': '31-1131.00',
#    'Score': 0.45263881587793,
#    'Rank': 33,
#    'Outlook': 'Bright',
#    'AnnualWages': 35760.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Nursing Assistants',
#    'EduCode': 6.0},
#   {'OnetCode': '29-1022.00',
#    'Score': 0.452252985558225,
#    'Rank': 34,
#    'Outlook': 'Average',
#    'AnnualWages': 999999.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Oral and Maxillofacial Surgeons',
#    'EduCode': 2.0},
#   {'OnetCode': '25-2012.00',
#    'Score': 0.450018095356813,
#    'Rank': 35,
#    'Outlook': 'Average',
#    'AnnualWages': 60490.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Kindergarten Teachers, Except Special Education',
#    'EduCode': 3.0},
#   {'OnetCode': '29-2091.00',
#    'Score': 0.449494800349898,
#    'Rank': 36,
#    'Outlook': 'Bright',
#    'AnnualWages': 77070.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Orthotists and Prosthetists',
#    'EduCode': 2.0},
#   {'OnetCode': '31-2022.00',
#    'Score': 0.44891750402089403,
#    'Rank': 37,
#    'Outlook': 'Bright',
#    'AnnualWages': 31410.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Physical Therapist Aides',
#    'EduCode': 7.0},
#   {'OnetCode': '29-1221.00',
#    'Score': 0.448847889875983,
#    'Rank': 38,
#    'Outlook': 'Below Average',
#    'AnnualWages': 190350.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Pediatricians, General',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1071.00',
#    'Score': 0.445446223014427,
#    'Rank': 39,
#    'Outlook': 'Bright',
#    'AnnualWages': 126010.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Physician Assistants',
#    'EduCode': 2.0},
#   {'OnetCode': '25-2031.00',
#    'Score': 0.4429410098301,
#    'Rank': 40,
#    'Outlook': 'Average',
#    'AnnualWages': 62360.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Secondary School Teachers, Except Special and Career/Technical Education',
#    'EduCode': 3.0},
#   {'OnetCode': '25-1041.00',
#    'Score': 0.442431382242169,
#    'Rank': 41,
#    'Outlook': 'Average',
#    'AnnualWages': 85860.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Agricultural Sciences Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '45-2041.00',
#    'Score': 0.44241495660644,
#    'Rank': 42,
#    'Outlook': 'Below Average',
#    'AnnualWages': 32550.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Graders and Sorters, Agricultural Products',
#    'EduCode': 9.0},
#   {'OnetCode': '25-1053.00',
#    'Score': 0.44200858748635596,
#    'Rank': 43,
#    'Outlook': 'Bright',
#    'AnnualWages': 83040.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Environmental Science Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '25-1072.00',
#    'Score': 0.44116342258398,
#    'Rank': 44,
#    'Outlook': 'Bright',
#    'AnnualWages': 78580.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Nursing Instructors and Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '31-9011.00',
#    'Score': 0.440630730537222,
#    'Rank': 45,
#    'Outlook': 'Bright',
#    'AnnualWages': 49860.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Massage Therapists',
#    'EduCode': 6.0},
#   {'OnetCode': '33-9092.00',
#    'Score': 0.44051488108183795,
#    'Rank': 46,
#    'Outlook': 'Bright',
#    'AnnualWages': 27270.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Lifeguards, Ski Patrol, and Other Recreational Protective Service Workers',
#    'EduCode': 9.0},
#   {'OnetCode': '51-3022.00',
#    'Score': 0.440445936445403,
#    'Rank': 47,
#    'Outlook': 'Below Average',
#    'AnnualWages': 35070.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Meat, Poultry, and Fish Cutters and Trimmers',
#    'EduCode': 9.0},
#   {'OnetCode': '29-1171.00',
#    'Score': 0.44011242193559297,
#    'Rank': 48,
#    'Outlook': 'Bright',
#    'AnnualWages': 121610.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Nurse Practitioners',
#    'EduCode': 2.0},
#   {'OnetCode': '39-2021.00',
#    'Score': 0.438379562405452,
#    'Rank': 49,
#    'Outlook': 'Bright',
#    'AnnualWages': 29530.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Animal Caretakers',
#    'EduCode': 7.0},
#   {'OnetCode': '29-1223.00',
#    'Score': 0.43775176513501995,
#    'Rank': 50,
#    'Outlook': 'Bright',
#    'AnnualWages': 226880.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Psychiatrists',
#    'EduCode': 2.0},
#   {'OnetCode': '21-1091.00',
#    'Score': 0.43700859424652594,
#    'Rank': 51,
#    'Outlook': 'Bright',
#    'AnnualWages': 59990.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Health Education Specialists',
#    'EduCode': 3.0},
#   {'OnetCode': '25-2023.00',
#    'Score': 0.435592856510945,
#    'Rank': 52,
#    'Outlook': 'Below Average',
#    'AnnualWages': 62630.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Career/Technical Education Teachers, Middle School',
#    'EduCode': 3.0},
#   {'OnetCode': '25-1121.00',
#    'Score': 0.435026711466548,
#    'Rank': 53,
#    'Outlook': 'Bright',
#    'AnnualWages': 77280.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Art, Drama, and Music Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '25-2032.00',
#    'Score': 0.43408161006564,
#    'Rank': 54,
#    'Outlook': 'Below Average',
#    'AnnualWages': 62500.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Career/Technical Education Teachers, Secondary School',
#    'EduCode': 3.0},
#   {'OnetCode': '29-2035.00',
#    'Score': 0.43142455984840006,
#    'Rank': 55,
#    'Outlook': 'Average',
#    'AnnualWages': 80090.0,
#    'TypicalEducation': "Associate's degree",
#    'OccupationTitle': 'Magnetic Resonance Imaging Technologists',
#    'EduCode': 4.0},
#   {'OnetCode': '29-1123.00',
#    'Score': 0.430859911460427,
#    'Rank': 56,
#    'Outlook': 'Bright',
#    'AnnualWages': 97720.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Physical Therapists',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1224.00',
#    'Score': 0.43050972308874996,
#    'Rank': 57,
#    'Outlook': 'Average',
#    'AnnualWages': 999999.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Radiologists',
#    'EduCode': 2.0},
#   {'OnetCode': '19-3093.00',
#    'Score': 0.429143980756668,
#    'Rank': 58,
#    'Outlook': 'Average',
#    'AnnualWages': 64540.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Historians',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1041.00',
#    'Score': 0.428909717314701,
#    'Rank': 59,
#    'Outlook': 'Bright',
#    'AnnualWages': 125590.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Optometrists',
#    'EduCode': 2.0},
#   {'OnetCode': '25-1051.00',
#    'Score': 0.42845218879081404,
#    'Rank': 60,
#    'Outlook': 'Average',
#    'AnnualWages': 97770.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Atmospheric, Earth, Marine, and Space Sciences Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '33-3041.00',
#    'Score': 0.425904455184608,
#    'Rank': 61,
#    'Outlook': 'Below Average',
#    'AnnualWages': 41570.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Parking Enforcement Workers',
#    'EduCode': 7.0},
#   {'OnetCode': '25-1042.00',
#    'Score': 0.424602416899951,
#    'Rank': 62,
#    'Outlook': 'Bright',
#    'AnnualWages': 81650.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Biological Science Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '25-1123.00',
#    'Score': 0.423918128889348,
#    'Rank': 63,
#    'Outlook': 'Average',
#    'AnnualWages': 74280.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'English Language and Literature Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1131.00',
#    'Score': 0.42280331803842097,
#    'Rank': 64,
#    'Outlook': 'Bright',
#    'AnnualWages': 103260.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Veterinarians',
#    'EduCode': 2.0},
#   {'OnetCode': '43-6013.00',
#    'Score': 0.417252874721427,
#    'Rank': 65,
#    'Outlook': 'Bright',
#    'AnnualWages': 38500.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Medical Secretaries and Administrative Assistants',
#    'EduCode': 7.0},
#   {'OnetCode': '29-1141.03',
#    'Score': 0.416736089358324,
#    'Rank': 66,
#    'Outlook': 'Bright',
#    'AnnualWages': 81220.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Critical Care Nurses',
#    'EduCode': 3.0},
#   {'OnetCode': '21-1094.00',
#    'Score': 0.416318796010853,
#    'Rank': 67,
#    'Outlook': 'Bright',
#    'AnnualWages': 46190.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Community Health Workers',
#    'EduCode': 7.0},
#   {'OnetCode': '21-1022.00',
#    'Score': 0.415331318596535,
#    'Rank': 68,
#    'Outlook': 'Bright',
#    'AnnualWages': 60280.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Healthcare Social Workers',
#    'EduCode': 2.0},
#   {'OnetCode': '25-2058.00',
#    'Score': 0.415004287939102,
#    'Rank': 69,
#    'Outlook': 'Average',
#    'AnnualWages': 63560.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Special Education Teachers, Secondary School',
#    'EduCode': 3.0},
#   {'OnetCode': '39-9041.00',
#    'Score': 0.413843150384201,
#    'Rank': 70,
#    'Outlook': 'Bright',
#    'AnnualWages': 35720.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Residential Advisors',
#    'EduCode': 7.0},
#   {'OnetCode': '29-1211.00',
#    'Score': 0.410843352164265,
#    'Rank': 71,
#    'Outlook': 'Below Average',
#    'AnnualWages': 999999.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Anesthesiologists',
#    'EduCode': 2.0},
#   {'OnetCode': '43-4071.00',
#    'Score': 0.409666293478265,
#    'Rank': 72,
#    'Outlook': 'Below Average',
#    'AnnualWages': 37290.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'File Clerks',
#    'EduCode': 7.0},
#   {'OnetCode': '29-1229.05',
#    'Score': 0.409664066787757,
#    'Rank': 73,
#    'Outlook': 'Below Average',
#    'AnnualWages': 223410.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Preventive Medicine Physicians',
#    'EduCode': 2.0},
#   {'OnetCode': '25-3041.00',
#    'Score': 0.4095849848962,
#    'Rank': 74,
#    'Outlook': 'Bright',
#    'AnnualWages': 36680.0,
#    'TypicalEducation': 'Some college, no degree',
#    'OccupationTitle': 'Tutors',
#    'EduCode': 6.0},
#   {'OnetCode': '19-3034.00',
#    'Score': 0.40957528537564,
#    'Rank': 75,
#    'Outlook': 'Average',
#    'AnnualWages': 81500.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'School Psychologists',
#    'EduCode': 2.0},
#   {'OnetCode': '19-3033.00',
#    'Score': 0.407751219697256,
#    'Rank': 76,
#    'Outlook': 'Bright',
#    'AnnualWages': 90130.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Clinical and Counseling Psychologists',
#    'EduCode': 2.0},
#   {'OnetCode': '31-2011.00',
#    'Score': 0.406985807934673,
#    'Rank': 77,
#    'Outlook': 'Bright',
#    'AnnualWages': 64250.0,
#    'TypicalEducation': "Associate's degree",
#    'OccupationTitle': 'Occupational Therapy Assistants',
#    'EduCode': 4.0},
#   {'OnetCode': '29-1213.00',
#    'Score': 0.40590627001808605,
#    'Rank': 78,
#    'Outlook': 'Below Average',
#    'AnnualWages': 999999.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Dermatologists',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1151.00',
#    'Score': 0.40354523166581996,
#    'Rank': 79,
#    'Outlook': 'Bright',
#    'AnnualWages': 203090.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Nurse Anesthetists',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1081.00',
#    'Score': 0.403499922333499,
#    'Rank': 80,
#    'Outlook': 'Below Average',
#    'AnnualWages': 148720.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Podiatrists',
#    'EduCode': 2.0},
#   {'OnetCode': '25-1043.00',
#    'Score': 0.400586480003306,
#    'Rank': 81,
#    'Outlook': 'Bright',
#    'AnnualWages': 96500.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Forestry and Conservation Science Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '33-3051.04',
#    'Score': 0.40032483062670204,
#    'Rank': 82,
#    'Outlook': 'Below Average',
#    'AnnualWages': 65790.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Customs and Border Protection Officers',
#    'EduCode': 7.0},
#   {'OnetCode': '19-5011.00',
#    'Score': 0.39991135903527103,
#    'Rank': 83,
#    'Outlook': 'Average',
#    'AnnualWages': 78570.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Occupational Health and Safety Specialists',
#    'EduCode': 3.0},
#   {'OnetCode': '29-2099.05',
#    'Score': 0.39937969034994203,
#    'Rank': 84,
#    'Outlook': 'Average',
#    'AnnualWages': 44990.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Ophthalmic Medical Technologists',
#    'EduCode': 6.0},
#   {'OnetCode': '11-9171.00',
#    'Score': 0.399068222618321,
#    'Rank': 85,
#    'Outlook': 'Average',
#    'AnnualWages': 72110.0,
#    'TypicalEducation': "Associate's degree",
#    'OccupationTitle': 'Funeral Home Managers',
#    'EduCode': 4.0},
#   {'OnetCode': '47-2141.00',
#    'Score': 0.39864664342983297,
#    'Rank': 86,
#    'Outlook': 'Below Average',
#    'AnnualWages': 46090.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Painters, Construction and Maintenance',
#    'EduCode': 9.0},
#   {'OnetCode': '31-9092.00',
#    'Score': 0.396346500631606,
#    'Rank': 87,
#    'Outlook': 'Bright',
#    'AnnualWages': 38270.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Medical Assistants',
#    'EduCode': 6.0},
#   {'OnetCode': '33-3052.00',
#    'Score': 0.395663073220395,
#    'Rank': 88,
#    'Outlook': 'Below Average',
#    'AnnualWages': 69150.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Transit and Railroad Police',
#    'EduCode': 7.0},
#   {'OnetCode': '29-9091.00',
#    'Score': 0.39498478979796,
#    'Rank': 89,
#    'Outlook': 'Bright',
#    'AnnualWages': 53840.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Athletic Trainers',
#    'EduCode': 2.0},
#   {'OnetCode': '13-1199.05',
#    'Score': 0.394905167789361,
#    'Rank': 90,
#    'Outlook': 'Bright',
#    'AnnualWages': 75990.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Sustainability Specialists',
#    'EduCode': 3.0},
#   {'OnetCode': '35-1011.00',
#    'Score': 0.393109593033306,
#    'Rank': 91,
#    'Outlook': 'Bright',
#    'AnnualWages': 56520.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Chefs and Head Cooks',
#    'EduCode': 7.0},
#   {'OnetCode': '21-1011.00',
#    'Score': 0.392235937495668,
#    'Rank': 92,
#    'Outlook': 'Bright',
#    'AnnualWages': 49710.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Substance Abuse and Behavioral Disorder Counselors',
#    'EduCode': 3.0},
#   {'OnetCode': '27-3023.00',
#    'Score': 0.391753442815369,
#    'Rank': 93,
#    'Outlook': 'Below Average',
#    'AnnualWages': 55960.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'News Analysts, Reporters, and Journalists',
#    'EduCode': 3.0},
#   {'OnetCode': '25-1031.00',
#    'Score': 0.391662973702556,
#    'Rank': 94,
#    'Outlook': 'Bright',
#    'AnnualWages': 93220.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Architecture Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '25-1111.00',
#    'Score': 0.389781967858529,
#    'Rank': 95,
#    'Outlook': 'Bright',
#    'AnnualWages': 64990.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Criminal Justice and Law Enforcement Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '25-9021.00',
#    'Score': 0.389562070131471,
#    'Rank': 96,
#    'Outlook': 'Below Average',
#    'AnnualWages': 53450.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Farm and Home Management Educators',
#    'EduCode': 2.0},
#   {'OnetCode': '33-9011.00',
#    'Score': 0.388219214992589,
#    'Rank': 97,
#    'Outlook': 'Average',
#    'AnnualWages': 39320.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Animal Control Workers',
#    'EduCode': 7.0},
#   {'OnetCode': '29-1128.00',
#    'Score': 0.386988354454665,
#    'Rank': 98,
#    'Outlook': 'Bright',
#    'AnnualWages': 51350.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Exercise Physiologists',
#    'EduCode': 3.0},
#   {'OnetCode': '21-1021.00',
#    'Score': 0.385728594796136,
#    'Rank': 99,
#    'Outlook': 'Bright',
#    'AnnualWages': 50820.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Child, Family, and School Social Workers',
#    'EduCode': 3.0},
#   {'OnetCode': '25-1067.00',
#    'Score': 0.385628335821971,
#    'Rank': 100,
#    'Outlook': 'Bright',
#    'AnnualWages': 78970.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Sociology Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1215.00',
#    'Score': 0.38523367101234096,
#    'Rank': 101,
#    'Outlook': 'Below Average',
#    'AnnualWages': 211300.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Family Medicine Physicians',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1141.01',
#    'Score': 0.383370135917543,
#    'Rank': 102,
#    'Outlook': 'Bright',
#    'AnnualWages': 81220.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Acute Care Nurses',
#    'EduCode': 3.0},
#   {'OnetCode': '25-2057.00',
#    'Score': 0.38276120164139604,
#    'Rank': 103,
#    'Outlook': 'Average',
#    'AnnualWages': 62990.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Special Education Teachers, Middle School',
#    'EduCode': 3.0},
#   {'OnetCode': '17-1012.00',
#    'Score': 0.380748896526385,
#    'Rank': 104,
#    'Outlook': 'Below Average',
#    'AnnualWages': 73210.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Landscape Architects',
#    'EduCode': 3.0},
#   {'OnetCode': '25-1192.00',
#    'Score': 0.380619784394277,
#    'Rank': 105,
#    'Outlook': 'Average',
#    'AnnualWages': 76440.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Family and Consumer Sciences Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '33-2022.00',
#    'Score': 0.37926537601816995,
#    'Rank': 106,
#    'Outlook': 'Bright',
#    'AnnualWages': 48110.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Forest Fire Inspectors and Prevention Specialists',
#    'EduCode': 7.0},
#   {'OnetCode': '29-2099.08',
#    'Score': 0.378867652938406,
#    'Rank': 107,
#    'Outlook': 'Average',
#    'AnnualWages': 44990.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Patient Representatives',
#    'EduCode': 6.0},
#   {'OnetCode': '39-4021.00',
#    'Score': 0.378706636905142,
#    'Rank': 108,
#    'Outlook': 'Bright',
#    'AnnualWages': 31160.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Funeral Attendants',
#    'EduCode': 7.0},
#   {'OnetCode': '25-2059.01',
#    'Score': 0.37843274048136,
#    'Rank': 109,
#    'Outlook': 'Average',
#    'AnnualWages': 63950.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Adapted Physical Education Specialists',
#    'EduCode': 3.0},
#   {'OnetCode': '31-2012.00',
#    'Score': 0.37442066015339104,
#    'Rank': 110,
#    'Outlook': 'Bright',
#    'AnnualWages': 37060.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Occupational Therapy Aides',
#    'EduCode': 7.0},
#   {'OnetCode': '11-1011.03',
#    'Score': 0.374413204796032,
#    'Rank': 111,
#    'Outlook': 'Below Average',
#    'AnnualWages': 189520.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Chief Sustainability Officers',
#    'EduCode': 3.0},
#   {'OnetCode': '35-3041.00',
#    'Score': 0.37436173092748304,
#    'Rank': 112,
#    'Outlook': 'Average',
#    'AnnualWages': 30300.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Food Servers, Nonrestaurant',
#    'EduCode': 9.0},
#   {'OnetCode': '25-1113.00',
#    'Score': 0.373617846541146,
#    'Rank': 113,
#    'Outlook': 'Bright',
#    'AnnualWages': 66510.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Social Work Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '47-2142.00',
#    'Score': 0.370722827099117,
#    'Rank': 114,
#    'Outlook': 'Below Average',
#    'AnnualWages': 44930.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Paperhangers',
#    'EduCode': 9.0},
#   {'OnetCode': '33-3051.00',
#    'Score': 0.37021636967147004,
#    'Rank': 115,
#    'Outlook': 'Below Average',
#    'AnnualWages': 65790.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': "Police and Sheriff's Patrol Officers",
#    'EduCode': 7.0},
#   {'OnetCode': '29-1181.00',
#    'Score': 0.37005660164672105,
#    'Rank': 116,
#    'Outlook': 'Bright',
#    'AnnualWages': 82680.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Audiologists',
#    'EduCode': 2.0},
#   {'OnetCode': '25-1122.00',
#    'Score': 0.36942590107687395,
#    'Rank': 117,
#    'Outlook': 'Average',
#    'AnnualWages': 76250.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Communications Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '21-2011.00',
#    'Score': 0.368121245527409,
#    'Rank': 118,
#    'Outlook': 'Average',
#    'AnnualWages': 55550.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Clergy',
#    'EduCode': 3.0},
#   {'OnetCode': '39-3093.00',
#    'Score': 0.367647060660157,
#    'Rank': 119,
#    'Outlook': 'Bright',
#    'AnnualWages': 30210.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Locker Room, Coatroom, and Dressing Room Attendants',
#    'EduCode': 7.0},
#   {'OnetCode': '11-9179.01',
#    'Score': 0.367498529316694,
#    'Rank': 120,
#    'Outlook': 'Bright',
#    'AnnualWages': 56090.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Fitness and Wellness Coordinators',
#    'EduCode': 7.0},
#   {'OnetCode': '17-2111.00',
#    'Score': 0.366930911875324,
#    'Rank': 121,
#    'Outlook': 'Average',
#    'AnnualWages': 100660.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Health and Safety Engineers, Except Mining Safety Engineers and Inspectors',
#    'EduCode': 3.0},
#   {'OnetCode': '27-2021.00',
#    'Score': 0.366861266722169,
#    'Rank': 122,
#    'Outlook': 'Bright',
#    'AnnualWages': 94270.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Athletes and Sports Competitors',
#    'EduCode': 9.0},
#   {'OnetCode': '33-3021.00',
#    'Score': 0.366199006306096,
#    'Rank': 123,
#    'Outlook': 'Below Average',
#    'AnnualWages': 86280.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Detectives and Criminal Investigators',
#    'EduCode': 7.0},
#   {'OnetCode': '29-1241.00',
#    'Score': 0.36463146705842403,
#    'Rank': 124,
#    'Outlook': 'Average',
#    'AnnualWages': 219810.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Ophthalmologists, Except Pediatric',
#    'EduCode': 2.0},
#   {'OnetCode': '25-1081.00',
#    'Score': 0.36444925838361103,
#    'Rank': 125,
#    'Outlook': 'Bright',
#    'AnnualWages': 66930.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Education Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1021.00',
#    'Score': 0.364117679311525,
#    'Rank': 126,
#    'Outlook': 'Average',
#    'AnnualWages': 155040.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Dentists, General',
#    'EduCode': 2.0},
#   {'OnetCode': '19-3092.00',
#    'Score': 0.36359208756804695,
#    'Rank': 127,
#    'Outlook': 'Below Average',
#    'AnnualWages': 88900.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Geographers',
#    'EduCode': 3.0},
#   {'OnetCode': '11-9031.00',
#    'Score': 0.363003219697315,
#    'Rank': 128,
#    'Outlook': 'Bright',
#    'AnnualWages': 49690.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Education and Childcare Administrators, Preschool and Daycare',
#    'EduCode': 3.0},
#   {'OnetCode': '43-4061.00',
#    'Score': 0.362146148165004,
#    'Rank': 129,
#    'Outlook': 'Below Average',
#    'AnnualWages': 49230.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Eligibility Interviewers, Government Programs',
#    'EduCode': 7.0},
#   {'OnetCode': '39-2011.00',
#    'Score': 0.360723933858692,
#    'Rank': 130,
#    'Outlook': 'Bright',
#    'AnnualWages': 35620.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Animal Trainers',
#    'EduCode': 7.0},
#   {'OnetCode': '21-1015.00',
#    'Score': 0.357516514492597,
#    'Rank': 131,
#    'Outlook': 'Bright',
#    'AnnualWages': 39990.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Rehabilitation Counselors',
#    'EduCode': 2.0},
#   {'OnetCode': '39-7011.00',
#    'Score': 0.357239224918264,
#    'Rank': 132,
#    'Outlook': 'Bright',
#    'AnnualWages': 34440.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Tour Guides and Escorts',
#    'EduCode': 7.0},
#   {'OnetCode': '29-2057.00',
#    'Score': 0.357058678296984,
#    'Rank': 133,
#    'Outlook': 'Bright',
#    'AnnualWages': 38860.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Ophthalmic Medical Technicians',
#    'EduCode': 6.0},
#   {'OnetCode': '51-9051.00',
#    'Score': 0.355659491886442,
#    'Rank': 134,
#    'Outlook': 'Below Average',
#    'AnnualWages': 44530.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Furnace, Kiln, Oven, Drier, and Kettle Operators and Tenders',
#    'EduCode': 7.0},
#   {'OnetCode': '29-2092.00',
#    'Score': 0.35544796749975005,
#    'Rank': 135,
#    'Outlook': 'Bright',
#    'AnnualWages': 59020.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Hearing Aid Specialists',
#    'EduCode': 7.0},
#   {'OnetCode': '25-1052.00',
#    'Score': 0.35462128769989,
#    'Rank': 136,
#    'Outlook': 'Bright',
#    'AnnualWages': 80720.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Chemistry Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '27-3043.05',
#    'Score': 0.351926900493188,
#    'Rank': 137,
#    'Outlook': 'Average',
#    'AnnualWages': 73150.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Poets, Lyricists and Creative Writers',
#    'EduCode': 3.0},
#   {'OnetCode': '19-1031.03',
#    'Score': 0.35145193213451703,
#    'Rank': 138,
#    'Outlook': 'Below Average',
#    'AnnualWages': 64460.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Park Naturalists',
#    'EduCode': 3.0},
#   {'OnetCode': '25-1194.00',
#    'Score': 0.351096638636456,
#    'Rank': 139,
#    'Outlook': 'Below Average',
#    'AnnualWages': 59840.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Career/Technical Education Teachers, Postsecondary',
#    'EduCode': 3.0},
#   {'OnetCode': '29-9093.00',
#    'Score': 0.35094138250254203,
#    'Rank': 140,
#    'Outlook': 'Average',
#    'AnnualWages': 57290.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Surgical Assistants',
#    'EduCode': 6.0},
#   {'OnetCode': '31-9096.00',
#    'Score': 0.350558145871337,
#    'Rank': 141,
#    'Outlook': 'Bright',
#    'AnnualWages': 34740.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Veterinary Assistants and Laboratory Animal Caretakers',
#    'EduCode': 7.0},
#   {'OnetCode': '29-2051.00',
#    'Score': 0.34917416423070097,
#    'Rank': 142,
#    'Outlook': 'Average',
#    'AnnualWages': 33960.0,
#    'TypicalEducation': "Associate's degree",
#    'OccupationTitle': 'Dietetic Technicians',
#    'EduCode': 4.0},
#   {'OnetCode': '29-2061.00',
#    'Score': 0.349020919633883,
#    'Rank': 143,
#    'Outlook': 'Average',
#    'AnnualWages': 54620.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Licensed Practical and Licensed Vocational Nurses',
#    'EduCode': 6.0},
#   {'OnetCode': '29-1299.02',
#    'Score': 0.347971124217931,
#    'Rank': 144,
#    'Outlook': 'Below Average',
#    'AnnualWages': 106230.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Orthoptists',
#    'EduCode': 2.0},
#   {'OnetCode': '53-3011.00',
#    'Score': 0.347703569039893,
#    'Rank': 145,
#    'Outlook': 'Below Average',
#    'AnnualWages': 30380.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Ambulance Drivers and Attendants, Except Emergency Medical Technicians',
#    'EduCode': 7.0},
#   {'OnetCode': '25-2021.00',
#    'Score': 0.34674057548964704,
#    'Rank': 146,
#    'Outlook': 'Bright',
#    'AnnualWages': 61690.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Elementary School Teachers, Except Special Education',
#    'EduCode': 3.0},
#   {'OnetCode': '19-4012.00',
#    'Score': 0.346432143524055,
#    'Rank': 147,
#    'Outlook': 'Bright',
#    'AnnualWages': 41760.0,
#    'TypicalEducation': "Associate's degree",
#    'OccupationTitle': 'Agricultural Technicians',
#    'EduCode': 4.0},
#   {'OnetCode': '25-1082.00',
#    'Score': 0.344111244201267,
#    'Rank': 148,
#    'Outlook': 'Bright',
#    'AnnualWages': 76370.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Library Science Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '21-2021.00',
#    'Score': 0.343852502511148,
#    'Rank': 149,
#    'Outlook': 'Average',
#    'AnnualWages': 49380.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Directors, Religious Activities and Education',
#    'EduCode': 3.0},
#   {'OnetCode': '33-1011.00',
#    'Score': 0.34334444964192395,
#    'Rank': 150,
#    'Outlook': 'Below Average',
#    'AnnualWages': 63310.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'First-Line Supervisors of Correctional Officers',
#    'EduCode': 7.0}],
#  'EduClassList': [{'EduCode': 2.0,
#    'EduTitle': "Master's degree or higher",
#    'Count': 62},
#   {'EduCode': 3.0, 'EduTitle': "Bachelor's degree", 'Count': 34},
#   {'EduCode': 7.0,
#    'EduTitle': 'High school diploma or equivalent',
#    'Count': 29},
#   {'EduCode': 6.0, 'EduTitle': 'Some college', 'Count': 12},
#   {'EduCode': 9.0, 'EduTitle': 'Some high school', 'Count': 7},
#   {'EduCode': 4.0, 'EduTitle': "Associate's degree", 'Count': 6}],
#  'RecordCount': 150,
#  'FilterValue': 0}

# %%
headers = {
  "Authorization": f"Bearer {api_key['token-key']}"
}

response = requests.post(url, json=example_request, headers=headers)
response = response.json() # This matches the response we generated using the API Explorer

response
# Out:
# {'SKARankList': [{'OnetCode': '29-1229.04',
#    'Score': 0.579203491091142,
#    'Rank': 1,
#    'Outlook': 'Below Average',
#    'AnnualWages': 223410.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Physical Medicine and Rehabilitation Physicians',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1141.02',
#    'Score': 0.5451239172983321,
#    'Rank': 2,
#    'Outlook': 'Bright',
#    'AnnualWages': 81220.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Advanced Practice Psychiatric Nurses',
#    'EduCode': 3.0},
#   {'OnetCode': '29-1299.01',
#    'Score': 0.5427063472592409,
#    'Rank': 3,
#    'Outlook': 'Below Average',
#    'AnnualWages': 106230.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Naturopathic Physicians',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1291.00',
#    'Score': 0.5307120733164209,
#    'Rank': 4,
#    'Outlook': 'Average',
#    'AnnualWages': 72220.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Acupuncturists',
#    'EduCode': 2.0},
#   {'OnetCode': '25-1061.00',
#    'Score': 0.5237403200197621,
#    'Rank': 5,
#    'Outlook': 'Bright',
#    'AnnualWages': 85000.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Anthropology and Archeology Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1218.00',
#    'Score': 0.5118401881275619,
#    'Rank': 6,
#    'Outlook': 'Below Average',
#    'AnnualWages': 999999.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Obstetricians and Gynecologists',
#    'EduCode': 2.0},
#   {'OnetCode': '25-1071.00',
#    'Score': 0.51054082035112,
#    'Rank': 7,
#    'Outlook': 'Bright',
#    'AnnualWages': 100300.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Health Specialties Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '25-2022.00',
#    'Score': 0.497882736389359,
#    'Rank': 8,
#    'Outlook': 'Average',
#    'AnnualWages': 61810.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Middle School Teachers, Except Special and Career/Technical Education',
#    'EduCode': 3.0},
#   {'OnetCode': '29-1011.00',
#    'Score': 0.49679868843827096,
#    'Rank': 9,
#    'Outlook': 'Bright',
#    'AnnualWages': 75380.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Chiropractors',
#    'EduCode': 2.0},
#   {'OnetCode': '25-1193.00',
#    'Score': 0.49630978881560495,
#    'Rank': 10,
#    'Outlook': 'Average',
#    'AnnualWages': 72650.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Recreation and Fitness Studies Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '39-3092.00',
#    'Score': 0.495182719515101,
#    'Rank': 11,
#    'Outlook': 'Bright',
#    'AnnualWages': 48470.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Costume Attendants',
#    'EduCode': 7.0},
#   {'OnetCode': '29-9099.01',
#    'Score': 0.48797125183573903,
#    'Rank': 12,
#    'Outlook': 'Average',
#    'AnnualWages': 60160.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Midwives',
#    'EduCode': 6.0},
#   {'OnetCode': '39-4011.00',
#    'Score': 0.487691849450431,
#    'Rank': 13,
#    'Outlook': 'Average',
#    'AnnualWages': 49910.0,
#    'TypicalEducation': "Associate's degree",
#    'OccupationTitle': 'Embalmers',
#    'EduCode': 4.0},
#   {'OnetCode': '29-1229.03',
#    'Score': 0.485166668620227,
#    'Rank': 14,
#    'Outlook': 'Below Average',
#    'AnnualWages': 223410.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Urologists',
#    'EduCode': 2.0},
#   {'OnetCode': '19-5012.00',
#    'Score': 0.48501796234828903,
#    'Rank': 15,
#    'Outlook': 'Average',
#    'AnnualWages': 57970.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Occupational Health and Safety Technicians',
#    'EduCode': 7.0},
#   {'OnetCode': '13-1041.06',
#    'Score': 0.48239438338414703,
#    'Rank': 16,
#    'Outlook': 'Average',
#    'AnnualWages': 71690.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Coroners',
#    'EduCode': 3.0},
#   {'OnetCode': '29-9092.00',
#    'Score': 0.480146602829598,
#    'Rank': 17,
#    'Outlook': 'Bright',
#    'AnnualWages': 89990.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Genetic Counselors',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1141.04',
#    'Score': 0.47896882862260404,
#    'Rank': 18,
#    'Outlook': 'Bright',
#    'AnnualWages': 81220.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Clinical Nurse Specialists',
#    'EduCode': 3.0},
#   {'OnetCode': '29-1161.00',
#    'Score': 0.478713852664624,
#    'Rank': 19,
#    'Outlook': 'Bright',
#    'AnnualWages': 120880.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Nurse Midwives',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1129.01',
#    'Score': 0.478071768687837,
#    'Rank': 20,
#    'Outlook': 'Bright',
#    'AnnualWages': 60800.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Art Therapists',
#    'EduCode': 3.0},
#   {'OnetCode': '29-1125.00',
#    'Score': 0.476879613936595,
#    'Rank': 21,
#    'Outlook': 'Average',
#    'AnnualWages': 51330.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Recreational Therapists',
#    'EduCode': 3.0},
#   {'OnetCode': '29-1229.01',
#    'Score': 0.47352314527085404,
#    'Rank': 22,
#    'Outlook': 'Below Average',
#    'AnnualWages': 223410.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Allergists and Immunologists',
#    'EduCode': 2.0},
#   {'OnetCode': '51-2021.00',
#    'Score': 0.473367718193553,
#    'Rank': 23,
#    'Outlook': 'Below Average',
#    'AnnualWages': 43160.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Coil Winders, Tapers, and Finishers',
#    'EduCode': 7.0},
#   {'OnetCode': '19-3091.00',
#    'Score': 0.471454404233699,
#    'Rank': 24,
#    'Outlook': 'Average',
#    'AnnualWages': 63940.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Anthropologists and Archeologists',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1129.02',
#    'Score': 0.470475691560396,
#    'Rank': 25,
#    'Outlook': 'Bright',
#    'AnnualWages': 60800.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Music Therapists',
#    'EduCode': 3.0},
#   {'OnetCode': '25-1066.00',
#    'Score': 0.468342155484347,
#    'Rank': 26,
#    'Outlook': 'Bright',
#    'AnnualWages': 78810.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Psychology Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '31-9097.00',
#    'Score': 0.467745276420662,
#    'Rank': 27,
#    'Outlook': 'Bright',
#    'AnnualWages': 38530.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Phlebotomists',
#    'EduCode': 6.0},
#   {'OnetCode': '29-1216.00',
#    'Score': 0.45998788675796903,
#    'Rank': 28,
#    'Outlook': 'Below Average',
#    'AnnualWages': 214460.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'General Internal Medicine Physicians',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1217.00',
#    'Score': 0.458376451841869,
#    'Rank': 29,
#    'Outlook': 'Below Average',
#    'AnnualWages': 224260.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Neurologists',
#    'EduCode': 2.0},
#   {'OnetCode': '39-5092.00',
#    'Score': 0.45543820233502097,
#    'Rank': 30,
#    'Outlook': 'Bright',
#    'AnnualWages': 31130.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Manicurists and Pedicurists',
#    'EduCode': 6.0},
#   {'OnetCode': '29-1122.00',
#    'Score': 0.45346837526078704,
#    'Rank': 31,
#    'Outlook': 'Bright',
#    'AnnualWages': 93180.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Occupational Therapists',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1229.02',
#    'Score': 0.45328363416214495,
#    'Rank': 32,
#    'Outlook': 'Below Average',
#    'AnnualWages': 223410.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Hospitalists',
#    'EduCode': 2.0},
#   {'OnetCode': '31-1131.00',
#    'Score': 0.45263881587793,
#    'Rank': 33,
#    'Outlook': 'Bright',
#    'AnnualWages': 35760.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Nursing Assistants',
#    'EduCode': 6.0},
#   {'OnetCode': '29-1022.00',
#    'Score': 0.452252985558225,
#    'Rank': 34,
#    'Outlook': 'Average',
#    'AnnualWages': 999999.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Oral and Maxillofacial Surgeons',
#    'EduCode': 2.0},
#   {'OnetCode': '25-2012.00',
#    'Score': 0.450018095356813,
#    'Rank': 35,
#    'Outlook': 'Average',
#    'AnnualWages': 60490.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Kindergarten Teachers, Except Special Education',
#    'EduCode': 3.0},
#   {'OnetCode': '29-2091.00',
#    'Score': 0.449494800349898,
#    'Rank': 36,
#    'Outlook': 'Bright',
#    'AnnualWages': 77070.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Orthotists and Prosthetists',
#    'EduCode': 2.0},
#   {'OnetCode': '31-2022.00',
#    'Score': 0.44891750402089403,
#    'Rank': 37,
#    'Outlook': 'Bright',
#    'AnnualWages': 31410.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Physical Therapist Aides',
#    'EduCode': 7.0},
#   {'OnetCode': '29-1221.00',
#    'Score': 0.448847889875983,
#    'Rank': 38,
#    'Outlook': 'Below Average',
#    'AnnualWages': 190350.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Pediatricians, General',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1071.00',
#    'Score': 0.445446223014427,
#    'Rank': 39,
#    'Outlook': 'Bright',
#    'AnnualWages': 126010.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Physician Assistants',
#    'EduCode': 2.0},
#   {'OnetCode': '25-2031.00',
#    'Score': 0.4429410098301,
#    'Rank': 40,
#    'Outlook': 'Average',
#    'AnnualWages': 62360.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Secondary School Teachers, Except Special and Career/Technical Education',
#    'EduCode': 3.0},
#   {'OnetCode': '25-1041.00',
#    'Score': 0.442431382242169,
#    'Rank': 41,
#    'Outlook': 'Average',
#    'AnnualWages': 85860.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Agricultural Sciences Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '45-2041.00',
#    'Score': 0.44241495660644,
#    'Rank': 42,
#    'Outlook': 'Below Average',
#    'AnnualWages': 32550.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Graders and Sorters, Agricultural Products',
#    'EduCode': 9.0},
#   {'OnetCode': '25-1053.00',
#    'Score': 0.44200858748635596,
#    'Rank': 43,
#    'Outlook': 'Bright',
#    'AnnualWages': 83040.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Environmental Science Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '25-1072.00',
#    'Score': 0.44116342258398,
#    'Rank': 44,
#    'Outlook': 'Bright',
#    'AnnualWages': 78580.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Nursing Instructors and Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '31-9011.00',
#    'Score': 0.440630730537222,
#    'Rank': 45,
#    'Outlook': 'Bright',
#    'AnnualWages': 49860.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Massage Therapists',
#    'EduCode': 6.0},
#   {'OnetCode': '33-9092.00',
#    'Score': 0.44051488108183795,
#    'Rank': 46,
#    'Outlook': 'Bright',
#    'AnnualWages': 27270.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Lifeguards, Ski Patrol, and Other Recreational Protective Service Workers',
#    'EduCode': 9.0},
#   {'OnetCode': '51-3022.00',
#    'Score': 0.440445936445403,
#    'Rank': 47,
#    'Outlook': 'Below Average',
#    'AnnualWages': 35070.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Meat, Poultry, and Fish Cutters and Trimmers',
#    'EduCode': 9.0},
#   {'OnetCode': '29-1171.00',
#    'Score': 0.44011242193559297,
#    'Rank': 48,
#    'Outlook': 'Bright',
#    'AnnualWages': 121610.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Nurse Practitioners',
#    'EduCode': 2.0},
#   {'OnetCode': '39-2021.00',
#    'Score': 0.438379562405452,
#    'Rank': 49,
#    'Outlook': 'Bright',
#    'AnnualWages': 29530.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Animal Caretakers',
#    'EduCode': 7.0},
#   {'OnetCode': '29-1223.00',
#    'Score': 0.43775176513501995,
#    'Rank': 50,
#    'Outlook': 'Bright',
#    'AnnualWages': 226880.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Psychiatrists',
#    'EduCode': 2.0},
#   {'OnetCode': '21-1091.00',
#    'Score': 0.43700859424652594,
#    'Rank': 51,
#    'Outlook': 'Bright',
#    'AnnualWages': 59990.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Health Education Specialists',
#    'EduCode': 3.0},
#   {'OnetCode': '25-2023.00',
#    'Score': 0.435592856510945,
#    'Rank': 52,
#    'Outlook': 'Below Average',
#    'AnnualWages': 62630.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Career/Technical Education Teachers, Middle School',
#    'EduCode': 3.0},
#   {'OnetCode': '25-1121.00',
#    'Score': 0.435026711466548,
#    'Rank': 53,
#    'Outlook': 'Bright',
#    'AnnualWages': 77280.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Art, Drama, and Music Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '25-2032.00',
#    'Score': 0.43408161006564,
#    'Rank': 54,
#    'Outlook': 'Below Average',
#    'AnnualWages': 62500.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Career/Technical Education Teachers, Secondary School',
#    'EduCode': 3.0},
#   {'OnetCode': '29-2035.00',
#    'Score': 0.43142455984840006,
#    'Rank': 55,
#    'Outlook': 'Average',
#    'AnnualWages': 80090.0,
#    'TypicalEducation': "Associate's degree",
#    'OccupationTitle': 'Magnetic Resonance Imaging Technologists',
#    'EduCode': 4.0},
#   {'OnetCode': '29-1123.00',
#    'Score': 0.430859911460427,
#    'Rank': 56,
#    'Outlook': 'Bright',
#    'AnnualWages': 97720.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Physical Therapists',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1224.00',
#    'Score': 0.43050972308874996,
#    'Rank': 57,
#    'Outlook': 'Average',
#    'AnnualWages': 999999.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Radiologists',
#    'EduCode': 2.0},
#   {'OnetCode': '19-3093.00',
#    'Score': 0.429143980756668,
#    'Rank': 58,
#    'Outlook': 'Average',
#    'AnnualWages': 64540.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Historians',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1041.00',
#    'Score': 0.428909717314701,
#    'Rank': 59,
#    'Outlook': 'Bright',
#    'AnnualWages': 125590.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Optometrists',
#    'EduCode': 2.0},
#   {'OnetCode': '25-1051.00',
#    'Score': 0.42845218879081404,
#    'Rank': 60,
#    'Outlook': 'Average',
#    'AnnualWages': 97770.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Atmospheric, Earth, Marine, and Space Sciences Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '33-3041.00',
#    'Score': 0.425904455184608,
#    'Rank': 61,
#    'Outlook': 'Below Average',
#    'AnnualWages': 41570.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Parking Enforcement Workers',
#    'EduCode': 7.0},
#   {'OnetCode': '25-1042.00',
#    'Score': 0.424602416899951,
#    'Rank': 62,
#    'Outlook': 'Bright',
#    'AnnualWages': 81650.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Biological Science Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '25-1123.00',
#    'Score': 0.423918128889348,
#    'Rank': 63,
#    'Outlook': 'Average',
#    'AnnualWages': 74280.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'English Language and Literature Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1131.00',
#    'Score': 0.42280331803842097,
#    'Rank': 64,
#    'Outlook': 'Bright',
#    'AnnualWages': 103260.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Veterinarians',
#    'EduCode': 2.0},
#   {'OnetCode': '43-6013.00',
#    'Score': 0.417252874721427,
#    'Rank': 65,
#    'Outlook': 'Bright',
#    'AnnualWages': 38500.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Medical Secretaries and Administrative Assistants',
#    'EduCode': 7.0},
#   {'OnetCode': '29-1141.03',
#    'Score': 0.416736089358324,
#    'Rank': 66,
#    'Outlook': 'Bright',
#    'AnnualWages': 81220.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Critical Care Nurses',
#    'EduCode': 3.0},
#   {'OnetCode': '21-1094.00',
#    'Score': 0.416318796010853,
#    'Rank': 67,
#    'Outlook': 'Bright',
#    'AnnualWages': 46190.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Community Health Workers',
#    'EduCode': 7.0},
#   {'OnetCode': '21-1022.00',
#    'Score': 0.415331318596535,
#    'Rank': 68,
#    'Outlook': 'Bright',
#    'AnnualWages': 60280.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Healthcare Social Workers',
#    'EduCode': 2.0},
#   {'OnetCode': '25-2058.00',
#    'Score': 0.415004287939102,
#    'Rank': 69,
#    'Outlook': 'Average',
#    'AnnualWages': 63560.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Special Education Teachers, Secondary School',
#    'EduCode': 3.0},
#   {'OnetCode': '39-9041.00',
#    'Score': 0.413843150384201,
#    'Rank': 70,
#    'Outlook': 'Bright',
#    'AnnualWages': 35720.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Residential Advisors',
#    'EduCode': 7.0},
#   {'OnetCode': '29-1211.00',
#    'Score': 0.410843352164265,
#    'Rank': 71,
#    'Outlook': 'Below Average',
#    'AnnualWages': 999999.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Anesthesiologists',
#    'EduCode': 2.0},
#   {'OnetCode': '43-4071.00',
#    'Score': 0.409666293478265,
#    'Rank': 72,
#    'Outlook': 'Below Average',
#    'AnnualWages': 37290.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'File Clerks',
#    'EduCode': 7.0},
#   {'OnetCode': '29-1229.05',
#    'Score': 0.409664066787757,
#    'Rank': 73,
#    'Outlook': 'Below Average',
#    'AnnualWages': 223410.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Preventive Medicine Physicians',
#    'EduCode': 2.0},
#   {'OnetCode': '25-3041.00',
#    'Score': 0.4095849848962,
#    'Rank': 74,
#    'Outlook': 'Bright',
#    'AnnualWages': 36680.0,
#    'TypicalEducation': 'Some college, no degree',
#    'OccupationTitle': 'Tutors',
#    'EduCode': 6.0},
#   {'OnetCode': '19-3034.00',
#    'Score': 0.40957528537564,
#    'Rank': 75,
#    'Outlook': 'Average',
#    'AnnualWages': 81500.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'School Psychologists',
#    'EduCode': 2.0},
#   {'OnetCode': '19-3033.00',
#    'Score': 0.407751219697256,
#    'Rank': 76,
#    'Outlook': 'Bright',
#    'AnnualWages': 90130.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Clinical and Counseling Psychologists',
#    'EduCode': 2.0},
#   {'OnetCode': '31-2011.00',
#    'Score': 0.406985807934673,
#    'Rank': 77,
#    'Outlook': 'Bright',
#    'AnnualWages': 64250.0,
#    'TypicalEducation': "Associate's degree",
#    'OccupationTitle': 'Occupational Therapy Assistants',
#    'EduCode': 4.0},
#   {'OnetCode': '29-1213.00',
#    'Score': 0.40590627001808605,
#    'Rank': 78,
#    'Outlook': 'Below Average',
#    'AnnualWages': 999999.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Dermatologists',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1151.00',
#    'Score': 0.40354523166581996,
#    'Rank': 79,
#    'Outlook': 'Bright',
#    'AnnualWages': 203090.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Nurse Anesthetists',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1081.00',
#    'Score': 0.403499922333499,
#    'Rank': 80,
#    'Outlook': 'Below Average',
#    'AnnualWages': 148720.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Podiatrists',
#    'EduCode': 2.0},
#   {'OnetCode': '25-1043.00',
#    'Score': 0.400586480003306,
#    'Rank': 81,
#    'Outlook': 'Bright',
#    'AnnualWages': 96500.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Forestry and Conservation Science Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '33-3051.04',
#    'Score': 0.40032483062670204,
#    'Rank': 82,
#    'Outlook': 'Below Average',
#    'AnnualWages': 65790.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Customs and Border Protection Officers',
#    'EduCode': 7.0},
#   {'OnetCode': '19-5011.00',
#    'Score': 0.39991135903527103,
#    'Rank': 83,
#    'Outlook': 'Average',
#    'AnnualWages': 78570.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Occupational Health and Safety Specialists',
#    'EduCode': 3.0},
#   {'OnetCode': '29-2099.05',
#    'Score': 0.39937969034994203,
#    'Rank': 84,
#    'Outlook': 'Average',
#    'AnnualWages': 44990.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Ophthalmic Medical Technologists',
#    'EduCode': 6.0},
#   {'OnetCode': '11-9171.00',
#    'Score': 0.399068222618321,
#    'Rank': 85,
#    'Outlook': 'Average',
#    'AnnualWages': 72110.0,
#    'TypicalEducation': "Associate's degree",
#    'OccupationTitle': 'Funeral Home Managers',
#    'EduCode': 4.0},
#   {'OnetCode': '47-2141.00',
#    'Score': 0.39864664342983297,
#    'Rank': 86,
#    'Outlook': 'Below Average',
#    'AnnualWages': 46090.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Painters, Construction and Maintenance',
#    'EduCode': 9.0},
#   {'OnetCode': '31-9092.00',
#    'Score': 0.396346500631606,
#    'Rank': 87,
#    'Outlook': 'Bright',
#    'AnnualWages': 38270.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Medical Assistants',
#    'EduCode': 6.0},
#   {'OnetCode': '33-3052.00',
#    'Score': 0.395663073220395,
#    'Rank': 88,
#    'Outlook': 'Below Average',
#    'AnnualWages': 69150.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Transit and Railroad Police',
#    'EduCode': 7.0},
#   {'OnetCode': '29-9091.00',
#    'Score': 0.39498478979796,
#    'Rank': 89,
#    'Outlook': 'Bright',
#    'AnnualWages': 53840.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Athletic Trainers',
#    'EduCode': 2.0},
#   {'OnetCode': '13-1199.05',
#    'Score': 0.394905167789361,
#    'Rank': 90,
#    'Outlook': 'Bright',
#    'AnnualWages': 75990.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Sustainability Specialists',
#    'EduCode': 3.0},
#   {'OnetCode': '35-1011.00',
#    'Score': 0.393109593033306,
#    'Rank': 91,
#    'Outlook': 'Bright',
#    'AnnualWages': 56520.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Chefs and Head Cooks',
#    'EduCode': 7.0},
#   {'OnetCode': '21-1011.00',
#    'Score': 0.392235937495668,
#    'Rank': 92,
#    'Outlook': 'Bright',
#    'AnnualWages': 49710.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Substance Abuse and Behavioral Disorder Counselors',
#    'EduCode': 3.0},
#   {'OnetCode': '27-3023.00',
#    'Score': 0.391753442815369,
#    'Rank': 93,
#    'Outlook': 'Below Average',
#    'AnnualWages': 55960.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'News Analysts, Reporters, and Journalists',
#    'EduCode': 3.0},
#   {'OnetCode': '25-1031.00',
#    'Score': 0.391662973702556,
#    'Rank': 94,
#    'Outlook': 'Bright',
#    'AnnualWages': 93220.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Architecture Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '25-1111.00',
#    'Score': 0.389781967858529,
#    'Rank': 95,
#    'Outlook': 'Bright',
#    'AnnualWages': 64990.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Criminal Justice and Law Enforcement Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '25-9021.00',
#    'Score': 0.389562070131471,
#    'Rank': 96,
#    'Outlook': 'Below Average',
#    'AnnualWages': 53450.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Farm and Home Management Educators',
#    'EduCode': 2.0},
#   {'OnetCode': '33-9011.00',
#    'Score': 0.388219214992589,
#    'Rank': 97,
#    'Outlook': 'Average',
#    'AnnualWages': 39320.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Animal Control Workers',
#    'EduCode': 7.0},
#   {'OnetCode': '29-1128.00',
#    'Score': 0.386988354454665,
#    'Rank': 98,
#    'Outlook': 'Bright',
#    'AnnualWages': 51350.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Exercise Physiologists',
#    'EduCode': 3.0},
#   {'OnetCode': '21-1021.00',
#    'Score': 0.385728594796136,
#    'Rank': 99,
#    'Outlook': 'Bright',
#    'AnnualWages': 50820.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Child, Family, and School Social Workers',
#    'EduCode': 3.0},
#   {'OnetCode': '25-1067.00',
#    'Score': 0.385628335821971,
#    'Rank': 100,
#    'Outlook': 'Bright',
#    'AnnualWages': 78970.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Sociology Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1215.00',
#    'Score': 0.38523367101234096,
#    'Rank': 101,
#    'Outlook': 'Below Average',
#    'AnnualWages': 211300.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Family Medicine Physicians',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1141.01',
#    'Score': 0.383370135917543,
#    'Rank': 102,
#    'Outlook': 'Bright',
#    'AnnualWages': 81220.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Acute Care Nurses',
#    'EduCode': 3.0},
#   {'OnetCode': '25-2057.00',
#    'Score': 0.38276120164139604,
#    'Rank': 103,
#    'Outlook': 'Average',
#    'AnnualWages': 62990.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Special Education Teachers, Middle School',
#    'EduCode': 3.0},
#   {'OnetCode': '17-1012.00',
#    'Score': 0.380748896526385,
#    'Rank': 104,
#    'Outlook': 'Below Average',
#    'AnnualWages': 73210.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Landscape Architects',
#    'EduCode': 3.0},
#   {'OnetCode': '25-1192.00',
#    'Score': 0.380619784394277,
#    'Rank': 105,
#    'Outlook': 'Average',
#    'AnnualWages': 76440.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Family and Consumer Sciences Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '33-2022.00',
#    'Score': 0.37926537601816995,
#    'Rank': 106,
#    'Outlook': 'Bright',
#    'AnnualWages': 48110.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Forest Fire Inspectors and Prevention Specialists',
#    'EduCode': 7.0},
#   {'OnetCode': '29-2099.08',
#    'Score': 0.378867652938406,
#    'Rank': 107,
#    'Outlook': 'Average',
#    'AnnualWages': 44990.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Patient Representatives',
#    'EduCode': 6.0},
#   {'OnetCode': '39-4021.00',
#    'Score': 0.378706636905142,
#    'Rank': 108,
#    'Outlook': 'Bright',
#    'AnnualWages': 31160.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Funeral Attendants',
#    'EduCode': 7.0},
#   {'OnetCode': '25-2059.01',
#    'Score': 0.37843274048136,
#    'Rank': 109,
#    'Outlook': 'Average',
#    'AnnualWages': 63950.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Adapted Physical Education Specialists',
#    'EduCode': 3.0},
#   {'OnetCode': '31-2012.00',
#    'Score': 0.37442066015339104,
#    'Rank': 110,
#    'Outlook': 'Bright',
#    'AnnualWages': 37060.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Occupational Therapy Aides',
#    'EduCode': 7.0},
#   {'OnetCode': '11-1011.03',
#    'Score': 0.374413204796032,
#    'Rank': 111,
#    'Outlook': 'Below Average',
#    'AnnualWages': 189520.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Chief Sustainability Officers',
#    'EduCode': 3.0},
#   {'OnetCode': '35-3041.00',
#    'Score': 0.37436173092748304,
#    'Rank': 112,
#    'Outlook': 'Average',
#    'AnnualWages': 30300.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Food Servers, Nonrestaurant',
#    'EduCode': 9.0},
#   {'OnetCode': '25-1113.00',
#    'Score': 0.373617846541146,
#    'Rank': 113,
#    'Outlook': 'Bright',
#    'AnnualWages': 66510.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Social Work Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '47-2142.00',
#    'Score': 0.370722827099117,
#    'Rank': 114,
#    'Outlook': 'Below Average',
#    'AnnualWages': 44930.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Paperhangers',
#    'EduCode': 9.0},
#   {'OnetCode': '33-3051.00',
#    'Score': 0.37021636967147004,
#    'Rank': 115,
#    'Outlook': 'Below Average',
#    'AnnualWages': 65790.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': "Police and Sheriff's Patrol Officers",
#    'EduCode': 7.0},
#   {'OnetCode': '29-1181.00',
#    'Score': 0.37005660164672105,
#    'Rank': 116,
#    'Outlook': 'Bright',
#    'AnnualWages': 82680.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Audiologists',
#    'EduCode': 2.0},
#   {'OnetCode': '25-1122.00',
#    'Score': 0.36942590107687395,
#    'Rank': 117,
#    'Outlook': 'Average',
#    'AnnualWages': 76250.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Communications Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '21-2011.00',
#    'Score': 0.368121245527409,
#    'Rank': 118,
#    'Outlook': 'Average',
#    'AnnualWages': 55550.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Clergy',
#    'EduCode': 3.0},
#   {'OnetCode': '39-3093.00',
#    'Score': 0.367647060660157,
#    'Rank': 119,
#    'Outlook': 'Bright',
#    'AnnualWages': 30210.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Locker Room, Coatroom, and Dressing Room Attendants',
#    'EduCode': 7.0},
#   {'OnetCode': '11-9179.01',
#    'Score': 0.367498529316694,
#    'Rank': 120,
#    'Outlook': 'Bright',
#    'AnnualWages': 56090.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Fitness and Wellness Coordinators',
#    'EduCode': 7.0},
#   {'OnetCode': '17-2111.00',
#    'Score': 0.366930911875324,
#    'Rank': 121,
#    'Outlook': 'Average',
#    'AnnualWages': 100660.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Health and Safety Engineers, Except Mining Safety Engineers and Inspectors',
#    'EduCode': 3.0},
#   {'OnetCode': '27-2021.00',
#    'Score': 0.366861266722169,
#    'Rank': 122,
#    'Outlook': 'Bright',
#    'AnnualWages': 94270.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Athletes and Sports Competitors',
#    'EduCode': 9.0},
#   {'OnetCode': '33-3021.00',
#    'Score': 0.366199006306096,
#    'Rank': 123,
#    'Outlook': 'Below Average',
#    'AnnualWages': 86280.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Detectives and Criminal Investigators',
#    'EduCode': 7.0},
#   {'OnetCode': '29-1241.00',
#    'Score': 0.36463146705842403,
#    'Rank': 124,
#    'Outlook': 'Average',
#    'AnnualWages': 219810.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Ophthalmologists, Except Pediatric',
#    'EduCode': 2.0},
#   {'OnetCode': '25-1081.00',
#    'Score': 0.36444925838361103,
#    'Rank': 125,
#    'Outlook': 'Bright',
#    'AnnualWages': 66930.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Education Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1021.00',
#    'Score': 0.364117679311525,
#    'Rank': 126,
#    'Outlook': 'Average',
#    'AnnualWages': 155040.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Dentists, General',
#    'EduCode': 2.0},
#   {'OnetCode': '19-3092.00',
#    'Score': 0.36359208756804695,
#    'Rank': 127,
#    'Outlook': 'Below Average',
#    'AnnualWages': 88900.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Geographers',
#    'EduCode': 3.0},
#   {'OnetCode': '11-9031.00',
#    'Score': 0.363003219697315,
#    'Rank': 128,
#    'Outlook': 'Bright',
#    'AnnualWages': 49690.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Education and Childcare Administrators, Preschool and Daycare',
#    'EduCode': 3.0},
#   {'OnetCode': '43-4061.00',
#    'Score': 0.362146148165004,
#    'Rank': 129,
#    'Outlook': 'Below Average',
#    'AnnualWages': 49230.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Eligibility Interviewers, Government Programs',
#    'EduCode': 7.0},
#   {'OnetCode': '39-2011.00',
#    'Score': 0.360723933858692,
#    'Rank': 130,
#    'Outlook': 'Bright',
#    'AnnualWages': 35620.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Animal Trainers',
#    'EduCode': 7.0},
#   {'OnetCode': '21-1015.00',
#    'Score': 0.357516514492597,
#    'Rank': 131,
#    'Outlook': 'Bright',
#    'AnnualWages': 39990.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Rehabilitation Counselors',
#    'EduCode': 2.0},
#   {'OnetCode': '39-7011.00',
#    'Score': 0.357239224918264,
#    'Rank': 132,
#    'Outlook': 'Bright',
#    'AnnualWages': 34440.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Tour Guides and Escorts',
#    'EduCode': 7.0},
#   {'OnetCode': '29-2057.00',
#    'Score': 0.357058678296984,
#    'Rank': 133,
#    'Outlook': 'Bright',
#    'AnnualWages': 38860.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Ophthalmic Medical Technicians',
#    'EduCode': 6.0},
#   {'OnetCode': '51-9051.00',
#    'Score': 0.355659491886442,
#    'Rank': 134,
#    'Outlook': 'Below Average',
#    'AnnualWages': 44530.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Furnace, Kiln, Oven, Drier, and Kettle Operators and Tenders',
#    'EduCode': 7.0},
#   {'OnetCode': '29-2092.00',
#    'Score': 0.35544796749975005,
#    'Rank': 135,
#    'Outlook': 'Bright',
#    'AnnualWages': 59020.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Hearing Aid Specialists',
#    'EduCode': 7.0},
#   {'OnetCode': '25-1052.00',
#    'Score': 0.35462128769989,
#    'Rank': 136,
#    'Outlook': 'Bright',
#    'AnnualWages': 80720.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Chemistry Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '27-3043.05',
#    'Score': 0.351926900493188,
#    'Rank': 137,
#    'Outlook': 'Average',
#    'AnnualWages': 73150.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Poets, Lyricists and Creative Writers',
#    'EduCode': 3.0},
#   {'OnetCode': '19-1031.03',
#    'Score': 0.35145193213451703,
#    'Rank': 138,
#    'Outlook': 'Below Average',
#    'AnnualWages': 64460.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Park Naturalists',
#    'EduCode': 3.0},
#   {'OnetCode': '25-1194.00',
#    'Score': 0.351096638636456,
#    'Rank': 139,
#    'Outlook': 'Below Average',
#    'AnnualWages': 59840.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Career/Technical Education Teachers, Postsecondary',
#    'EduCode': 3.0},
#   {'OnetCode': '29-9093.00',
#    'Score': 0.35094138250254203,
#    'Rank': 140,
#    'Outlook': 'Average',
#    'AnnualWages': 57290.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Surgical Assistants',
#    'EduCode': 6.0},
#   {'OnetCode': '31-9096.00',
#    'Score': 0.350558145871337,
#    'Rank': 141,
#    'Outlook': 'Bright',
#    'AnnualWages': 34740.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Veterinary Assistants and Laboratory Animal Caretakers',
#    'EduCode': 7.0},
#   {'OnetCode': '29-2051.00',
#    'Score': 0.34917416423070097,
#    'Rank': 142,
#    'Outlook': 'Average',
#    'AnnualWages': 33960.0,
#    'TypicalEducation': "Associate's degree",
#    'OccupationTitle': 'Dietetic Technicians',
#    'EduCode': 4.0},
#   {'OnetCode': '29-2061.00',
#    'Score': 0.349020919633883,
#    'Rank': 143,
#    'Outlook': 'Average',
#    'AnnualWages': 54620.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Licensed Practical and Licensed Vocational Nurses',
#    'EduCode': 6.0},
#   {'OnetCode': '29-1299.02',
#    'Score': 0.347971124217931,
#    'Rank': 144,
#    'Outlook': 'Below Average',
#    'AnnualWages': 106230.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Orthoptists',
#    'EduCode': 2.0},
#   {'OnetCode': '53-3011.00',
#    'Score': 0.347703569039893,
#    'Rank': 145,
#    'Outlook': 'Below Average',
#    'AnnualWages': 30380.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Ambulance Drivers and Attendants, Except Emergency Medical Technicians',
#    'EduCode': 7.0},
#   {'OnetCode': '25-2021.00',
#    'Score': 0.34674057548964704,
#    'Rank': 146,
#    'Outlook': 'Bright',
#    'AnnualWages': 61690.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Elementary School Teachers, Except Special Education',
#    'EduCode': 3.0},
#   {'OnetCode': '19-4012.00',
#    'Score': 0.346432143524055,
#    'Rank': 147,
#    'Outlook': 'Bright',
#    'AnnualWages': 41760.0,
#    'TypicalEducation': "Associate's degree",
#    'OccupationTitle': 'Agricultural Technicians',
#    'EduCode': 4.0},
#   {'OnetCode': '25-1082.00',
#    'Score': 0.344111244201267,
#    'Rank': 148,
#    'Outlook': 'Bright',
#    'AnnualWages': 76370.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Library Science Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '21-2021.00',
#    'Score': 0.343852502511148,
#    'Rank': 149,
#    'Outlook': 'Average',
#    'AnnualWages': 49380.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Directors, Religious Activities and Education',
#    'EduCode': 3.0},
#   {'OnetCode': '33-1011.00',
#    'Score': 0.34334444964192395,
#    'Rank': 150,
#    'Outlook': 'Below Average',
#    'AnnualWages': 63310.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'First-Line Supervisors of Correctional Officers',
#    'EduCode': 7.0}],
#  'EduClassList': [{'EduCode': 2.0,
#    'EduTitle': "Master's degree or higher",
#    'Count': 62},
#   {'EduCode': 3.0, 'EduTitle': "Bachelor's degree", 'Count': 34},
#   {'EduCode': 7.0,
#    'EduTitle': 'High school diploma or equivalent',
#    'Count': 29},
#   {'EduCode': 6.0, 'EduTitle': 'Some college', 'Count': 12},
#   {'EduCode': 9.0, 'EduTitle': 'Some high school', 'Count': 7},
#   {'EduCode': 4.0, 'EduTitle': "Associate's degree", 'Count': 6}],
#  'RecordCount': 150,
#  'FilterValue': 0}

# %% [markdown]
# #### 2. Send API GET request using custom user answers

# %% [markdown]
# To submit our own request with our own survey answers, we need to imitate the example request we just sent:

# %%
with open(os.path.join("data", "skills-submit-api", "example-request.json"), "r") as file:
  example_request = json.load(file)

example_request
# Out:
# {'SKAValueList': [{'ElementId': '2.C.1.a', 'DataValue': '3.295'},
#   {'ElementId': '2.C.4.d', 'DataValue': '3.43'},
#   {'ElementId': '2.C.3.d', 'DataValue': '3.1'},
#   {'ElementId': '2.C.4.c', 'DataValue': '3.33'},
#   {'ElementId': '2.C.1.b', 'DataValue': '3.295'},
#   {'ElementId': '2.B.2.i', 'DataValue': '3.31'},
#   {'ElementId': '2.C.3.a', 'DataValue': '3.41'},
#   {'ElementId': '2.C.1.e', 'DataValue': '3.23'},
#   {'ElementId': '2.C.1.c', 'DataValue': '3.175'},
#   {'ElementId': '2.C.6', 'DataValue': '3.615'},
#   {'ElementId': '2.B.3.j', 'DataValue': '2.375'},
#   {'ElementId': '2.C.7.c', 'DataValue': '3.41'},
#   {'ElementId': '2.C.7.b', 'DataValue': '3.315'},
#   {'ElementId': '1.A.3.c.3', 'DataValue': '2.94'},
#   {'ElementId': '2.B.1.e', 'DataValue': '2.44'},
#   {'ElementId': '2.B.5.b', 'DataValue': '2.75'},
#   {'ElementId': '2.B.5.d', 'DataValue': '2.69'},
#   {'ElementId': '2.A.1.e', 'DataValue': '3.06'},
#   {'ElementId': '2.C.3.e', 'DataValue': '3.425'},
#   {'ElementId': '2.C.5.a', 'DataValue': '3.385'},
#   {'ElementId': '1.A.1.d.1', 'DataValue': '2.19'},
#   {'ElementId': '2.A.2.d', 'DataValue': '3.69'},
#   {'ElementId': '2.B.1.d', 'DataValue': '2.915'},
#   {'ElementId': '2.B.3.g', 'DataValue': '2.44'},
#   {'ElementId': '2.B.3.a', 'DataValue': '2.5'},
#   {'ElementId': '2.C.1.f', 'DataValue': '3.23'},
#   {'ElementId': '2.C.2.a', 'DataValue': '2.83'},
#   {'ElementId': '2.B.3.e', 'DataValue': '2.375'},
#   {'ElementId': '2.C.4.e', 'DataValue': '3.525'},
#   {'ElementId': '2.C.8.a', 'DataValue': '2.775'},
#   {'ElementId': '2.B.3.m', 'DataValue': '2.25'},
#   {'ElementId': '2.B.3.l', 'DataValue': '2.125'},
#   {'ElementId': '2.C.1.d', 'DataValue': '3.025'},
#   {'ElementId': '2.A.1.f', 'DataValue': '2.94'},
#   {'ElementId': '2.B.1.f', 'DataValue': '2.64'},
#   {'ElementId': '2.C.4.f', 'DataValue': '3.345'},
#   {'ElementId': '2.A.1.d', 'DataValue': '3.565'},
#   {'ElementId': '2.B.4.g', 'DataValue': '2.69'},
#   {'ElementId': '2.C.9.a', 'DataValue': '3.02'},
#   {'ElementId': '2.C.5.b', 'DataValue': '3.46'}]}

# %% [markdown]
# * `ElementId` - Question identifier (`data-label` attribute in the HTML). Inspected the page source to see which question number each corresponds to (unfortunately aren't all given in order in this example)
# * `DataValue`- Beginner, Basic, Skilled, Advanced, Expert. The values which correspond to these ratings change from question to question because they are the unique id tags for the radio button elements in the webpage.
#
# Each question is listed with a unique identifier that bears no discernible relation to the question number, and each answer level (`DataPoint20`, `DataPoint35`, ... `DataPoint80`) for each question has a globally unique answer format (such that question 37 could be `2.C.7.b` and "Basic" answer could be `3.315`, but question 14 might be `1.A.3.c.3` and "Basic" answer for that could be `2.94`). The questions in the example request above aren't even in order, so we can't translate human-readable question and answers 1-40 based on that assumption.

# %%
# ## Trying to get questions from HTML page -- Get Skills API endpoint is easier.  
# import requests 
# from bs4 import BeautifulSoup
# url = "https://www.careeronestop.org/Toolkit/Skills/skills-matcher-questions.aspx"

# headers = {}

# response = requests.get(url)
# soup = BeautifulSoup(response.content, 'html.parser')
# soup # Gives 403 Error. Note this is not a request to their API -- I'm just trying to get the survey_questions_questions page's HTML to get the ElementId's and DataValues 

# # Copy-pasted HTML table from inspect element 
# with open("divtableskills.html", "r", encoding="utf-8") as file:
#   skill_table = file.read()

# soup = BeautifulSoup(skill_table, 'html.parser')
# soup # Works, but a bit difficult to extract relevant information (questions are not in order)

# %% [markdown]
# The [Get Skills](https://api.careeronestop.org/api-explorer/home/index/SkillsMatcher_GetSkills) API provides the survey questions in JSON (in correct order) with information needed to format our own custom requests:

# %%
response = requests.get(url, headers=headers)
response = response.json()
response
# Out:
# {'Skills': [{'ElementId': '2.C.1.a',
#    'ElementName': 'Administration and Management',
#    'DataPoint20': 1.534,
#    'DataPoint35': 2.4145,
#    'DataPoint50': 3.295,
#    'DataPoint65': 4.1755,
#    'DataPoint80': 5.056,
#    'AnchorFirst': 'Complete a timesheet',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Monitor project progress to complete it on time',
#    'AnchorFourth': '',
#    'AnchorLast': 'Manage a $10m company',
#    'Question': 'How much do you know about business planning and leadership?',
#    'EasyReadDescription': 'Knowledge of business and management principles involved in strategic planning, resource allocation, human resources modeling, leadership technique, production methods, and coordination of people and resources.'},
#   {'ElementId': '2.C.4.d',
#    'ElementName': 'Biology',
#    'DataPoint20': 1.372,
#    'DataPoint35': 2.401,
#    'DataPoint50': 3.43,
#    'DataPoint65': 4.459,
#    'DataPoint80': 5.488,
#    'AnchorFirst': 'Care for a pet',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Investigate effects of pollution on plants',
#    'AnchorFourth': '',
#    'AnchorLast': 'Identify a new virus',
#    'Question': 'How much do you know about plant, animal and cell functions?',
#    'EasyReadDescription': 'Knowledge of plant and animal organisms, their tissues, cells, functions, interdependencies, and interactions with each other and the environment.'},
#   {'ElementId': '1.A.3.c.3',
#    'ElementName': 'Body Coordination',
#    'DataPoint20': 1.176,
#    'DataPoint35': 2.058,
#    'DataPoint50': 2.94,
#    'DataPoint65': 3.822,
#    'DataPoint80': 4.704,
#    'AnchorFirst': 'Get in and out of a truck',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Swim one pool  length, or play a ball sport',
#    'AnchorFourth': '',
#    'AnchorLast': 'Perform ballet choreography',
#    'Question': 'How well can you coordinate moving your arms, legs, and torso together?',
#    'EasyReadDescription': 'Moving your arms, legs, and mid-section together while your whole body is moving.'},
#   {'ElementId': '2.C.3.d',
#    'ElementName': 'Building and Construction',
#    'DataPoint20': 1.24,
#    'DataPoint35': 2.17,
#    'DataPoint50': 3.1,
#    'DataPoint65': 4.03,
#    'DataPoint80': 4.96,
#    'AnchorFirst': 'Hang a picture',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Fix a plumbing leak in ceiling',
#    'AnchorFourth': '',
#    'AnchorLast': 'Build a high-rise',
#    'Question': 'How much do you know about construction materials, methods, and tools?',
#    'EasyReadDescription': 'Knowledge of materials, methods, and the tools involved in the construction or repair of houses, buildings, or other structures such as highways and roads.'},
#   {'ElementId': '2.C.4.c',
#    'ElementName': 'Chemistry',
#    'DataPoint20': 1.332,
#    'DataPoint35': 2.331,
#    'DataPoint50': 3.33,
#    'DataPoint65': 4.329,
#    'DataPoint80': 5.328,
#    'AnchorFirst': 'Use a household chemical safely',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Use proper chlorine concentration to purify water source',
#    'AnchorFourth': '',
#    'AnchorLast': 'Develop a formula for a safe cleaner',
#    'Question': 'How well do you know chemistry?',
#    'EasyReadDescription': 'Knowledge of the chemical composition, structure, and properties of substances and of the chemical processes and transformations that they undergo. This includes uses of chemicals and their interactions, danger signs, production techniques, and disposal methods.'},
#   {'ElementId': '2.C.1.b',
#    'ElementName': 'Clerical',
#    'DataPoint20': 1.366,
#    'DataPoint35': 2.3305,
#    'DataPoint50': 3.295,
#    'DataPoint65': 4.2595,
#    'DataPoint80': 5.224,
#    'AnchorFirst': 'File forms',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Type 30 words per minute',
#    'AnchorFourth': '',
#    'AnchorLast': 'Design an online office-wide storage system',
#    'Question': 'How much do you know about administrative tasks and processes?',
#    'EasyReadDescription': 'Knowledge of administrative and clerical procedures and systems such as word processing, managing files and records, stenography and transcription, designing forms, and other office procedures and terminology.'},
#   {'ElementId': '2.B.2.i',
#    'ElementName': 'Complex Problem Solving',
#    'DataPoint20': 2.224,
#    'DataPoint35': 2.767,
#    'DataPoint50': 3.31,
#    'DataPoint65': 3.853,
#    'DataPoint80': 4.396,
#    'AnchorFirst': 'Gather tools for a household job',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Redesign a floor plan around new equipment',
#    'AnchorFourth': '',
#    'AnchorLast': 'Develop a local disaster response plan',
#    'Question': 'How good are you at figuring out the best way to solve a problem?',
#    'EasyReadDescription': 'Noticing a problem and figuring out the best way to solve it.'},
#   {'ElementId': '2.C.3.a',
#    'ElementName': 'Computers and Electronics',
#    'DataPoint20': 1.406,
#    'DataPoint35': 2.408,
#    'DataPoint50': 3.41,
#    'DataPoint65': 4.412,
#    'DataPoint80': 5.414,
#    'AnchorFirst': 'Open a program on a computer',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Use a word processor',
#    'AnchorFourth': '',
#    'AnchorLast': 'Create a virus-scanning program',
#    'Question': 'How effective are you at using electronic equipment?',
#    'EasyReadDescription': 'Knowledge of circuit boards, processors, chips, electronic equipment, and computer hardware and software, including applications and programming.'},
#   {'ElementId': '2.C.1.e',
#    'ElementName': 'Customer and Personal Service',
#    'DataPoint20': 1.292,
#    'DataPoint35': 2.261,
#    'DataPoint50': 3.23,
#    'DataPoint65': 4.199,
#    'DataPoint80': 5.168,
#    'AnchorFirst': 'Process a dry-cleaning order',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Supervise 10 children at a day care',
#    'AnchorFourth': '',
#    'AnchorLast': 'Plan customer outreach after data privacy breach',
#    'Question': 'How well do you know how to handle customer needs and resolve service problems?',
#    'EasyReadDescription': 'Knowledge of principles and processes for providing customer and personal services. This includes customer needs assessment, meeting quality standards for services, and evaluation of customer satisfaction.'},
#   {'ElementId': '2.C.1.c',
#    'ElementName': 'Economics and Accounting',
#    'DataPoint20': 1.282,
#    'DataPoint35': 2.2285,
#    'DataPoint50': 3.175,
#    'DataPoint65': 4.1215,
#    'DataPoint80': 5.068,
#    'AnchorFirst': 'Answer billing questions',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Develop an investment plan for clients',
#    'AnchorFourth': '',
#    'AnchorLast': "Oversee a large firm's finances",
#    'Question': 'How well do you know banking and financial systems?',
#    'EasyReadDescription': 'Knowledge of economic and accounting principles and practices, the financial markets, banking and the analysis and reporting of financial data.'},
#   {'ElementId': '2.C.7.c',
#    'ElementName': 'Fine Arts',
#    'DataPoint20': 1.364,
#    'DataPoint35': 2.387,
#    'DataPoint50': 3.41,
#    'DataPoint65': 4.433,
#    'DataPoint80': 5.456,
#    'AnchorFirst': 'Attend a concert',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Play a minor part in a local theater play',
#    'AnchorFourth': '',
#    'AnchorLast': 'Teach the theory of an art form',
#    'Question': 'How well do you know the theory and techniques of an art form such as music, painting, drama, or other?',
#    'EasyReadDescription': 'Knowledge of the theory and techniques required to compose, produce, and perform works of music, dance, visual arts, drama, and sculpture.'},
#   {'ElementId': '2.C.7.b',
#    'ElementName': 'Foreign Language',
#    'DataPoint20': 1.326,
#    'DataPoint35': 2.3205,
#    'DataPoint50': 3.315,
#    'DataPoint65': 4.3095,
#    'DataPoint80': 5.304,
#    'AnchorFirst': 'Say "please" and "thank you"',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Ask directions in a foreign city',
#    'AnchorFourth': '',
#    'AnchorLast': 'Critique a literary book',
#    'Question': 'How well do you know a foreign language?',
#    'EasyReadDescription': 'Knowledge of the structure and content of a foreign (non-English) language including the meaning and spelling of words, rules of composition and grammar, and pronunciation.'},
#   {'ElementId': '2.B.1.f',
#    'ElementName': 'Helping People',
#    'DataPoint20': 1.152,
#    'DataPoint35': 1.896,
#    'DataPoint50': 2.64,
#    'DataPoint65': 3.384,
#    'DataPoint80': 4.128,
#    'AnchorFirst': 'Ask clients if they would like coffee',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Make travel arrangements for customers',
#    'AnchorFourth': '',
#    'AnchorLast': 'Direct relief operations in a disaster area',
#    'Question': 'How good are you at understanding how to help people?',
#    'EasyReadDescription': 'Looking for ways to help people.'},
#   {'ElementId': '2.B.1.e',
#    'ElementName': 'Instructing',
#    'DataPoint20': 0.976,
#    'DataPoint35': 1.708,
#    'DataPoint50': 2.44,
#    'DataPoint65': 3.172,
#    'DataPoint80': 3.904,
#    'AnchorFirst': 'Show someone how to bowl',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Instruct a coworker in how to operate a software program',
#    'AnchorFourth': '',
#    'AnchorLast': 'Demonstrate surgery to interns',
#    'Question': 'How skilled are you at teaching people how to do something?',
#    'EasyReadDescription': 'Teaching people how to do something.'},
#   {'ElementId': '2.B.5.b',
#    'ElementName': 'Management of Financial Resources',
#    'DataPoint20': 1.1,
#    'DataPoint35': 1.925,
#    'DataPoint50': 2.75,
#    'DataPoint65': 3.575,
#    'DataPoint80': 4.4,
#    'AnchorFirst': 'Record office supply purchases',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Prepare and manage a budget for a short-term project',
#    'AnchorFourth': '',
#    'AnchorLast': 'Oversee yearly budgets for a large firm',
#    'Question': 'What level of financial decision-maker are you?',
#    'EasyReadDescription': 'Making spending decisions and keeping track of what is spent.'},
#   {'ElementId': '2.A.1.e',
#    'ElementName': 'Mathematics',
#    'DataPoint20': 1.224,
#    'DataPoint35': 2.142,
#    'DataPoint50': 3.06,
#    'DataPoint65': 3.978,
#    'DataPoint80': 4.896,
#    'AnchorFirst': 'Add two large numbers',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Calculate the square footage of a home',
#    'AnchorFourth': '',
#    'AnchorLast': 'Derive a complex formula',
#    'Question': 'What is your level of math skill?',
#    'EasyReadDescription': 'Using math to solve problems.'},
#   {'ElementId': '2.C.3.e',
#    'ElementName': 'Mechanical',
#    'DataPoint20': 1.37,
#    'DataPoint35': 2.3975,
#    'DataPoint50': 3.425,
#    'DataPoint65': 4.4525,
#    'DataPoint80': 5.48,
#    'AnchorFirst': 'Replace a battery in a smoke detector',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Replace a valve on a steam pipe',
#    'AnchorFourth': '',
#    'AnchorLast': 'Overhaul a jet engine',
#    'Question': 'How well can you design, use, repair, and maintain machines?',
#    'EasyReadDescription': 'Knowledge of machines and tools, including their designs, uses, repair, and maintenance.'},
#   {'ElementId': '2.C.5.a',
#    'ElementName': 'Medicine and Dentistry',
#    'DataPoint20': 1.354,
#    'DataPoint35': 2.3695,
#    'DataPoint50': 3.385,
#    'DataPoint65': 4.4005,
#    'DataPoint80': 5.416,
#    'AnchorFirst': 'Treat a cut',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Fill a tooth cavity',
#    'AnchorFourth': '',
#    'AnchorLast': 'Perform open-heart surgery',
#    'Question': 'How well do you know how to provide health care?',
#    'EasyReadDescription': 'Knowledge of the information and techniques needed to diagnose and treat human injuries, diseases, and deformities. This includes symptoms, treatment alternatives, drug properties and interactions, and preventive health-care measures.'},
#   {'ElementId': '1.A.1.d.1',
#    'ElementName': 'Memorization',
#    'DataPoint20': 0.954,
#    'DataPoint35': 1.572,
#    'DataPoint50': 2.19,
#    'DataPoint65': 2.808,
#    'DataPoint80': 3.426,
#    'AnchorFirst': 'Remember your bus number',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Recite the first names of 5 people you just met',
#    'AnchorFourth': '',
#    'AnchorLast': 'Quickly memorize and recite a complex equation',
#    'Question': 'How good is your memory?',
#    'EasyReadDescription': 'Remembering words, numbers, pictures, or steps.'},
#   {'ElementId': '2.A.2.d',
#    'ElementName': 'Monitoring',
#    'DataPoint20': 2.604,
#    'DataPoint35': 3.147,
#    'DataPoint50': 3.69,
#    'DataPoint65': 4.233,
#    'DataPoint80': 4.776,
#    'AnchorFirst': 'Proofread a letter',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Make adjustments to a meeting to ensure key goals are met',
#    'AnchorFourth': '',
#    'AnchorLast': "Measure and plan to increase a firm's productivity",
#    'Question': 'How well can you assess your or others’ work?',
#    'EasyReadDescription': 'Keeping track of how well people and/or groups are doing in order to make improvements.'},
#   {'ElementId': '2.B.1.d',
#    'ElementName': 'Negotiation',
#    'DataPoint20': 1.664,
#    'DataPoint35': 2.2895,
#    'DataPoint50': 2.915,
#    'DataPoint65': 3.5405,
#    'DataPoint80': 4.166,
#    'AnchorFirst': 'Justify a new work schedule to your manager',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Contract with a wholesaler to sell items at a given cost',
#    'AnchorFourth': '',
#    'AnchorLast': 'Negotiate a foreign treaty as an ambassador',
#    'Question': 'How well do you persuade others to see different points of view or compromise?',
#    'EasyReadDescription': 'Bringing people together to solve differences.'},
#   {'ElementId': '2.B.3.a',
#    'ElementName': 'Operations Analysis',
#    'DataPoint20': 1.0,
#    'DataPoint35': 1.75,
#    'DataPoint50': 2.5,
#    'DataPoint65': 3.25,
#    'DataPoint80': 4.0,
#    'AnchorFirst': 'Select a copy machine for the office',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Suggest software changes to make a system more user friendly',
#    'AnchorFourth': '',
#    'AnchorLast': 'Identify system needs for a new process production plant',
#    'Question': 'How well can you analyze needs and requirements, then make a plan that meets them?',
#    'EasyReadDescription': 'Figuring out what a product or service needs to be able to do.'},
#   {'ElementId': '2.C.1.f',
#    'ElementName': 'Personnel and Human Resources',
#    'DataPoint20': 1.34,
#    'DataPoint35': 2.285,
#    'DataPoint50': 3.23,
#    'DataPoint65': 4.175,
#    'DataPoint80': 5.12,
#    'AnchorFirst': 'Fill out a medical claim form',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Interview applicants for a new position',
#    'AnchorFourth': '',
#    'AnchorLast': 'Design a new HR system for a large firm',
#    'Question': 'How well do you know the principles and procedures for recruiting, hiring, and training employees?',
#    'EasyReadDescription': 'Knowledge of principles and procedures for personnel recruitment, selection, training, compensation and benefits, labor relations and negotiation, and personnel information systems.'},
#   {'ElementId': '2.C.2.a',
#    'ElementName': 'Production and Processing',
#    'DataPoint20': 1.156,
#    'DataPoint35': 1.993,
#    'DataPoint50': 2.83,
#    'DataPoint65': 3.667,
#    'DataPoint80': 4.504,
#    'AnchorFirst': 'Repack a computer in original box',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Supervise an appliance assembly line',
#    'AnchorFourth': '',
#    'AnchorLast': 'Maintain an international distribution center',
#    'Question': 'How well can you oversee manufacturing and distribution processes?',
#    'EasyReadDescription': 'Knowledge of raw materials, production processes, quality control, costs, and other techniques for maximizing the effective manufacture and distribution of goods.'},
#   {'ElementId': '2.B.3.e',
#    'ElementName': 'Programming',
#    'DataPoint20': 0.95,
#    'DataPoint35': 1.6625,
#    'DataPoint50': 2.375,
#    'DataPoint65': 3.0875,
#    'DataPoint80': 3.8,
#    'AnchorFirst': 'Create an Excel spreadsheet',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Write a statistical program to analyze  demographic data',
#    'AnchorFourth': '',
#    'AnchorLast': 'Write a program to analyze data for probability results',
#    'Question': 'How well can you write computer programs?',
#    'EasyReadDescription': 'Writing computer programs.'},
#   {'ElementId': '2.C.4.e',
#    'ElementName': 'Psychology',
#    'DataPoint20': 1.458,
#    'DataPoint35': 2.4915,
#    'DataPoint50': 3.525,
#    'DataPoint65': 4.5585,
#    'DataPoint80': 5.592,
#    'AnchorFirst': 'Monitor kids on a playground',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Understand the impact of addiction on human responses',
#    'AnchorFourth': '',
#    'AnchorLast': 'Treat a person with severe mental illness',
#    'Question': 'How well do you know the methods of research, assessment, and treatment of human behavior?',
#    'EasyReadDescription': 'Knowledge of human behavior and performance; individual differences in ability, personality, and interests; learning and motivation; psychological research methods; and the assessment and treatment of behavioral and affective disorders.'},
#   {'ElementId': '2.C.8.a',
#    'ElementName': 'Public Safety and Security',
#    'DataPoint20': 1.164,
#    'DataPoint35': 1.9695,
#    'DataPoint50': 2.775,
#    'DataPoint65': 3.5805,
#    'DataPoint80': 4.386,
#    'AnchorFirst': 'Follow work safety guidelines',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Inspect a building site for safety violations',
#    'AnchorFourth': '',
#    'AnchorLast': 'Command a military operation',
#    'Question': 'How well do you know the equipment, policies, procedures, and strategies used to promote security operations?',
#    'EasyReadDescription': 'Knowledge of relevant equipment, policies, procedures, and strategies to promote effective local, state, or national security operations for the protection of people, data, property, and institutions.'},
#   {'ElementId': '2.B.3.m',
#    'ElementName': 'Quality Control Analysis',
#    'DataPoint20': 0.9,
#    'DataPoint35': 1.575,
#    'DataPoint50': 2.25,
#    'DataPoint65': 2.925,
#    'DataPoint80': 3.6,
#    'AnchorFirst': 'Compare two ways to make a recipe',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Measure new part requisitions for tolerance to specifications',
#    'AnchorFourth': '',
#    'AnchorLast': 'Plan and run a test for a new computer program',
#    'Question': 'How well can you develop and use testing processes?',
#    'EasyReadDescription': 'Testing how well a product or service works.'},
#   {'ElementId': '2.B.3.l',
#    'ElementName': 'Repairing',
#    'DataPoint20': 0.85,
#    'DataPoint35': 1.4875,
#    'DataPoint50': 2.125,
#    'DataPoint65': 2.7625,
#    'DataPoint80': 3.4,
#    'AnchorFirst': 'Tighten the correct screw to get a door to close properly',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Replace a faulty hydraulic valve',
#    'AnchorFourth': '',
#    'AnchorLast': 'Repair structural damage after an earthquake',
#    'Question': 'How well can you repair machines or systems using the needed tools?',
#    'EasyReadDescription': 'Repairing machines or systems using the right tools.'},
#   {'ElementId': '2.C.1.d',
#    'ElementName': 'Sales and Marketing',
#    'DataPoint20': 1.21,
#    'DataPoint35': 2.1175,
#    'DataPoint50': 3.025,
#    'DataPoint65': 3.9325,
#    'DataPoint80': 4.84,
#    'AnchorFirst': 'Sell cakes at a bake sale',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Call a list of clients to introduce them to a new product line',
#    'AnchorFourth': '',
#    'AnchorLast': 'Develop a marketing plan for a large firm',
#    'Question': 'How well can you perform marketing strategies and tactics?',
#    'EasyReadDescription': 'Knowledge of principles and methods for showing, promoting, and selling products or services. This includes marketing strategy and tactics, product demonstration, sales techniques, and sales control systems.'},
#   {'ElementId': '2.A.1.f',
#    'ElementName': 'Science',
#    'DataPoint20': 1.176,
#    'DataPoint35': 2.058,
#    'DataPoint50': 2.94,
#    'DataPoint65': 3.822,
#    'DataPoint80': 4.704,
#    'AnchorFirst': 'Maintain house plants',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Conduct product tests to ensure safety standards are met',
#    'AnchorFourth': '',
#    'AnchorLast': 'Analyze aerodynamic systems for aircraft design',
#    'Question': 'How well can you use scientific rules and methods to solve problems?',
#    'EasyReadDescription': 'Using scientific rules and strategies to solve problems.'},
#   {'ElementId': '2.C.4.f',
#    'ElementName': 'Sociology and Anthropology',
#    'DataPoint20': 1.338,
#    'DataPoint35': 2.3415,
#    'DataPoint50': 3.345,
#    'DataPoint65': 4.3485,
#    'DataPoint80': 5.352,
#    'AnchorFirst': 'Identify two different cultures',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Write an article about cultural differences',
#    'AnchorFourth': '',
#    'AnchorLast': "Create a new theory of civilization's development",
#    'Question': 'How well do you know the theories of group behavior, societal trends and influences, and human culture?',
#    'EasyReadDescription': 'Knowledge of group behavior and dynamics, societal trends and influences, human migrations, ethnicity, cultures and their history and origins.'},
#   {'ElementId': '2.A.1.d',
#    'ElementName': 'Speaking',
#    'DataPoint20': 2.476,
#    'DataPoint35': 3.0205,
#    'DataPoint50': 3.565,
#    'DataPoint65': 4.1095,
#    'DataPoint80': 4.654,
#    'AnchorFirst': 'Greet customers',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Interview applicants to obtain personal and work history',
#    'AnchorFourth': '',
#    'AnchorLast': 'Argue a legal case before the Supreme Court',
#    'Question': 'How well do you convey information when you speak?',
#    'EasyReadDescription': 'Talking to others.'},
#   {'ElementId': '2.B.4.g',
#    'ElementName': 'Systems Analysis',
#    'DataPoint20': 1.076,
#    'DataPoint35': 1.883,
#    'DataPoint50': 2.69,
#    'DataPoint65': 3.497,
#    'DataPoint80': 4.304,
#    'AnchorFirst': 'Manage work with a missing teammate',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Determine how new equipment will affect production rates',
#    'AnchorFourth': '',
#    'AnchorLast': 'Identify impact of tax changes across industries',
#    'Question': 'How well can you analyze systems?',
#    'EasyReadDescription': 'Figuring out how a system should work and how changes in the future will affect it.'},
#   {'ElementId': '2.C.6',
#    'ElementName': 'Teaching and Course Design',
#    'DataPoint20': 1.632,
#    'DataPoint35': 2.6235,
#    'DataPoint50': 3.615,
#    'DataPoint65': 4.6065,
#    'DataPoint80': 5.598,
#    'AnchorFirst': 'Teach workers how to use a time clock',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Lead a quality improvement seminar',
#    'AnchorFourth': '',
#    'AnchorLast': 'Design a training program for new employees',
#    'Question': 'How well do you know the principles and methods of instruction?',
#    'EasyReadDescription': 'Knowledge of principles and methods for curriculum and training design, teaching and instruction for individuals and groups, and the measurement of training effects.'},
#   {'ElementId': '2.C.9.a',
#    'ElementName': 'Telecommunications',
#    'DataPoint20': 1.208,
#    'DataPoint35': 2.114,
#    'DataPoint50': 3.02,
#    'DataPoint65': 3.926,
#    'DataPoint80': 4.832,
#    'AnchorFirst': 'Use a business phone',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Install a satellite TV dish',
#    'AnchorFourth': '',
#    'AnchorLast': 'Develop a worldwide telecom network',
#    'Question': 'How well do you understand telecom systems?',
#    'EasyReadDescription': 'Knowledge of transmission, broadcasting, switching, control, and operation of telecommunications systems.'},
#   {'ElementId': '2.C.5.b',
#    'ElementName': 'Therapy and Counseling',
#    'DataPoint20': 1.384,
#    'DataPoint35': 2.422,
#    'DataPoint50': 3.46,
#    'DataPoint65': 4.498,
#    'DataPoint80': 5.536,
#    'AnchorFirst': 'Offer sympathy to a stranger',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Provide job counseling to the unemployed',
#    'AnchorFourth': '',
#    'AnchorLast': 'Supervise experienced therapists',
#    'Question': 'How well do you know the principles and methods used in counseling?',
#    'EasyReadDescription': 'Knowledge of principles, methods, and procedures for diagnosis, treatment, and rehabilitation of physical and mental dysfunctions, and for career counseling and guidance.'},
#   {'ElementId': '2.B.5.a',
#    'ElementName': 'Time Management',
#    'DataPoint20': 2.054,
#    'DataPoint35': 2.5595,
#    'DataPoint50': 3.065,
#    'DataPoint65': 3.5705,
#    'DataPoint80': 4.076,
#    'AnchorFirst': 'Keep a monthly appointment calendar',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Allocate staff time to projects for the coming week',
#    'AnchorFourth': '',
#    'AnchorLast': 'Allocate scientists’ time to multiple multi-stage projects',
#    'Question': "How well do you manage your and others' time?",
#    'EasyReadDescription': 'Managing your time and the time of other people.'},
#   {'ElementId': '2.B.3.k',
#    'ElementName': 'Troubleshooting',
#    'DataPoint20': 1.05,
#    'DataPoint35': 1.8375,
#    'DataPoint50': 2.625,
#    'DataPoint65': 3.4125,
#    'DataPoint80': 4.2,
#    'AnchorFirst': 'Identify source of leak on outside of machine',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Identify the circuit causing an electrical system to fail',
#    'AnchorFourth': '',
#    'AnchorLast': 'Oversee code debugging for new operating system',
#    'Question': 'How well can you identify and fix problems in machines or technology?',
#    'EasyReadDescription': 'Figuring out what is causing equipment, machines, wiring, or computer programs to not work.'},
#   {'ElementId': '2.A.1.c',
#    'ElementName': 'Writing',
#    'DataPoint20': 1.624,
#    'DataPoint35': 2.467,
#    'DataPoint50': 3.31,
#    'DataPoint65': 4.153,
#    'DataPoint80': 4.996,
#    'AnchorFirst': 'Take a telephone message',
#    'AnchorSecond': '',
#    'AnchorThrid': 'Write a memo to staff outlining new directives',
#    'AnchorFourth': '',
#    'AnchorLast': 'Write a technical manual',
#    'Question': "How well does your writing effectively communicate to an audience's particular need?",
#    'EasyReadDescription': 'Writing things for co-workers or customers.'}]}

# %%
import json 

# Loading cached copy
with open(os.path.join("data","get-skills-api","response.json"), "r") as file: # previously extracted with API Explorer
  survey_questions = json.load(file)['Skills']

skill_level_map = { 
  "DataPoint20": "Beginner",
  "DataPoint35": "Basic",
  "DataPoint50": "Skilled",
  "DataPoint65": "Advanced",
  "DataPoint80": "Expert"
}

for q in survey_questions: # Translating Skill level ide
  for k,v in skill_level_map.items():
    q[v] = q.pop(k)

with open(os.path.join("data","get-skills-api","response_translated.json"), "w") as file:
  json.dump(survey_questions, file)

# %%
survey_questions
# Out:
# [{'ElementId': '2.C.1.a',
#   'ElementName': 'Administration and Management',
#   'AnchorFirst': 'Complete a timesheet',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Monitor project progress to complete it on time',
#   'AnchorFourth': '',
#   'AnchorLast': 'Manage a $10m company',
#   'Question': 'How much do you know about business planning and leadership?',
#   'EasyReadDescription': 'Knowledge of business and management principles involved in strategic planning, resource allocation, human resources modeling, leadership technique, production methods, and coordination of people and resources.',
#   'Beginner': 1.534,
#   'Basic': 2.4145,
#   'Skilled': 3.295,
#   'Advanced': 4.1755,
#   'Expert': 5.056},
#  {'ElementId': '2.C.4.d',
#   'ElementName': 'Biology',
#   'AnchorFirst': 'Care for a pet',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Investigate effects of pollution on plants',
#   'AnchorFourth': '',
#   'AnchorLast': 'Identify a new virus',
#   'Question': 'How much do you know about plant, animal and cell functions?',
#   'EasyReadDescription': 'Knowledge of plant and animal organisms, their tissues, cells, functions, interdependencies, and interactions with each other and the environment.',
#   'Beginner': 1.372,
#   'Basic': 2.401,
#   'Skilled': 3.43,
#   'Advanced': 4.459,
#   'Expert': 5.488},
#  {'ElementId': '1.A.3.c.3',
#   'ElementName': 'Body Coordination',
#   'AnchorFirst': 'Get in and out of a truck',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Swim one pool  length, or play a ball sport',
#   'AnchorFourth': '',
#   'AnchorLast': 'Perform ballet choreography',
#   'Question': 'How well can you coordinate moving your arms, legs, and torso together?',
#   'EasyReadDescription': 'Moving your arms, legs, and mid-section together while your whole body is moving.',
#   'Beginner': 1.176,
#   'Basic': 2.058,
#   'Skilled': 2.94,
#   'Advanced': 3.822,
#   'Expert': 4.704},
#  {'ElementId': '2.C.3.d',
#   'ElementName': 'Building and Construction',
#   'AnchorFirst': 'Hang a picture',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Fix a plumbing leak in ceiling',
#   'AnchorFourth': '',
#   'AnchorLast': 'Build a high-rise',
#   'Question': 'How much do you know about construction materials, methods, and tools?',
#   'EasyReadDescription': 'Knowledge of materials, methods, and the tools involved in the construction or repair of houses, buildings, or other structures such as highways and roads.',
#   'Beginner': 1.24,
#   'Basic': 2.17,
#   'Skilled': 3.1,
#   'Advanced': 4.03,
#   'Expert': 4.96},
#  {'ElementId': '2.C.4.c',
#   'ElementName': 'Chemistry',
#   'AnchorFirst': 'Use a household chemical safely',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Use proper chlorine concentration to purify water source',
#   'AnchorFourth': '',
#   'AnchorLast': 'Develop a formula for a safe cleaner',
#   'Question': 'How well do you know chemistry?',
#   'EasyReadDescription': 'Knowledge of the chemical composition, structure, and properties of substances and of the chemical processes and transformations that they undergo. This includes uses of chemicals and their interactions, danger signs, production techniques, and disposal methods.',
#   'Beginner': 1.332,
#   'Basic': 2.331,
#   'Skilled': 3.33,
#   'Advanced': 4.329,
#   'Expert': 5.328},
#  {'ElementId': '2.C.1.b',
#   'ElementName': 'Clerical',
#   'AnchorFirst': 'File forms',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Type 30 words per minute',
#   'AnchorFourth': '',
#   'AnchorLast': 'Design an online office-wide storage system',
#   'Question': 'How much do you know about administrative tasks and processes?',
#   'EasyReadDescription': 'Knowledge of administrative and clerical procedures and systems such as word processing, managing files and records, stenography and transcription, designing forms, and other office procedures and terminology.',
#   'Beginner': 1.366,
#   'Basic': 2.3305,
#   'Skilled': 3.295,
#   'Advanced': 4.2595,
#   'Expert': 5.224},
#  {'ElementId': '2.B.2.i',
#   'ElementName': 'Complex Problem Solving',
#   'AnchorFirst': 'Gather tools for a household job',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Redesign a floor plan around new equipment',
#   'AnchorFourth': '',
#   'AnchorLast': 'Develop a local disaster response plan',
#   'Question': 'How good are you at figuring out the best way to solve a problem?',
#   'EasyReadDescription': 'Noticing a problem and figuring out the best way to solve it.',
#   'Beginner': 2.224,
#   'Basic': 2.767,
#   'Skilled': 3.31,
#   'Advanced': 3.853,
#   'Expert': 4.396},
#  {'ElementId': '2.C.3.a',
#   'ElementName': 'Computers and Electronics',
#   'AnchorFirst': 'Open a program on a computer',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Use a word processor',
#   'AnchorFourth': '',
#   'AnchorLast': 'Create a virus-scanning program',
#   'Question': 'How effective are you at using electronic equipment?',
#   'EasyReadDescription': 'Knowledge of circuit boards, processors, chips, electronic equipment, and computer hardware and software, including applications and programming.',
#   'Beginner': 1.406,
#   'Basic': 2.408,
#   'Skilled': 3.41,
#   'Advanced': 4.412,
#   'Expert': 5.414},
#  {'ElementId': '2.C.1.e',
#   'ElementName': 'Customer and Personal Service',
#   'AnchorFirst': 'Process a dry-cleaning order',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Supervise 10 children at a day care',
#   'AnchorFourth': '',
#   'AnchorLast': 'Plan customer outreach after data privacy breach',
#   'Question': 'How well do you know how to handle customer needs and resolve service problems?',
#   'EasyReadDescription': 'Knowledge of principles and processes for providing customer and personal services. This includes customer needs assessment, meeting quality standards for services, and evaluation of customer satisfaction.',
#   'Beginner': 1.292,
#   'Basic': 2.261,
#   'Skilled': 3.23,
#   'Advanced': 4.199,
#   'Expert': 5.168},
#  {'ElementId': '2.C.1.c',
#   'ElementName': 'Economics and Accounting',
#   'AnchorFirst': 'Answer billing questions',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Develop an investment plan for clients',
#   'AnchorFourth': '',
#   'AnchorLast': "Oversee a large firm's finances",
#   'Question': 'How well do you know banking and financial systems?',
#   'EasyReadDescription': 'Knowledge of economic and accounting principles and practices, the financial markets, banking and the analysis and reporting of financial data.',
#   'Beginner': 1.282,
#   'Basic': 2.2285,
#   'Skilled': 3.175,
#   'Advanced': 4.1215,
#   'Expert': 5.068},
#  {'ElementId': '2.C.7.c',
#   'ElementName': 'Fine Arts',
#   'AnchorFirst': 'Attend a concert',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Play a minor part in a local theater play',
#   'AnchorFourth': '',
#   'AnchorLast': 'Teach the theory of an art form',
#   'Question': 'How well do you know the theory and techniques of an art form such as music, painting, drama, or other?',
#   'EasyReadDescription': 'Knowledge of the theory and techniques required to compose, produce, and perform works of music, dance, visual arts, drama, and sculpture.',
#   'Beginner': 1.364,
#   'Basic': 2.387,
#   'Skilled': 3.41,
#   'Advanced': 4.433,
#   'Expert': 5.456},
#  {'ElementId': '2.C.7.b',
#   'ElementName': 'Foreign Language',
#   'AnchorFirst': 'Say "please" and "thank you"',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Ask directions in a foreign city',
#   'AnchorFourth': '',
#   'AnchorLast': 'Critique a literary book',
#   'Question': 'How well do you know a foreign language?',
#   'EasyReadDescription': 'Knowledge of the structure and content of a foreign (non-English) language including the meaning and spelling of words, rules of composition and grammar, and pronunciation.',
#   'Beginner': 1.326,
#   'Basic': 2.3205,
#   'Skilled': 3.315,
#   'Advanced': 4.3095,
#   'Expert': 5.304},
#  {'ElementId': '2.B.1.f',
#   'ElementName': 'Helping People',
#   'AnchorFirst': 'Ask clients if they would like coffee',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Make travel arrangements for customers',
#   'AnchorFourth': '',
#   'AnchorLast': 'Direct relief operations in a disaster area',
#   'Question': 'How good are you at understanding how to help people?',
#   'EasyReadDescription': 'Looking for ways to help people.',
#   'Beginner': 1.152,
#   'Basic': 1.896,
#   'Skilled': 2.64,
#   'Advanced': 3.384,
#   'Expert': 4.128},
#  {'ElementId': '2.B.1.e',
#   'ElementName': 'Instructing',
#   'AnchorFirst': 'Show someone how to bowl',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Instruct a coworker in how to operate a software program',
#   'AnchorFourth': '',
#   'AnchorLast': 'Demonstrate surgery to interns',
#   'Question': 'How skilled are you at teaching people how to do something?',
#   'EasyReadDescription': 'Teaching people how to do something.',
#   'Beginner': 0.976,
#   'Basic': 1.708,
#   'Skilled': 2.44,
#   'Advanced': 3.172,
#   'Expert': 3.904},
#  {'ElementId': '2.B.5.b',
#   'ElementName': 'Management of Financial Resources',
#   'AnchorFirst': 'Record office supply purchases',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Prepare and manage a budget for a short-term project',
#   'AnchorFourth': '',
#   'AnchorLast': 'Oversee yearly budgets for a large firm',
#   'Question': 'What level of financial decision-maker are you?',
#   'EasyReadDescription': 'Making spending decisions and keeping track of what is spent.',
#   'Beginner': 1.1,
#   'Basic': 1.925,
#   'Skilled': 2.75,
#   'Advanced': 3.575,
#   'Expert': 4.4},
#  {'ElementId': '2.A.1.e',
#   'ElementName': 'Mathematics',
#   'AnchorFirst': 'Add two large numbers',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Calculate the square footage of a home',
#   'AnchorFourth': '',
#   'AnchorLast': 'Derive a complex formula',
#   'Question': 'What is your level of math skill?',
#   'EasyReadDescription': 'Using math to solve problems.',
#   'Beginner': 1.224,
#   'Basic': 2.142,
#   'Skilled': 3.06,
#   'Advanced': 3.978,
#   'Expert': 4.896},
#  {'ElementId': '2.C.3.e',
#   'ElementName': 'Mechanical',
#   'AnchorFirst': 'Replace a battery in a smoke detector',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Replace a valve on a steam pipe',
#   'AnchorFourth': '',
#   'AnchorLast': 'Overhaul a jet engine',
#   'Question': 'How well can you design, use, repair, and maintain machines?',
#   'EasyReadDescription': 'Knowledge of machines and tools, including their designs, uses, repair, and maintenance.',
#   'Beginner': 1.37,
#   'Basic': 2.3975,
#   'Skilled': 3.425,
#   'Advanced': 4.4525,
#   'Expert': 5.48},
#  {'ElementId': '2.C.5.a',
#   'ElementName': 'Medicine and Dentistry',
#   'AnchorFirst': 'Treat a cut',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Fill a tooth cavity',
#   'AnchorFourth': '',
#   'AnchorLast': 'Perform open-heart surgery',
#   'Question': 'How well do you know how to provide health care?',
#   'EasyReadDescription': 'Knowledge of the information and techniques needed to diagnose and treat human injuries, diseases, and deformities. This includes symptoms, treatment alternatives, drug properties and interactions, and preventive health-care measures.',
#   'Beginner': 1.354,
#   'Basic': 2.3695,
#   'Skilled': 3.385,
#   'Advanced': 4.4005,
#   'Expert': 5.416},
#  {'ElementId': '1.A.1.d.1',
#   'ElementName': 'Memorization',
#   'AnchorFirst': 'Remember your bus number',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Recite the first names of 5 people you just met',
#   'AnchorFourth': '',
#   'AnchorLast': 'Quickly memorize and recite a complex equation',
#   'Question': 'How good is your memory?',
#   'EasyReadDescription': 'Remembering words, numbers, pictures, or steps.',
#   'Beginner': 0.954,
#   'Basic': 1.572,
#   'Skilled': 2.19,
#   'Advanced': 2.808,
#   'Expert': 3.426},
#  {'ElementId': '2.A.2.d',
#   'ElementName': 'Monitoring',
#   'AnchorFirst': 'Proofread a letter',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Make adjustments to a meeting to ensure key goals are met',
#   'AnchorFourth': '',
#   'AnchorLast': "Measure and plan to increase a firm's productivity",
#   'Question': 'How well can you assess your or others’ work?',
#   'EasyReadDescription': 'Keeping track of how well people and/or groups are doing in order to make improvements.',
#   'Beginner': 2.604,
#   'Basic': 3.147,
#   'Skilled': 3.69,
#   'Advanced': 4.233,
#   'Expert': 4.776},
#  {'ElementId': '2.B.1.d',
#   'ElementName': 'Negotiation',
#   'AnchorFirst': 'Justify a new work schedule to your manager',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Contract with a wholesaler to sell items at a given cost',
#   'AnchorFourth': '',
#   'AnchorLast': 'Negotiate a foreign treaty as an ambassador',
#   'Question': 'How well do you persuade others to see different points of view or compromise?',
#   'EasyReadDescription': 'Bringing people together to solve differences.',
#   'Beginner': 1.664,
#   'Basic': 2.2895,
#   'Skilled': 2.915,
#   'Advanced': 3.5405,
#   'Expert': 4.166},
#  {'ElementId': '2.B.3.a',
#   'ElementName': 'Operations Analysis',
#   'AnchorFirst': 'Select a copy machine for the office',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Suggest software changes to make a system more user friendly',
#   'AnchorFourth': '',
#   'AnchorLast': 'Identify system needs for a new process production plant',
#   'Question': 'How well can you analyze needs and requirements, then make a plan that meets them?',
#   'EasyReadDescription': 'Figuring out what a product or service needs to be able to do.',
#   'Beginner': 1,
#   'Basic': 1.75,
#   'Skilled': 2.5,
#   'Advanced': 3.25,
#   'Expert': 4},
#  {'ElementId': '2.C.1.f',
#   'ElementName': 'Personnel and Human Resources',
#   'AnchorFirst': 'Fill out a medical claim form',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Interview applicants for a new position',
#   'AnchorFourth': '',
#   'AnchorLast': 'Design a new HR system for a large firm',
#   'Question': 'How well do you know the principles and procedures for recruiting, hiring, and training employees?',
#   'EasyReadDescription': 'Knowledge of principles and procedures for personnel recruitment, selection, training, compensation and benefits, labor relations and negotiation, and personnel information systems.',
#   'Beginner': 1.34,
#   'Basic': 2.285,
#   'Skilled': 3.23,
#   'Advanced': 4.175,
#   'Expert': 5.12},
#  {'ElementId': '2.C.2.a',
#   'ElementName': 'Production and Processing',
#   'AnchorFirst': 'Repack a computer in original box',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Supervise an appliance assembly line',
#   'AnchorFourth': '',
#   'AnchorLast': 'Maintain an international distribution center',
#   'Question': 'How well can you oversee manufacturing and distribution processes?',
#   'EasyReadDescription': 'Knowledge of raw materials, production processes, quality control, costs, and other techniques for maximizing the effective manufacture and distribution of goods.',
#   'Beginner': 1.156,
#   'Basic': 1.993,
#   'Skilled': 2.83,
#   'Advanced': 3.667,
#   'Expert': 4.504},
#  {'ElementId': '2.B.3.e',
#   'ElementName': 'Programming',
#   'AnchorFirst': 'Create an Excel spreadsheet',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Write a statistical program to analyze  demographic data',
#   'AnchorFourth': '',
#   'AnchorLast': 'Write a program to analyze data for probability results',
#   'Question': 'How well can you write computer programs?',
#   'EasyReadDescription': 'Writing computer programs.',
#   'Beginner': 0.95,
#   'Basic': 1.6625,
#   'Skilled': 2.375,
#   'Advanced': 3.0875,
#   'Expert': 3.8},
#  {'ElementId': '2.C.4.e',
#   'ElementName': 'Psychology',
#   'AnchorFirst': 'Monitor kids on a playground',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Understand the impact of addiction on human responses',
#   'AnchorFourth': '',
#   'AnchorLast': 'Treat a person with severe mental illness',
#   'Question': 'How well do you know the methods of research, assessment, and treatment of human behavior?',
#   'EasyReadDescription': 'Knowledge of human behavior and performance; individual differences in ability, personality, and interests; learning and motivation; psychological research methods; and the assessment and treatment of behavioral and affective disorders.',
#   'Beginner': 1.458,
#   'Basic': 2.4915,
#   'Skilled': 3.525,
#   'Advanced': 4.5585,
#   'Expert': 5.592},
#  {'ElementId': '2.C.8.a',
#   'ElementName': 'Public Safety and Security',
#   'AnchorFirst': 'Follow work safety guidelines',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Inspect a building site for safety violations',
#   'AnchorFourth': '',
#   'AnchorLast': 'Command a military operation',
#   'Question': 'How well do you know the equipment, policies, procedures, and strategies used to promote security operations?',
#   'EasyReadDescription': 'Knowledge of relevant equipment, policies, procedures, and strategies to promote effective local, state, or national security operations for the protection of people, data, property, and institutions.',
#   'Beginner': 1.164,
#   'Basic': 1.9695,
#   'Skilled': 2.775,
#   'Advanced': 3.5805,
#   'Expert': 4.386},
#  {'ElementId': '2.B.3.m',
#   'ElementName': 'Quality Control Analysis',
#   'AnchorFirst': 'Compare two ways to make a recipe',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Measure new part requisitions for tolerance to specifications',
#   'AnchorFourth': '',
#   'AnchorLast': 'Plan and run a test for a new computer program',
#   'Question': 'How well can you develop and use testing processes?',
#   'EasyReadDescription': 'Testing how well a product or service works.',
#   'Beginner': 0.9,
#   'Basic': 1.575,
#   'Skilled': 2.25,
#   'Advanced': 2.925,
#   'Expert': 3.6},
#  {'ElementId': '2.B.3.l',
#   'ElementName': 'Repairing',
#   'AnchorFirst': 'Tighten the correct screw to get a door to close properly',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Replace a faulty hydraulic valve',
#   'AnchorFourth': '',
#   'AnchorLast': 'Repair structural damage after an earthquake',
#   'Question': 'How well can you repair machines or systems using the needed tools?',
#   'EasyReadDescription': 'Repairing machines or systems using the right tools.',
#   'Beginner': 0.85,
#   'Basic': 1.4875,
#   'Skilled': 2.125,
#   'Advanced': 2.7625,
#   'Expert': 3.4},
#  {'ElementId': '2.C.1.d',
#   'ElementName': 'Sales and Marketing',
#   'AnchorFirst': 'Sell cakes at a bake sale',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Call a list of clients to introduce them to a new product line',
#   'AnchorFourth': '',
#   'AnchorLast': 'Develop a marketing plan for a large firm',
#   'Question': 'How well can you perform marketing strategies and tactics?',
#   'EasyReadDescription': 'Knowledge of principles and methods for showing, promoting, and selling products or services. This includes marketing strategy and tactics, product demonstration, sales techniques, and sales control systems.',
#   'Beginner': 1.21,
#   'Basic': 2.1175,
#   'Skilled': 3.025,
#   'Advanced': 3.9325,
#   'Expert': 4.84},
#  {'ElementId': '2.A.1.f',
#   'ElementName': 'Science',
#   'AnchorFirst': 'Maintain house plants',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Conduct product tests to ensure safety standards are met',
#   'AnchorFourth': '',
#   'AnchorLast': 'Analyze aerodynamic systems for aircraft design',
#   'Question': 'How well can you use scientific rules and methods to solve problems?',
#   'EasyReadDescription': 'Using scientific rules and strategies to solve problems.',
#   'Beginner': 1.176,
#   'Basic': 2.058,
#   'Skilled': 2.94,
#   'Advanced': 3.822,
#   'Expert': 4.704},
#  {'ElementId': '2.C.4.f',
#   'ElementName': 'Sociology and Anthropology',
#   'AnchorFirst': 'Identify two different cultures',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Write an article about cultural differences',
#   'AnchorFourth': '',
#   'AnchorLast': "Create a new theory of civilization's development",
#   'Question': 'How well do you know the theories of group behavior, societal trends and influences, and human culture?',
#   'EasyReadDescription': 'Knowledge of group behavior and dynamics, societal trends and influences, human migrations, ethnicity, cultures and their history and origins.',
#   'Beginner': 1.338,
#   'Basic': 2.3415,
#   'Skilled': 3.345,
#   'Advanced': 4.3485,
#   'Expert': 5.352},
#  {'ElementId': '2.A.1.d',
#   'ElementName': 'Speaking',
#   'AnchorFirst': 'Greet customers',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Interview applicants to obtain personal and work history',
#   'AnchorFourth': '',
#   'AnchorLast': 'Argue a legal case before the Supreme Court',
#   'Question': 'How well do you convey information when you speak?',
#   'EasyReadDescription': 'Talking to others.',
#   'Beginner': 2.476,
#   'Basic': 3.0205,
#   'Skilled': 3.565,
#   'Advanced': 4.1095,
#   'Expert': 4.654},
#  {'ElementId': '2.B.4.g',
#   'ElementName': 'Systems Analysis',
#   'AnchorFirst': 'Manage work with a missing teammate',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Determine how new equipment will affect production rates',
#   'AnchorFourth': '',
#   'AnchorLast': 'Identify impact of tax changes across industries',
#   'Question': 'How well can you analyze systems?',
#   'EasyReadDescription': 'Figuring out how a system should work and how changes in the future will affect it.',
#   'Beginner': 1.076,
#   'Basic': 1.883,
#   'Skilled': 2.69,
#   'Advanced': 3.497,
#   'Expert': 4.304},
#  {'ElementId': '2.C.6',
#   'ElementName': 'Teaching and Course Design',
#   'AnchorFirst': 'Teach workers how to use a time clock',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Lead a quality improvement seminar',
#   'AnchorFourth': '',
#   'AnchorLast': 'Design a training program for new employees',
#   'Question': 'How well do you know the principles and methods of instruction?',
#   'EasyReadDescription': 'Knowledge of principles and methods for curriculum and training design, teaching and instruction for individuals and groups, and the measurement of training effects.',
#   'Beginner': 1.632,
#   'Basic': 2.6235,
#   'Skilled': 3.615,
#   'Advanced': 4.6065,
#   'Expert': 5.598},
#  {'ElementId': '2.C.9.a',
#   'ElementName': 'Telecommunications',
#   'AnchorFirst': 'Use a business phone',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Install a satellite TV dish',
#   'AnchorFourth': '',
#   'AnchorLast': 'Develop a worldwide telecom network',
#   'Question': 'How well do you understand telecom systems?',
#   'EasyReadDescription': 'Knowledge of transmission, broadcasting, switching, control, and operation of telecommunications systems.',
#   'Beginner': 1.208,
#   'Basic': 2.114,
#   'Skilled': 3.02,
#   'Advanced': 3.926,
#   'Expert': 4.832},
#  {'ElementId': '2.C.5.b',
#   'ElementName': 'Therapy and Counseling',
#   'AnchorFirst': 'Offer sympathy to a stranger',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Provide job counseling to the unemployed',
#   'AnchorFourth': '',
#   'AnchorLast': 'Supervise experienced therapists',
#   'Question': 'How well do you know the principles and methods used in counseling?',
#   'EasyReadDescription': 'Knowledge of principles, methods, and procedures for diagnosis, treatment, and rehabilitation of physical and mental dysfunctions, and for career counseling and guidance.',
#   'Beginner': 1.384,
#   'Basic': 2.422,
#   'Skilled': 3.46,
#   'Advanced': 4.498,
#   'Expert': 5.536},
#  {'ElementId': '2.B.5.a',
#   'ElementName': 'Time Management',
#   'AnchorFirst': 'Keep a monthly appointment calendar',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Allocate staff time to projects for the coming week',
#   'AnchorFourth': '',
#   'AnchorLast': 'Allocate scientists’ time to multiple multi-stage projects',
#   'Question': "How well do you manage your and others' time?",
#   'EasyReadDescription': 'Managing your time and the time of other people.',
#   'Beginner': 2.054,
#   'Basic': 2.5595,
#   'Skilled': 3.065,
#   'Advanced': 3.5705,
#   'Expert': 4.076},
#  {'ElementId': '2.B.3.k',
#   'ElementName': 'Troubleshooting',
#   'AnchorFirst': 'Identify source of leak on outside of machine',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Identify the circuit causing an electrical system to fail',
#   'AnchorFourth': '',
#   'AnchorLast': 'Oversee code debugging for new operating system',
#   'Question': 'How well can you identify and fix problems in machines or technology?',
#   'EasyReadDescription': 'Figuring out what is causing equipment, machines, wiring, or computer programs to not work.',
#   'Beginner': 1.05,
#   'Basic': 1.8375,
#   'Skilled': 2.625,
#   'Advanced': 3.4125,
#   'Expert': 4.2},
#  {'ElementId': '2.A.1.c',
#   'ElementName': 'Writing',
#   'AnchorFirst': 'Take a telephone message',
#   'AnchorSecond': '',
#   'AnchorThrid': 'Write a memo to staff outlining new directives',
#   'AnchorFourth': '',
#   'AnchorLast': 'Write a technical manual',
#   'Question': "How well does your writing effectively communicate to an audience's particular need?",
#   'EasyReadDescription': 'Writing things for co-workers or customers.',
#   'Beginner': 1.624,
#   'Basic': 2.467,
#   'Skilled': 3.31,
#   'Advanced': 4.153,
#   'Expert': 4.996}]

# %% [markdown]
# Two example functions:
# * One using custom user input for skill ratings
# * Another randomly selects skill ratings

# %%
def new_survey_request() -> dict:
  """Create new survey request object from user input (will be empty if survey is aborted)"""   
  
  print("Select your skill level")
  print("Use the examples help choose your levels. Think about whether you have done the example activity, or something like it in your own field")
  print("Answer Key: 1 - Beginner; 2 - Basic; 3 - Skilled; 4 - Advanced; 5 - Expert\n")
  print("(Type 'exit' to end this survey)")

  answers = []
  for n,q in enumerate(survey_questions):

    print(f"{n+1}. {q['ElementName']}: {q['Question']}")
    print("1 | 2 | 3 | 4 | 5 ")
    print(f"Beginner: {q['AnchorFirst']}")
    print(f"Skilled: {q['AnchorThrid']}")
    print(f"Expert: {q['AnchorLast']}") 

    x = input()

    if x == "exit":
      return {}
    else: 

      ratings_map = { # Recall that the value for each rating changes from question to question because each is a unique HTML identifier
      
      "1":q['Beginner'], 
      "2":q['Basic'], 
      "3":q['Skilled'],
      "4":q['Advanced'], 
      "5":q['Expert']

      }
      
      answers.append({
        "ElementId": q["ElementId"],
        "DataValue": ratings_map[x], 
      })


  return {"SKAValueList":answers} 

new_request = new_survey_request()
# Out:
# Select your skill level
# Use the examples help choose your levels. Think about whether you have done the example activity, or something like it in your own field
# Answer Key: 1 - Beginner; 2 - Basic; 3 - Skilled; 4 - Advanced; 5 - Expert
#
# (Type 'exit' to end this survey)
# 1. Administration and Management: How much do you know about business planning and leadership?
# 1 | 2 | 3 | 4 | 5
# Beginner: Complete a timesheet
# Skilled: Monitor project progress to complete it on time
# Expert: Manage a $10m company
# 2. Biology: How much do you know about plant, animal and cell functions?
# 1 | 2 | 3 | 4 | 5
# Beginner: Care for a pet
# Skilled: Investigate effects of pollution on plants
# Expert: Identify a new virus
# 3. Body Coordination: How well can you coordinate moving your arms, legs, and torso together?
# 1 | 2 | 3 | 4 | 5
# Beginner: Get in and out of a truck
# Skilled: Swim one pool  length, or play a ball sport
# Expert: Perform ballet choreography
# 4. Building and Construction: How much do you know about construction materials, methods, and tools?
# 1 | 2 | 3 | 4 | 5
# Beginner: Hang a picture
# Skilled: Fix a plumbing leak in ceiling
# Expert: Build a high-rise
# 5. Chemistry: How well do you know chemistry?
# 1 | 2 | 3 | 4 | 5
# Beginner: Use a household chemical safely
# Skilled: Use proper chlorine concentration to purify water source
# Expert: Develop a formula for a safe cleaner
# 6. Clerical: How much do you know about administrative tasks and processes?
# 1 | 2 | 3 | 4 | 5
# Beginner: File forms
# Skilled: Type 30 words per minute
# Expert: Design an online office-wide storage system
# 7. Complex Problem Solving: How good are you at figuring out the best way to solve a problem?
# 1 | 2 | 3 | 4 | 5
# Beginner: Gather tools for a household job
# Skilled: Redesign a floor plan around new equipment
# Expert: Develop a local disaster response plan
# 8. Computers and Electronics: How effective are you at using electronic equipment?
# 1 | 2 | 3 | 4 | 5
# Beginner: Open a program on a computer
# Skilled: Use a word processor
# Expert: Create a virus-scanning program
# 9. Customer and Personal Service: How well do you know how to handle customer needs and resolve service problems?
# 1 | 2 | 3 | 4 | 5
# Beginner: Process a dry-cleaning order
# Skilled: Supervise 10 children at a day care
# Expert: Plan customer outreach after data privacy breach
# 10. Economics and Accounting: How well do you know banking and financial systems?
# 1 | 2 | 3 | 4 | 5
# Beginner: Answer billing questions
# Skilled: Develop an investment plan for clients
# Expert: Oversee a large firm's finances
# 11. Fine Arts: How well do you know the theory and techniques of an art form such as music, painting, drama, or other?
# 1 | 2 | 3 | 4 | 5
# Beginner: Attend a concert
# Skilled: Play a minor part in a local theater play
# Expert: Teach the theory of an art form
# 12. Foreign Language: How well do you know a foreign language?
# 1 | 2 | 3 | 4 | 5
# Beginner: Say "please" and "thank you"
# Skilled: Ask directions in a foreign city
# Expert: Critique a literary book
# 13. Helping People: How good are you at understanding how to help people?
# 1 | 2 | 3 | 4 | 5
# Beginner: Ask clients if they would like coffee
# Skilled: Make travel arrangements for customers
# Expert: Direct relief operations in a disaster area
# 14. Instructing: How skilled are you at teaching people how to do something?
# 1 | 2 | 3 | 4 | 5
# Beginner: Show someone how to bowl
# Skilled: Instruct a coworker in how to operate a software program
# Expert: Demonstrate surgery to interns
# 15. Management of Financial Resources: What level of financial decision-maker are you?
# 1 | 2 | 3 | 4 | 5
# Beginner: Record office supply purchases
# Skilled: Prepare and manage a budget for a short-term project
# Expert: Oversee yearly budgets for a large firm
# 16. Mathematics: What is your level of math skill?
# 1 | 2 | 3 | 4 | 5
# Beginner: Add two large numbers
# Skilled: Calculate the square footage of a home
# Expert: Derive a complex formula
# 17. Mechanical: How well can you design, use, repair, and maintain machines?
# 1 | 2 | 3 | 4 | 5
# Beginner: Replace a battery in a smoke detector
# Skilled: Replace a valve on a steam pipe
# Expert: Overhaul a jet engine
# 18. Medicine and Dentistry: How well do you know how to provide health care?
# 1 | 2 | 3 | 4 | 5
# Beginner: Treat a cut
# Skilled: Fill a tooth cavity
# Expert: Perform open-heart surgery
# 19. Memorization: How good is your memory?
# 1 | 2 | 3 | 4 | 5
# Beginner: Remember your bus number
# Skilled: Recite the first names of 5 people you just met
# Expert: Quickly memorize and recite a complex equation
# 20. Monitoring: How well can you assess your or others’ work?
# 1 | 2 | 3 | 4 | 5
# Beginner: Proofread a letter
# Skilled: Make adjustments to a meeting to ensure key goals are met
# Expert: Measure and plan to increase a firm's productivity
# 21. Negotiation: How well do you persuade others to see different points of view or compromise?
# 1 | 2 | 3 | 4 | 5
# Beginner: Justify a new work schedule to your manager
# Skilled: Contract with a wholesaler to sell items at a given cost
# Expert: Negotiate a foreign treaty as an ambassador
# 22. Operations Analysis: How well can you analyze needs and requirements, then make a plan that meets them?
# 1 | 2 | 3 | 4 | 5
# Beginner: Select a copy machine for the office
# Skilled: Suggest software changes to make a system more user friendly
# Expert: Identify system needs for a new process production plant
# 23. Personnel and Human Resources: How well do you know the principles and procedures for recruiting, hiring, and training employees?
# 1 | 2 | 3 | 4 | 5
# Beginner: Fill out a medical claim form
# Skilled: Interview applicants for a new position
# Expert: Design a new HR system for a large firm
# 24. Production and Processing: How well can you oversee manufacturing and distribution processes?
# 1 | 2 | 3 | 4 | 5
# Beginner: Repack a computer in original box
# Skilled: Supervise an appliance assembly line
# Expert: Maintain an international distribution center
# 25. Programming: How well can you write computer programs?
# 1 | 2 | 3 | 4 | 5
# Beginner: Create an Excel spreadsheet
# Skilled: Write a statistical program to analyze  demographic data
# Expert: Write a program to analyze data for probability results
# 26. Psychology: How well do you know the methods of research, assessment, and treatment of human behavior?
# 1 | 2 | 3 | 4 | 5
# Beginner: Monitor kids on a playground
# Skilled: Understand the impact of addiction on human responses
# Expert: Treat a person with severe mental illness
# 27. Public Safety and Security: How well do you know the equipment, policies, procedures, and strategies used to promote security operations?
# 1 | 2 | 3 | 4 | 5
# Beginner: Follow work safety guidelines
# Skilled: Inspect a building site for safety violations
# Expert: Command a military operation
# 28. Quality Control Analysis: How well can you develop and use testing processes?
# 1 | 2 | 3 | 4 | 5
# Beginner: Compare two ways to make a recipe
# Skilled: Measure new part requisitions for tolerance to specifications
# Expert: Plan and run a test for a new computer program
# 29. Repairing: How well can you repair machines or systems using the needed tools?
# 1 | 2 | 3 | 4 | 5
# Beginner: Tighten the correct screw to get a door to close properly
# Skilled: Replace a faulty hydraulic valve
# Expert: Repair structural damage after an earthquake
# 30. Sales and Marketing: How well can you perform marketing strategies and tactics?
# 1 | 2 | 3 | 4 | 5
# Beginner: Sell cakes at a bake sale
# Skilled: Call a list of clients to introduce them to a new product line
# Expert: Develop a marketing plan for a large firm
# 31. Science: How well can you use scientific rules and methods to solve problems?
# 1 | 2 | 3 | 4 | 5
# Beginner: Maintain house plants
# Skilled: Conduct product tests to ensure safety standards are met
# Expert: Analyze aerodynamic systems for aircraft design
# 32. Sociology and Anthropology: How well do you know the theories of group behavior, societal trends and influences, and human culture?
# 1 | 2 | 3 | 4 | 5
# Beginner: Identify two different cultures
# Skilled: Write an article about cultural differences
# Expert: Create a new theory of civilization's development
# 33. Speaking: How well do you convey information when you speak?
# 1 | 2 | 3 | 4 | 5
# Beginner: Greet customers
# Skilled: Interview applicants to obtain personal and work history
# Expert: Argue a legal case before the Supreme Court
# 34. Systems Analysis: How well can you analyze systems?
# 1 | 2 | 3 | 4 | 5
# Beginner: Manage work with a missing teammate
# Skilled: Determine how new equipment will affect production rates
# Expert: Identify impact of tax changes across industries
# 35. Teaching and Course Design: How well do you know the principles and methods of instruction?
# 1 | 2 | 3 | 4 | 5
# Beginner: Teach workers how to use a time clock
# Skilled: Lead a quality improvement seminar
# Expert: Design a training program for new employees
# 36. Telecommunications: How well do you understand telecom systems?
# 1 | 2 | 3 | 4 | 5
# Beginner: Use a business phone
# Skilled: Install a satellite TV dish
# Expert: Develop a worldwide telecom network
# 37. Therapy and Counseling: How well do you know the principles and methods used in counseling?
# 1 | 2 | 3 | 4 | 5
# Beginner: Offer sympathy to a stranger
# Skilled: Provide job counseling to the unemployed
# Expert: Supervise experienced therapists
# 38. Time Management: How well do you manage your and others' time?
# 1 | 2 | 3 | 4 | 5
# Beginner: Keep a monthly appointment calendar
# Skilled: Allocate staff time to projects for the coming week
# Expert: Allocate scientists’ time to multiple multi-stage projects
# 39. Troubleshooting: How well can you identify and fix problems in machines or technology?
# 1 | 2 | 3 | 4 | 5
# Beginner: Identify source of leak on outside of machine
# Skilled: Identify the circuit causing an electrical system to fail
# Expert: Oversee code debugging for new operating system
# 40. Writing: How well does your writing effectively communicate to an audience's particular need?
# 1 | 2 | 3 | 4 | 5
# Beginner: Take a telephone message
# Skilled: Write a memo to staff outlining new directives
# Expert: Write a technical manual

# %%
response = requests.post(url, json=new_request, headers=headers)
response = response.json() # This matches the response we generated using the API Explorer
response
# Out:
# {'SKARankList': [{'OnetCode': '29-1221.00',
#    'Score': 0.28121313160199796,
#    'Rank': 1,
#    'Outlook': 'Below Average',
#    'AnnualWages': 190350.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Pediatricians, General',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1218.00',
#    'Score': 0.272130223767874,
#    'Rank': 2,
#    'Outlook': 'Below Average',
#    'AnnualWages': 999999.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Obstetricians and Gynecologists',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1216.00',
#    'Score': 0.262200674428677,
#    'Rank': 3,
#    'Outlook': 'Below Average',
#    'AnnualWages': 214460.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'General Internal Medicine Physicians',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1217.00',
#    'Score': 0.260975386319619,
#    'Rank': 4,
#    'Outlook': 'Below Average',
#    'AnnualWages': 224260.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Neurologists',
#    'EduCode': 2.0}],
#  'EduClassList': [{'EduCode': 2.0,
#    'EduTitle': "Master's degree or higher",
#    'Count': 4},
#   {'EduCode': 4.0, 'EduTitle': "Associate's degree", 'Count': 0},
#   {'EduCode': 3.0, 'EduTitle': "Bachelor's degree", 'Count': 0},
#   {'EduCode': 7.0,
#    'EduTitle': 'High school diploma or equivalent',
#    'Count': 0},
#   {'EduCode': 9.0, 'EduTitle': 'Some high school', 'Count': 0},
#   {'EduCode': 6.0, 'EduTitle': 'Some college', 'Count': 0}],
#  'RecordCount': 4,
#  'FilterValue': 0}

# %%
import random
def random_survey() -> dict: 
  """Generate a survey response object with random skill ratings for the Submit Skills API"""
  answers = [{"ElementId":q["ElementId"],
      "DataValue":random.choice([q['Beginner'], q['Basic'], q['Skilled'], q['Advanced'], q['Expert']])
    } for q in survey_questions]
    
  return {"SKAValueList":answers} 

rand_request = random_survey()

response = requests.post(url, json=rand_request, headers=headers)
response = response.json() # This matches the response we generated using the API Explorer
response
# Out:
# {'SKARankList': [{'OnetCode': '39-5092.00',
#    'Score': 0.443644066481302,
#    'Rank': 1,
#    'Outlook': 'Bright',
#    'AnnualWages': 31130.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Manicurists and Pedicurists',
#    'EduCode': 6.0},
#   {'OnetCode': '19-3091.00',
#    'Score': 0.44286812419121596,
#    'Rank': 2,
#    'Outlook': 'Average',
#    'AnnualWages': 63940.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Anthropologists and Archeologists',
#    'EduCode': 2.0},
#   {'OnetCode': '45-2041.00',
#    'Score': 0.43716886592564197,
#    'Rank': 3,
#    'Outlook': 'Below Average',
#    'AnnualWages': 32550.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Graders and Sorters, Agricultural Products',
#    'EduCode': 9.0},
#   {'OnetCode': '31-1131.00',
#    'Score': 0.43314916662403297,
#    'Rank': 4,
#    'Outlook': 'Bright',
#    'AnnualWages': 35760.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Nursing Assistants',
#    'EduCode': 6.0},
#   {'OnetCode': '35-3041.00',
#    'Score': 0.41801121903272304,
#    'Rank': 5,
#    'Outlook': 'Average',
#    'AnnualWages': 30300.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Food Servers, Nonrestaurant',
#    'EduCode': 9.0},
#   {'OnetCode': '47-5051.00',
#    'Score': 0.41343703368263596,
#    'Rank': 6,
#    'Outlook': 'Average',
#    'AnnualWages': 46010.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Rock Splitters, Quarry',
#    'EduCode': 9.0},
#   {'OnetCode': '35-2014.00',
#    'Score': 0.40943832728272606,
#    'Rank': 7,
#    'Outlook': 'Bright',
#    'AnnualWages': 34110.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Cooks, Restaurant',
#    'EduCode': 9.0},
#   {'OnetCode': '47-2141.00',
#    'Score': 0.405886304356957,
#    'Rank': 8,
#    'Outlook': 'Below Average',
#    'AnnualWages': 46090.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Painters, Construction and Maintenance',
#    'EduCode': 9.0},
#   {'OnetCode': '13-1199.05',
#    'Score': 0.40552953945955406,
#    'Rank': 9,
#    'Outlook': 'Bright',
#    'AnnualWages': 75990.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Sustainability Specialists',
#    'EduCode': 3.0},
#   {'OnetCode': '35-1011.00',
#    'Score': 0.395929497531123,
#    'Rank': 10,
#    'Outlook': 'Bright',
#    'AnnualWages': 56520.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Chefs and Head Cooks',
#    'EduCode': 7.0},
#   {'OnetCode': '29-1229.04',
#    'Score': 0.39538373392779497,
#    'Rank': 11,
#    'Outlook': 'Below Average',
#    'AnnualWages': 223410.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Physical Medicine and Rehabilitation Physicians',
#    'EduCode': 2.0},
#   {'OnetCode': '31-9011.00',
#    'Score': 0.393492225031025,
#    'Rank': 12,
#    'Outlook': 'Bright',
#    'AnnualWages': 49860.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Massage Therapists',
#    'EduCode': 6.0},
#   {'OnetCode': '39-2021.00',
#    'Score': 0.38881120780341705,
#    'Rank': 13,
#    'Outlook': 'Bright',
#    'AnnualWages': 29530.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Animal Caretakers',
#    'EduCode': 7.0},
#   {'OnetCode': '29-1141.02',
#    'Score': 0.38523038548405897,
#    'Rank': 14,
#    'Outlook': 'Bright',
#    'AnnualWages': 81220.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Advanced Practice Psychiatric Nurses',
#    'EduCode': 3.0},
#   {'OnetCode': '31-9097.00',
#    'Score': 0.38354123227861603,
#    'Rank': 15,
#    'Outlook': 'Bright',
#    'AnnualWages': 38530.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Phlebotomists',
#    'EduCode': 6.0},
#   {'OnetCode': '29-1161.00',
#    'Score': 0.38221770315423004,
#    'Rank': 16,
#    'Outlook': 'Bright',
#    'AnnualWages': 120880.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Nurse Midwives',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1291.00',
#    'Score': 0.38157544203420396,
#    'Rank': 17,
#    'Outlook': 'Average',
#    'AnnualWages': 72220.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Acupuncturists',
#    'EduCode': 2.0},
#   {'OnetCode': '39-5093.00',
#    'Score': 0.376724813702618,
#    'Rank': 18,
#    'Outlook': 'Bright',
#    'AnnualWages': 27860.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Shampooers',
#    'EduCode': 9.0},
#   {'OnetCode': '29-1229.03',
#    'Score': 0.374092828869178,
#    'Rank': 19,
#    'Outlook': 'Below Average',
#    'AnnualWages': 223410.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Urologists',
#    'EduCode': 2.0},
#   {'OnetCode': '35-3031.00',
#    'Score': 0.37225798962561396,
#    'Rank': 20,
#    'Outlook': 'Bright',
#    'AnnualWages': 29120.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Waiters and Waitresses',
#    'EduCode': 9.0},
#   {'OnetCode': '31-1122.00',
#    'Score': 0.36928214475399396,
#    'Rank': 21,
#    'Outlook': 'Bright',
#    'AnnualWages': 30180.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Personal Care Aides',
#    'EduCode': 7.0},
#   {'OnetCode': '25-1041.00',
#    'Score': 0.368912788896708,
#    'Rank': 22,
#    'Outlook': 'Average',
#    'AnnualWages': 85860.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Agricultural Sciences Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1299.01',
#    'Score': 0.367679433316306,
#    'Rank': 23,
#    'Outlook': 'Below Average',
#    'AnnualWages': 106230.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Naturopathic Physicians',
#    'EduCode': 2.0},
#   {'OnetCode': '35-2015.00',
#    'Score': 0.367372319366359,
#    'Rank': 24,
#    'Outlook': 'Below Average',
#    'AnnualWages': 30360.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Cooks, Short Order',
#    'EduCode': 9.0},
#   {'OnetCode': '33-9092.00',
#    'Score': 0.366989072655511,
#    'Rank': 25,
#    'Outlook': 'Bright',
#    'AnnualWages': 27270.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Lifeguards, Ski Patrol, and Other Recreational Protective Service Workers',
#    'EduCode': 9.0},
#   {'OnetCode': '39-9031.00',
#    'Score': 0.365349997670022,
#    'Rank': 26,
#    'Outlook': 'Bright',
#    'AnnualWages': 45380.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Exercise Trainers and Group Fitness Instructors',
#    'EduCode': 7.0},
#   {'OnetCode': '51-2051.00',
#    'Score': 0.36253194395696,
#    'Rank': 27,
#    'Outlook': 'Below Average',
#    'AnnualWages': 38110.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Fiberglass Laminators and Fabricators',
#    'EduCode': 7.0},
#   {'OnetCode': '11-9171.00',
#    'Score': 0.36166761286141896,
#    'Rank': 28,
#    'Outlook': 'Average',
#    'AnnualWages': 72110.0,
#    'TypicalEducation': "Associate's degree",
#    'OccupationTitle': 'Funeral Home Managers',
#    'EduCode': 4.0},
#   {'OnetCode': '19-1011.00',
#    'Score': 0.36037817706327296,
#    'Rank': 29,
#    'Outlook': 'Bright',
#    'AnnualWages': 69390.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Animal Scientists',
#    'EduCode': 3.0},
#   {'OnetCode': '35-3011.00',
#    'Score': 0.358652229327773,
#    'Rank': 30,
#    'Outlook': 'Bright',
#    'AnnualWages': 29380.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Bartenders',
#    'EduCode': 9.0},
#   {'OnetCode': '33-3051.04',
#    'Score': 0.358252387528203,
#    'Rank': 31,
#    'Outlook': 'Below Average',
#    'AnnualWages': 65790.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Customs and Border Protection Officers',
#    'EduCode': 7.0},
#   {'OnetCode': '25-9021.00',
#    'Score': 0.358196135422914,
#    'Rank': 32,
#    'Outlook': 'Below Average',
#    'AnnualWages': 53450.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Farm and Home Management Educators',
#    'EduCode': 2.0},
#   {'OnetCode': '13-1074.00',
#    'Score': 0.357280104803462,
#    'Rank': 33,
#    'Outlook': 'Bright',
#    'AnnualWages': 49330.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Farm Labor Contractors',
#    'EduCode': 9.0},
#   {'OnetCode': '51-2021.00',
#    'Score': 0.354789107898483,
#    'Rank': 34,
#    'Outlook': 'Below Average',
#    'AnnualWages': 43160.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Coil Winders, Tapers, and Finishers',
#    'EduCode': 7.0},
#   {'OnetCode': '25-1061.00',
#    'Score': 0.354523760353584,
#    'Rank': 35,
#    'Outlook': 'Bright',
#    'AnnualWages': 85000.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Anthropology and Archeology Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '29-9092.00',
#    'Score': 0.353442287171101,
#    'Rank': 36,
#    'Outlook': 'Bright',
#    'AnnualWages': 89990.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Genetic Counselors',
#    'EduCode': 2.0},
#   {'OnetCode': '39-2011.00',
#    'Score': 0.35119603010940703,
#    'Rank': 37,
#    'Outlook': 'Bright',
#    'AnnualWages': 35620.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Animal Trainers',
#    'EduCode': 7.0},
#   {'OnetCode': '25-3021.00',
#    'Score': 0.349356624618829,
#    'Rank': 38,
#    'Outlook': 'Bright',
#    'AnnualWages': 44110.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Self-Enrichment Teachers',
#    'EduCode': 7.0},
#   {'OnetCode': '35-2021.00',
#    'Score': 0.349131498979557,
#    'Rank': 39,
#    'Outlook': 'Bright',
#    'AnnualWages': 29790.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Food Preparation Workers',
#    'EduCode': 9.0},
#   {'OnetCode': '29-1141.04',
#    'Score': 0.34904807630769896,
#    'Rank': 40,
#    'Outlook': 'Bright',
#    'AnnualWages': 81220.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Clinical Nurse Specialists',
#    'EduCode': 3.0},
#   {'OnetCode': '51-9192.00',
#    'Score': 0.34513329012901395,
#    'Rank': 41,
#    'Outlook': 'Average',
#    'AnnualWages': 37190.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Cleaning, Washing, and Metal Pickling Equipment Operators and Tenders',
#    'EduCode': 7.0},
#   {'OnetCode': '25-3041.00',
#    'Score': 0.340398851586571,
#    'Rank': 42,
#    'Outlook': 'Bright',
#    'AnnualWages': 36680.0,
#    'TypicalEducation': 'Some college, no degree',
#    'OccupationTitle': 'Tutors',
#    'EduCode': 6.0},
#   {'OnetCode': '37-3012.00',
#    'Score': 0.338265716887149,
#    'Rank': 43,
#    'Outlook': 'Average',
#    'AnnualWages': 41440.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Pesticide Handlers, Sprayers, and Applicators, Vegetation',
#    'EduCode': 7.0},
#   {'OnetCode': '19-5012.00',
#    'Score': 0.337736372622425,
#    'Rank': 44,
#    'Outlook': 'Average',
#    'AnnualWages': 57970.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Occupational Health and Safety Technicians',
#    'EduCode': 7.0},
#   {'OnetCode': '39-7011.00',
#    'Score': 0.33504845293790597,
#    'Rank': 45,
#    'Outlook': 'Bright',
#    'AnnualWages': 34440.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Tour Guides and Escorts',
#    'EduCode': 7.0},
#   {'OnetCode': '47-2142.00',
#    'Score': 0.33443166152347803,
#    'Rank': 46,
#    'Outlook': 'Below Average',
#    'AnnualWages': 44930.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Paperhangers',
#    'EduCode': 9.0},
#   {'OnetCode': '29-9099.01',
#    'Score': 0.333574154765568,
#    'Rank': 47,
#    'Outlook': 'Average',
#    'AnnualWages': 60160.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Midwives',
#    'EduCode': 6.0},
#   {'OnetCode': '21-1094.00',
#    'Score': 0.333426367344513,
#    'Rank': 48,
#    'Outlook': 'Bright',
#    'AnnualWages': 46190.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Community Health Workers',
#    'EduCode': 7.0},
#   {'OnetCode': '29-1011.00',
#    'Score': 0.331532185916439,
#    'Rank': 49,
#    'Outlook': 'Bright',
#    'AnnualWages': 75380.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Chiropractors',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1123.00',
#    'Score': 0.330881248751117,
#    'Rank': 50,
#    'Outlook': 'Bright',
#    'AnnualWages': 97720.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Physical Therapists',
#    'EduCode': 2.0},
#   {'OnetCode': '39-4021.00',
#    'Score': 0.330794886861186,
#    'Rank': 51,
#    'Outlook': 'Bright',
#    'AnnualWages': 31160.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Funeral Attendants',
#    'EduCode': 7.0},
#   {'OnetCode': '27-2021.00',
#    'Score': 0.329077378671729,
#    'Rank': 52,
#    'Outlook': 'Bright',
#    'AnnualWages': 94270.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Athletes and Sports Competitors',
#    'EduCode': 9.0},
#   {'OnetCode': '25-2022.00',
#    'Score': 0.326795217568159,
#    'Rank': 53,
#    'Outlook': 'Average',
#    'AnnualWages': 61810.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Middle School Teachers, Except Special and Career/Technical Education',
#    'EduCode': 3.0},
#   {'OnetCode': '29-1125.00',
#    'Score': 0.326485558629528,
#    'Rank': 54,
#    'Outlook': 'Average',
#    'AnnualWages': 51330.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Recreational Therapists',
#    'EduCode': 3.0},
#   {'OnetCode': '35-9011.00',
#    'Score': 0.323014649809788,
#    'Rank': 55,
#    'Outlook': 'Bright',
#    'AnnualWages': 29120.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Dining Room and Cafeteria Attendants and Bartender Helpers',
#    'EduCode': 9.0},
#   {'OnetCode': '37-2012.00',
#    'Score': 0.322701900094856,
#    'Rank': 56,
#    'Outlook': 'Bright',
#    'AnnualWages': 29960.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Maids and Housekeeping Cleaners',
#    'EduCode': 9.0},
#   {'OnetCode': '29-1229.02',
#    'Score': 0.322126585750445,
#    'Rank': 57,
#    'Outlook': 'Below Average',
#    'AnnualWages': 223410.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Hospitalists',
#    'EduCode': 2.0},
#   {'OnetCode': '31-1121.00',
#    'Score': 0.321994867353085,
#    'Rank': 58,
#    'Outlook': 'Bright',
#    'AnnualWages': 30180.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Home Health Aides',
#    'EduCode': 7.0},
#   {'OnetCode': '35-2012.00',
#    'Score': 0.321680453509233,
#    'Rank': 59,
#    'Outlook': 'Average',
#    'AnnualWages': 32510.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Cooks, Institution and Cafeteria',
#    'EduCode': 9.0},
#   {'OnetCode': '29-1141.03',
#    'Score': 0.321332924332497,
#    'Rank': 60,
#    'Outlook': 'Bright',
#    'AnnualWages': 81220.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Critical Care Nurses',
#    'EduCode': 3.0},
#   {'OnetCode': '29-1171.00',
#    'Score': 0.31875782403164604,
#    'Rank': 61,
#    'Outlook': 'Bright',
#    'AnnualWages': 121610.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Nurse Practitioners',
#    'EduCode': 2.0},
#   {'OnetCode': '19-1031.00',
#    'Score': 0.31854221370653596,
#    'Rank': 62,
#    'Outlook': 'Below Average',
#    'AnnualWages': 64460.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Conservation Scientists',
#    'EduCode': 3.0},
#   {'OnetCode': '39-4011.00',
#    'Score': 0.318410267996785,
#    'Rank': 63,
#    'Outlook': 'Average',
#    'AnnualWages': 49910.0,
#    'TypicalEducation': "Associate's degree",
#    'OccupationTitle': 'Embalmers',
#    'EduCode': 4.0},
#   {'OnetCode': '11-1011.03',
#    'Score': 0.31804282694785,
#    'Rank': 64,
#    'Outlook': 'Below Average',
#    'AnnualWages': 189520.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Chief Sustainability Officers',
#    'EduCode': 3.0},
#   {'OnetCode': '25-2023.00',
#    'Score': 0.31590077147843604,
#    'Rank': 65,
#    'Outlook': 'Below Average',
#    'AnnualWages': 62630.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Career/Technical Education Teachers, Middle School',
#    'EduCode': 3.0},
#   {'OnetCode': '29-2035.00',
#    'Score': 0.313636002353578,
#    'Rank': 66,
#    'Outlook': 'Average',
#    'AnnualWages': 80090.0,
#    'TypicalEducation': "Associate's degree",
#    'OccupationTitle': 'Magnetic Resonance Imaging Technologists',
#    'EduCode': 4.0},
#   {'OnetCode': '45-1011.00',
#    'Score': 0.313291360818628,
#    'Rank': 67,
#    'Outlook': 'Average',
#    'AnnualWages': 54490.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'First-Line Supervisors of Farming, Fishing, and Forestry Workers',
#    'EduCode': 7.0},
#   {'OnetCode': '39-5011.00',
#    'Score': 0.313240215303349,
#    'Rank': 68,
#    'Outlook': 'Bright',
#    'AnnualWages': 34990.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Barbers',
#    'EduCode': 6.0},
#   {'OnetCode': '47-2132.00',
#    'Score': 0.31234744686545995,
#    'Rank': 69,
#    'Outlook': 'Below Average',
#    'AnnualWages': 50590.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Insulation Workers, Mechanical',
#    'EduCode': 7.0},
#   {'OnetCode': '39-3012.00',
#    'Score': 0.312144280315726,
#    'Rank': 70,
#    'Outlook': 'Below Average',
#    'AnnualWages': 28940.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Gambling and Sports Book Writers and Runners',
#    'EduCode': 7.0},
#   {'OnetCode': '51-3022.00',
#    'Score': 0.311739971203161,
#    'Rank': 71,
#    'Outlook': 'Below Average',
#    'AnnualWages': 35070.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Meat, Poultry, and Fish Cutters and Trimmers',
#    'EduCode': 9.0},
#   {'OnetCode': '35-3023.00',
#    'Score': 0.311340187808651,
#    'Rank': 72,
#    'Outlook': 'Bright',
#    'AnnualWages': 27930.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Fast Food and Counter Workers',
#    'EduCode': 9.0},
#   {'OnetCode': '35-9021.00',
#    'Score': 0.31027717729335696,
#    'Rank': 73,
#    'Outlook': 'Bright',
#    'AnnualWages': 29080.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Dishwashers',
#    'EduCode': 9.0},
#   {'OnetCode': '11-9179.01',
#    'Score': 0.30771580851662395,
#    'Rank': 74,
#    'Outlook': 'Bright',
#    'AnnualWages': 56090.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Fitness and Wellness Coordinators',
#    'EduCode': 7.0},
#   {'OnetCode': '29-1122.00',
#    'Score': 0.306351990369937,
#    'Rank': 75,
#    'Outlook': 'Bright',
#    'AnnualWages': 93180.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Occupational Therapists',
#    'EduCode': 2.0},
#   {'OnetCode': '21-1022.00',
#    'Score': 0.30574723076442395,
#    'Rank': 76,
#    'Outlook': 'Bright',
#    'AnnualWages': 60280.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Healthcare Social Workers',
#    'EduCode': 2.0},
#   {'OnetCode': '25-2032.00',
#    'Score': 0.305741718532129,
#    'Rank': 77,
#    'Outlook': 'Below Average',
#    'AnnualWages': 62500.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Career/Technical Education Teachers, Secondary School',
#    'EduCode': 3.0},
#   {'OnetCode': '29-2081.00',
#    'Score': 0.304509048116733,
#    'Rank': 78,
#    'Outlook': 'Average',
#    'AnnualWages': 39610.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Opticians, Dispensing',
#    'EduCode': 7.0},
#   {'OnetCode': '19-5011.00',
#    'Score': 0.304061731417321,
#    'Rank': 79,
#    'Outlook': 'Average',
#    'AnnualWages': 78570.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Occupational Health and Safety Specialists',
#    'EduCode': 3.0},
#   {'OnetCode': '25-1193.00',
#    'Score': 0.303527732102293,
#    'Rank': 80,
#    'Outlook': 'Average',
#    'AnnualWages': 72650.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Recreation and Fitness Studies Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '33-3052.00',
#    'Score': 0.302651043883537,
#    'Rank': 81,
#    'Outlook': 'Below Average',
#    'AnnualWages': 69150.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Transit and Railroad Police',
#    'EduCode': 7.0},
#   {'OnetCode': '29-1141.01',
#    'Score': 0.30128066128112696,
#    'Rank': 82,
#    'Outlook': 'Bright',
#    'AnnualWages': 81220.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Acute Care Nurses',
#    'EduCode': 3.0},
#   {'OnetCode': '43-5052.00',
#    'Score': 0.300686492807235,
#    'Rank': 83,
#    'Outlook': 'Below Average',
#    'AnnualWages': 54250.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Postal Service Mail Carriers',
#    'EduCode': 7.0},
#   {'OnetCode': '51-3023.00',
#    'Score': 0.300367677964698,
#    'Rank': 84,
#    'Outlook': 'Below Average',
#    'AnnualWages': 35240.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Slaughterers and Meat Packers',
#    'EduCode': 9.0},
#   {'OnetCode': '51-9123.00',
#    'Score': 0.30019782158449,
#    'Rank': 85,
#    'Outlook': 'Below Average',
#    'AnnualWages': 38270.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Painting, Coating, and Decorating Workers',
#    'EduCode': 9.0},
#   {'OnetCode': '35-9031.00',
#    'Score': 0.300051299178524,
#    'Rank': 86,
#    'Outlook': 'Bright',
#    'AnnualWages': 27720.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop',
#    'EduCode': 9.0},
#   {'OnetCode': '45-2092.00',
#    'Score': 0.299303313551639,
#    'Rank': 87,
#    'Outlook': 'Below Average',
#    'AnnualWages': 33000.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Farmworkers and Laborers, Crop, Nursery, and Greenhouse',
#    'EduCode': 9.0},
#   {'OnetCode': '31-2011.00',
#    'Score': 0.298372595120911,
#    'Rank': 88,
#    'Outlook': 'Bright',
#    'AnnualWages': 64250.0,
#    'TypicalEducation': "Associate's degree",
#    'OccupationTitle': 'Occupational Therapy Assistants',
#    'EduCode': 4.0},
#   {'OnetCode': '19-1031.03',
#    'Score': 0.297545793832647,
#    'Rank': 89,
#    'Outlook': 'Below Average',
#    'AnnualWages': 64460.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Park Naturalists',
#    'EduCode': 3.0},
#   {'OnetCode': '21-1011.00',
#    'Score': 0.29742835517049104,
#    'Rank': 90,
#    'Outlook': 'Bright',
#    'AnnualWages': 49710.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Substance Abuse and Behavioral Disorder Counselors',
#    'EduCode': 3.0},
#   {'OnetCode': '53-2031.00',
#    'Score': 0.296770423416236,
#    'Rank': 91,
#    'Outlook': 'Bright',
#    'AnnualWages': 63760.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Flight Attendants',
#    'EduCode': 7.0},
#   {'OnetCode': '51-6041.00',
#    'Score': 0.29603681110278,
#    'Rank': 92,
#    'Outlook': 'Below Average',
#    'AnnualWages': 32460.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Shoe and Leather Workers and Repairers',
#    'EduCode': 7.0},
#   {'OnetCode': '19-3092.00',
#    'Score': 0.294716983907197,
#    'Rank': 93,
#    'Outlook': 'Below Average',
#    'AnnualWages': 88900.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Geographers',
#    'EduCode': 3.0},
#   {'OnetCode': '29-1151.00',
#    'Score': 0.29462551827401495,
#    'Rank': 94,
#    'Outlook': 'Bright',
#    'AnnualWages': 203090.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Nurse Anesthetists',
#    'EduCode': 2.0},
#   {'OnetCode': '25-2059.01',
#    'Score': 0.294192648876541,
#    'Rank': 95,
#    'Outlook': 'Average',
#    'AnnualWages': 63950.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Adapted Physical Education Specialists',
#    'EduCode': 3.0},
#   {'OnetCode': '53-7064.00',
#    'Score': 0.293330453082354,
#    'Rank': 96,
#    'Outlook': 'Below Average',
#    'AnnualWages': 32920.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Packers and Packagers, Hand',
#    'EduCode': 9.0},
#   {'OnetCode': '39-4031.00',
#    'Score': 0.293179287272178,
#    'Rank': 97,
#    'Outlook': 'Bright',
#    'AnnualWages': 51570.0,
#    'TypicalEducation': "Associate's degree",
#    'OccupationTitle': 'Morticians, Undertakers, and Funeral Arrangers',
#    'EduCode': 4.0},
#   {'OnetCode': '19-3033.00',
#    'Score': 0.29290249536845103,
#    'Rank': 98,
#    'Outlook': 'Bright',
#    'AnnualWages': 90130.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Clinical and Counseling Psychologists',
#    'EduCode': 2.0},
#   {'OnetCode': '13-2071.00',
#    'Score': 0.292226111248115,
#    'Rank': 99,
#    'Outlook': 'Bright',
#    'AnnualWages': 47320.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Credit Counselors',
#    'EduCode': 3.0},
#   {'OnetCode': '39-3093.00',
#    'Score': 0.29173348662015497,
#    'Rank': 100,
#    'Outlook': 'Bright',
#    'AnnualWages': 30210.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Locker Room, Coatroom, and Dressing Room Attendants',
#    'EduCode': 7.0},
#   {'OnetCode': '29-2091.00',
#    'Score': 0.29116560549896003,
#    'Rank': 101,
#    'Outlook': 'Bright',
#    'AnnualWages': 77070.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Orthotists and Prosthetists',
#    'EduCode': 2.0},
#   {'OnetCode': '51-6021.00',
#    'Score': 0.290495126982746,
#    'Rank': 102,
#    'Outlook': 'Below Average',
#    'AnnualWages': 29690.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Pressers, Textile, Garment, and Related Materials',
#    'EduCode': 9.0},
#   {'OnetCode': '47-2042.00',
#    'Score': 0.28999162997864203,
#    'Rank': 103,
#    'Outlook': 'Bright',
#    'AnnualWages': 48870.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Floor Layers, Except Carpet, Wood, and Hard Tiles',
#    'EduCode': 9.0},
#   {'OnetCode': '25-1066.00',
#    'Score': 0.28710092357684,
#    'Rank': 104,
#    'Outlook': 'Bright',
#    'AnnualWages': 78810.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Psychology Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1128.00',
#    'Score': 0.286864923967769,
#    'Rank': 105,
#    'Outlook': 'Bright',
#    'AnnualWages': 51350.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Exercise Physiologists',
#    'EduCode': 3.0},
#   {'OnetCode': '33-9011.00',
#    'Score': 0.28671510416443596,
#    'Rank': 106,
#    'Outlook': 'Average',
#    'AnnualWages': 39320.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Animal Control Workers',
#    'EduCode': 7.0},
#   {'OnetCode': '31-2021.00',
#    'Score': 0.286079403758161,
#    'Rank': 107,
#    'Outlook': 'Bright',
#    'AnnualWages': 62770.0,
#    'TypicalEducation': "Associate's degree",
#    'OccupationTitle': 'Physical Therapist Assistants',
#    'EduCode': 4.0},
#   {'OnetCode': '53-7061.00',
#    'Score': 0.28551071601008904,
#    'Rank': 108,
#    'Outlook': 'Average',
#    'AnnualWages': 31000.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Cleaners of Vehicles and Equipment',
#    'EduCode': 9.0},
#   {'OnetCode': '27-3091.00',
#    'Score': 0.28539443393378094,
#    'Rank': 109,
#    'Outlook': 'Bright',
#    'AnnualWages': 53640.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Interpreters and Translators',
#    'EduCode': 3.0},
#   {'OnetCode': '39-5012.00',
#    'Score': 0.284989495070333,
#    'Rank': 110,
#    'Outlook': 'Bright',
#    'AnnualWages': 33290.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Hairdressers, Hairstylists, and Cosmetologists',
#    'EduCode': 6.0},
#   {'OnetCode': '29-1229.01',
#    'Score': 0.28376027299126494,
#    'Rank': 111,
#    'Outlook': 'Below Average',
#    'AnnualWages': 223410.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Allergists and Immunologists',
#    'EduCode': 2.0},
#   {'OnetCode': '33-3021.02',
#    'Score': 0.283453471892028,
#    'Rank': 112,
#    'Outlook': 'Below Average',
#    'AnnualWages': 86280.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Police Identification and Records Officers',
#    'EduCode': 7.0},
#   {'OnetCode': '39-9011.00',
#    'Score': 0.282996464214809,
#    'Rank': 113,
#    'Outlook': 'Bright',
#    'AnnualWages': 28520.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Childcare Workers',
#    'EduCode': 7.0},
#   {'OnetCode': '25-1072.00',
#    'Score': 0.282708778055511,
#    'Rank': 114,
#    'Outlook': 'Bright',
#    'AnnualWages': 78580.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Nursing Instructors and Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '39-3092.00',
#    'Score': 0.282367775779519,
#    'Rank': 115,
#    'Outlook': 'Bright',
#    'AnnualWages': 48470.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Costume Attendants',
#    'EduCode': 7.0},
#   {'OnetCode': '51-3092.00',
#    'Score': 0.28153099099407797,
#    'Rank': 116,
#    'Outlook': 'Average',
#    'AnnualWages': 36580.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Food Batchmakers',
#    'EduCode': 7.0},
#   {'OnetCode': '29-2099.08',
#    'Score': 0.281401849123459,
#    'Rank': 117,
#    'Outlook': 'Average',
#    'AnnualWages': 44990.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Patient Representatives',
#    'EduCode': 6.0},
#   {'OnetCode': '29-1071.00',
#    'Score': 0.28078323743286,
#    'Rank': 118,
#    'Outlook': 'Bright',
#    'AnnualWages': 126010.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Physician Assistants',
#    'EduCode': 2.0},
#   {'OnetCode': '19-1012.00',
#    'Score': 0.28060554027235995,
#    'Rank': 119,
#    'Outlook': 'Average',
#    'AnnualWages': 79860.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Food Scientists and Technologists',
#    'EduCode': 3.0},
#   {'OnetCode': '25-1011.00',
#    'Score': 0.279514292798481,
#    'Rank': 120,
#    'Outlook': 'Average',
#    'AnnualWages': 88790.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Business Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '45-2021.00',
#    'Score': 0.279019042048903,
#    'Rank': 121,
#    'Outlook': 'Average',
#    'AnnualWages': 45320.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Animal Breeders',
#    'EduCode': 7.0},
#   {'OnetCode': '31-1132.00',
#    'Score': 0.278713011771642,
#    'Rank': 122,
#    'Outlook': 'Average',
#    'AnnualWages': 34520.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Orderlies',
#    'EduCode': 7.0},
#   {'OnetCode': '47-4051.00',
#    'Score': 0.278481726653635,
#    'Rank': 123,
#    'Outlook': 'Average',
#    'AnnualWages': 44930.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Highway Maintenance Workers',
#    'EduCode': 7.0},
#   {'OnetCode': '25-1123.00',
#    'Score': 0.277085493995978,
#    'Rank': 124,
#    'Outlook': 'Average',
#    'AnnualWages': 74280.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'English Language and Literature Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '25-1126.00',
#    'Score': 0.27633123753947497,
#    'Rank': 125,
#    'Outlook': 'Bright',
#    'AnnualWages': 78780.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Philosophy and Religion Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '39-1022.00',
#    'Score': 0.275500260969582,
#    'Rank': 126,
#    'Outlook': 'Bright',
#    'AnnualWages': 43680.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'First-Line Supervisors of Personal Service Workers',
#    'EduCode': 7.0},
#   {'OnetCode': '29-1031.00',
#    'Score': 0.27530510686840903,
#    'Rank': 127,
#    'Outlook': 'Average',
#    'AnnualWages': 66450.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Dietitians and Nutritionists',
#    'EduCode': 3.0},
#   {'OnetCode': '39-5091.00',
#    'Score': 0.275246857541275,
#    'Rank': 128,
#    'Outlook': 'Average',
#    'AnnualWages': 96370.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Makeup Artists, Theatrical and Performance',
#    'EduCode': 6.0},
#   {'OnetCode': '17-2111.00',
#    'Score': 0.27523649883114704,
#    'Rank': 129,
#    'Outlook': 'Average',
#    'AnnualWages': 100660.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Health and Safety Engineers, Except Mining Safety Engineers and Inspectors',
#    'EduCode': 3.0},
#   {'OnetCode': '51-9051.00',
#    'Score': 0.27503957600612006,
#    'Rank': 130,
#    'Outlook': 'Below Average',
#    'AnnualWages': 44530.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Furnace, Kiln, Oven, Drier, and Kettle Operators and Tenders',
#    'EduCode': 7.0},
#   {'OnetCode': '25-2058.00',
#    'Score': 0.274860564045174,
#    'Rank': 131,
#    'Outlook': 'Average',
#    'AnnualWages': 63560.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Special Education Teachers, Secondary School',
#    'EduCode': 3.0},
#   {'OnetCode': '25-3011.00',
#    'Score': 0.273857873609471,
#    'Rank': 132,
#    'Outlook': 'Below Average',
#    'AnnualWages': 58590.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Adult Basic Education, Adult Secondary Education, and English as a Second Language Instructors',
#    'EduCode': 3.0},
#   {'OnetCode': '25-2031.00',
#    'Score': 0.273391362966268,
#    'Rank': 133,
#    'Outlook': 'Average',
#    'AnnualWages': 62360.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Secondary School Teachers, Except Special and Career/Technical Education',
#    'EduCode': 3.0},
#   {'OnetCode': '39-5094.00',
#    'Score': 0.27252203500951705,
#    'Rank': 134,
#    'Outlook': 'Bright',
#    'AnnualWages': 38060.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Skincare Specialists',
#    'EduCode': 6.0},
#   {'OnetCode': '53-6061.00',
#    'Score': 0.27089648682434003,
#    'Rank': 135,
#    'Outlook': 'Below Average',
#    'AnnualWages': 34630.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Passenger Attendants',
#    'EduCode': 7.0},
#   {'OnetCode': '33-3041.00',
#    'Score': 0.27075658748681203,
#    'Rank': 136,
#    'Outlook': 'Below Average',
#    'AnnualWages': 41570.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Parking Enforcement Workers',
#    'EduCode': 7.0},
#   {'OnetCode': '29-1129.02',
#    'Score': 0.270712236440888,
#    'Rank': 137,
#    'Outlook': 'Bright',
#    'AnnualWages': 60800.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Music Therapists',
#    'EduCode': 3.0},
#   {'OnetCode': '29-9091.00',
#    'Score': 0.26971778921322603,
#    'Rank': 138,
#    'Outlook': 'Bright',
#    'AnnualWages': 53840.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Athletic Trainers',
#    'EduCode': 2.0},
#   {'OnetCode': '31-1133.00',
#    'Score': 0.268247972734944,
#    'Rank': 139,
#    'Outlook': 'Average',
#    'AnnualWages': 37160.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Psychiatric Aides',
#    'EduCode': 7.0},
#   {'OnetCode': '29-1218.00',
#    'Score': 0.268101971749561,
#    'Rank': 140,
#    'Outlook': 'Below Average',
#    'AnnualWages': 999999.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Obstetricians and Gynecologists',
#    'EduCode': 2.0},
#   {'OnetCode': '25-2012.00',
#    'Score': 0.267002690123006,
#    'Rank': 141,
#    'Outlook': 'Average',
#    'AnnualWages': 60490.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Kindergarten Teachers, Except Special Education',
#    'EduCode': 3.0},
#   {'OnetCode': '25-1071.00',
#    'Score': 0.266050225559714,
#    'Rank': 142,
#    'Outlook': 'Bright',
#    'AnnualWages': 100300.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Health Specialties Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '33-3021.00',
#    'Score': 0.26601336351984,
#    'Rank': 143,
#    'Outlook': 'Below Average',
#    'AnnualWages': 86280.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Detectives and Criminal Investigators',
#    'EduCode': 7.0},
#   {'OnetCode': '33-3051.00',
#    'Score': 0.265718352468633,
#    'Rank': 144,
#    'Outlook': 'Below Average',
#    'AnnualWages': 65790.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': "Police and Sheriff's Patrol Officers",
#    'EduCode': 7.0},
#   {'OnetCode': '29-2057.00',
#    'Score': 0.265428422093241,
#    'Rank': 145,
#    'Outlook': 'Bright',
#    'AnnualWages': 38860.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Ophthalmic Medical Technicians',
#    'EduCode': 6.0},
#   {'OnetCode': '29-1022.00',
#    'Score': 0.265294737942695,
#    'Rank': 146,
#    'Outlook': 'Average',
#    'AnnualWages': 999999.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Oral and Maxillofacial Surgeons',
#    'EduCode': 2.0},
#   {'OnetCode': '11-9013.00',
#    'Score': 0.264331124286571,
#    'Rank': 147,
#    'Outlook': 'Below Average',
#    'AnnualWages': 75760.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Farmers, Ranchers, and Other Agricultural Managers',
#    'EduCode': 7.0},
#   {'OnetCode': '41-9021.00',
#    'Score': 0.263696250696732,
#    'Rank': 148,
#    'Outlook': 'Average',
#    'AnnualWages': 62190.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Real Estate Brokers',
#    'EduCode': 7.0},
#   {'OnetCode': '39-3011.00',
#    'Score': 0.263308002545387,
#    'Rank': 149,
#    'Outlook': 'Bright',
#    'AnnualWages': 29120.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Gambling Dealers',
#    'EduCode': 7.0},
#   {'OnetCode': '29-1131.00',
#    'Score': 0.259798681078428,
#    'Rank': 150,
#    'Outlook': 'Bright',
#    'AnnualWages': 103260.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Veterinarians',
#    'EduCode': 2.0}],
#  'EduClassList': [{'EduCode': 7.0,
#    'EduTitle': 'High school diploma or equivalent',
#    'Count': 44},
#   {'EduCode': 2.0, 'EduTitle': "Master's degree or higher", 'Count': 32},
#   {'EduCode': 3.0, 'EduTitle': "Bachelor's degree", 'Count': 28},
#   {'EduCode': 9.0, 'EduTitle': 'Some high school', 'Count': 28},
#   {'EduCode': 6.0, 'EduTitle': 'Some college', 'Count': 12},
#   {'EduCode': 4.0, 'EduTitle': "Associate's degree", 'Count': 6}],
#  'RecordCount': 150,
#  'FilterValue': 0}

# %% [markdown]
# The API states you can filter out suggested jobs from the response by setting an education level restriction in the parameters, but it doesn't do anything when I provide it (example below). An easy workaround is to omit that parameter, get the entire response object of suggested jobs, and filter by education level afterwards.

# %%
headers_associates = {
  "Authorization": f"Bearer {api_key['token-key']}", 
  "eduFilterValue":"Associate's degree"
}
response = requests.post(url, json=rand_request, headers=headers_associates)
response = response.json() # This matches the response we generated using the API Explorer
response
# Out:
# {'SKARankList': [{'OnetCode': '39-5092.00',
#    'Score': 0.443644066481302,
#    'Rank': 1,
#    'Outlook': 'Bright',
#    'AnnualWages': 31130.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Manicurists and Pedicurists',
#    'EduCode': 6.0},
#   {'OnetCode': '19-3091.00',
#    'Score': 0.44286812419121596,
#    'Rank': 2,
#    'Outlook': 'Average',
#    'AnnualWages': 63940.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Anthropologists and Archeologists',
#    'EduCode': 2.0},
#   {'OnetCode': '45-2041.00',
#    'Score': 0.43716886592564197,
#    'Rank': 3,
#    'Outlook': 'Below Average',
#    'AnnualWages': 32550.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Graders and Sorters, Agricultural Products',
#    'EduCode': 9.0},
#   {'OnetCode': '31-1131.00',
#    'Score': 0.43314916662403297,
#    'Rank': 4,
#    'Outlook': 'Bright',
#    'AnnualWages': 35760.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Nursing Assistants',
#    'EduCode': 6.0},
#   {'OnetCode': '35-3041.00',
#    'Score': 0.41801121903272304,
#    'Rank': 5,
#    'Outlook': 'Average',
#    'AnnualWages': 30300.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Food Servers, Nonrestaurant',
#    'EduCode': 9.0},
#   {'OnetCode': '47-5051.00',
#    'Score': 0.41343703368263596,
#    'Rank': 6,
#    'Outlook': 'Average',
#    'AnnualWages': 46010.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Rock Splitters, Quarry',
#    'EduCode': 9.0},
#   {'OnetCode': '35-2014.00',
#    'Score': 0.40943832728272606,
#    'Rank': 7,
#    'Outlook': 'Bright',
#    'AnnualWages': 34110.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Cooks, Restaurant',
#    'EduCode': 9.0},
#   {'OnetCode': '47-2141.00',
#    'Score': 0.405886304356957,
#    'Rank': 8,
#    'Outlook': 'Below Average',
#    'AnnualWages': 46090.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Painters, Construction and Maintenance',
#    'EduCode': 9.0},
#   {'OnetCode': '13-1199.05',
#    'Score': 0.40552953945955406,
#    'Rank': 9,
#    'Outlook': 'Bright',
#    'AnnualWages': 75990.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Sustainability Specialists',
#    'EduCode': 3.0},
#   {'OnetCode': '35-1011.00',
#    'Score': 0.395929497531123,
#    'Rank': 10,
#    'Outlook': 'Bright',
#    'AnnualWages': 56520.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Chefs and Head Cooks',
#    'EduCode': 7.0},
#   {'OnetCode': '29-1229.04',
#    'Score': 0.39538373392779497,
#    'Rank': 11,
#    'Outlook': 'Below Average',
#    'AnnualWages': 223410.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Physical Medicine and Rehabilitation Physicians',
#    'EduCode': 2.0},
#   {'OnetCode': '31-9011.00',
#    'Score': 0.393492225031025,
#    'Rank': 12,
#    'Outlook': 'Bright',
#    'AnnualWages': 49860.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Massage Therapists',
#    'EduCode': 6.0},
#   {'OnetCode': '39-2021.00',
#    'Score': 0.38881120780341705,
#    'Rank': 13,
#    'Outlook': 'Bright',
#    'AnnualWages': 29530.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Animal Caretakers',
#    'EduCode': 7.0},
#   {'OnetCode': '29-1141.02',
#    'Score': 0.38523038548405897,
#    'Rank': 14,
#    'Outlook': 'Bright',
#    'AnnualWages': 81220.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Advanced Practice Psychiatric Nurses',
#    'EduCode': 3.0},
#   {'OnetCode': '31-9097.00',
#    'Score': 0.38354123227861603,
#    'Rank': 15,
#    'Outlook': 'Bright',
#    'AnnualWages': 38530.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Phlebotomists',
#    'EduCode': 6.0},
#   {'OnetCode': '29-1161.00',
#    'Score': 0.38221770315423004,
#    'Rank': 16,
#    'Outlook': 'Bright',
#    'AnnualWages': 120880.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Nurse Midwives',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1291.00',
#    'Score': 0.38157544203420396,
#    'Rank': 17,
#    'Outlook': 'Average',
#    'AnnualWages': 72220.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Acupuncturists',
#    'EduCode': 2.0},
#   {'OnetCode': '39-5093.00',
#    'Score': 0.376724813702618,
#    'Rank': 18,
#    'Outlook': 'Bright',
#    'AnnualWages': 27860.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Shampooers',
#    'EduCode': 9.0},
#   {'OnetCode': '29-1229.03',
#    'Score': 0.374092828869178,
#    'Rank': 19,
#    'Outlook': 'Below Average',
#    'AnnualWages': 223410.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Urologists',
#    'EduCode': 2.0},
#   {'OnetCode': '35-3031.00',
#    'Score': 0.37225798962561396,
#    'Rank': 20,
#    'Outlook': 'Bright',
#    'AnnualWages': 29120.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Waiters and Waitresses',
#    'EduCode': 9.0},
#   {'OnetCode': '31-1122.00',
#    'Score': 0.36928214475399396,
#    'Rank': 21,
#    'Outlook': 'Bright',
#    'AnnualWages': 30180.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Personal Care Aides',
#    'EduCode': 7.0},
#   {'OnetCode': '25-1041.00',
#    'Score': 0.368912788896708,
#    'Rank': 22,
#    'Outlook': 'Average',
#    'AnnualWages': 85860.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Agricultural Sciences Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1299.01',
#    'Score': 0.367679433316306,
#    'Rank': 23,
#    'Outlook': 'Below Average',
#    'AnnualWages': 106230.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Naturopathic Physicians',
#    'EduCode': 2.0},
#   {'OnetCode': '35-2015.00',
#    'Score': 0.367372319366359,
#    'Rank': 24,
#    'Outlook': 'Below Average',
#    'AnnualWages': 30360.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Cooks, Short Order',
#    'EduCode': 9.0},
#   {'OnetCode': '33-9092.00',
#    'Score': 0.366989072655511,
#    'Rank': 25,
#    'Outlook': 'Bright',
#    'AnnualWages': 27270.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Lifeguards, Ski Patrol, and Other Recreational Protective Service Workers',
#    'EduCode': 9.0},
#   {'OnetCode': '39-9031.00',
#    'Score': 0.365349997670022,
#    'Rank': 26,
#    'Outlook': 'Bright',
#    'AnnualWages': 45380.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Exercise Trainers and Group Fitness Instructors',
#    'EduCode': 7.0},
#   {'OnetCode': '51-2051.00',
#    'Score': 0.36253194395696,
#    'Rank': 27,
#    'Outlook': 'Below Average',
#    'AnnualWages': 38110.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Fiberglass Laminators and Fabricators',
#    'EduCode': 7.0},
#   {'OnetCode': '11-9171.00',
#    'Score': 0.36166761286141896,
#    'Rank': 28,
#    'Outlook': 'Average',
#    'AnnualWages': 72110.0,
#    'TypicalEducation': "Associate's degree",
#    'OccupationTitle': 'Funeral Home Managers',
#    'EduCode': 4.0},
#   {'OnetCode': '19-1011.00',
#    'Score': 0.36037817706327296,
#    'Rank': 29,
#    'Outlook': 'Bright',
#    'AnnualWages': 69390.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Animal Scientists',
#    'EduCode': 3.0},
#   {'OnetCode': '35-3011.00',
#    'Score': 0.358652229327773,
#    'Rank': 30,
#    'Outlook': 'Bright',
#    'AnnualWages': 29380.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Bartenders',
#    'EduCode': 9.0},
#   {'OnetCode': '33-3051.04',
#    'Score': 0.358252387528203,
#    'Rank': 31,
#    'Outlook': 'Below Average',
#    'AnnualWages': 65790.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Customs and Border Protection Officers',
#    'EduCode': 7.0},
#   {'OnetCode': '25-9021.00',
#    'Score': 0.358196135422914,
#    'Rank': 32,
#    'Outlook': 'Below Average',
#    'AnnualWages': 53450.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Farm and Home Management Educators',
#    'EduCode': 2.0},
#   {'OnetCode': '13-1074.00',
#    'Score': 0.357280104803462,
#    'Rank': 33,
#    'Outlook': 'Bright',
#    'AnnualWages': 49330.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Farm Labor Contractors',
#    'EduCode': 9.0},
#   {'OnetCode': '51-2021.00',
#    'Score': 0.354789107898483,
#    'Rank': 34,
#    'Outlook': 'Below Average',
#    'AnnualWages': 43160.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Coil Winders, Tapers, and Finishers',
#    'EduCode': 7.0},
#   {'OnetCode': '25-1061.00',
#    'Score': 0.354523760353584,
#    'Rank': 35,
#    'Outlook': 'Bright',
#    'AnnualWages': 85000.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Anthropology and Archeology Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '29-9092.00',
#    'Score': 0.353442287171101,
#    'Rank': 36,
#    'Outlook': 'Bright',
#    'AnnualWages': 89990.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Genetic Counselors',
#    'EduCode': 2.0},
#   {'OnetCode': '39-2011.00',
#    'Score': 0.35119603010940703,
#    'Rank': 37,
#    'Outlook': 'Bright',
#    'AnnualWages': 35620.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Animal Trainers',
#    'EduCode': 7.0},
#   {'OnetCode': '25-3021.00',
#    'Score': 0.349356624618829,
#    'Rank': 38,
#    'Outlook': 'Bright',
#    'AnnualWages': 44110.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Self-Enrichment Teachers',
#    'EduCode': 7.0},
#   {'OnetCode': '35-2021.00',
#    'Score': 0.349131498979557,
#    'Rank': 39,
#    'Outlook': 'Bright',
#    'AnnualWages': 29790.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Food Preparation Workers',
#    'EduCode': 9.0},
#   {'OnetCode': '29-1141.04',
#    'Score': 0.34904807630769896,
#    'Rank': 40,
#    'Outlook': 'Bright',
#    'AnnualWages': 81220.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Clinical Nurse Specialists',
#    'EduCode': 3.0},
#   {'OnetCode': '51-9192.00',
#    'Score': 0.34513329012901395,
#    'Rank': 41,
#    'Outlook': 'Average',
#    'AnnualWages': 37190.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Cleaning, Washing, and Metal Pickling Equipment Operators and Tenders',
#    'EduCode': 7.0},
#   {'OnetCode': '25-3041.00',
#    'Score': 0.340398851586571,
#    'Rank': 42,
#    'Outlook': 'Bright',
#    'AnnualWages': 36680.0,
#    'TypicalEducation': 'Some college, no degree',
#    'OccupationTitle': 'Tutors',
#    'EduCode': 6.0},
#   {'OnetCode': '37-3012.00',
#    'Score': 0.338265716887149,
#    'Rank': 43,
#    'Outlook': 'Average',
#    'AnnualWages': 41440.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Pesticide Handlers, Sprayers, and Applicators, Vegetation',
#    'EduCode': 7.0},
#   {'OnetCode': '19-5012.00',
#    'Score': 0.337736372622425,
#    'Rank': 44,
#    'Outlook': 'Average',
#    'AnnualWages': 57970.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Occupational Health and Safety Technicians',
#    'EduCode': 7.0},
#   {'OnetCode': '39-7011.00',
#    'Score': 0.33504845293790597,
#    'Rank': 45,
#    'Outlook': 'Bright',
#    'AnnualWages': 34440.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Tour Guides and Escorts',
#    'EduCode': 7.0},
#   {'OnetCode': '47-2142.00',
#    'Score': 0.33443166152347803,
#    'Rank': 46,
#    'Outlook': 'Below Average',
#    'AnnualWages': 44930.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Paperhangers',
#    'EduCode': 9.0},
#   {'OnetCode': '29-9099.01',
#    'Score': 0.333574154765568,
#    'Rank': 47,
#    'Outlook': 'Average',
#    'AnnualWages': 60160.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Midwives',
#    'EduCode': 6.0},
#   {'OnetCode': '21-1094.00',
#    'Score': 0.333426367344513,
#    'Rank': 48,
#    'Outlook': 'Bright',
#    'AnnualWages': 46190.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Community Health Workers',
#    'EduCode': 7.0},
#   {'OnetCode': '29-1011.00',
#    'Score': 0.331532185916439,
#    'Rank': 49,
#    'Outlook': 'Bright',
#    'AnnualWages': 75380.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Chiropractors',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1123.00',
#    'Score': 0.330881248751117,
#    'Rank': 50,
#    'Outlook': 'Bright',
#    'AnnualWages': 97720.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Physical Therapists',
#    'EduCode': 2.0},
#   {'OnetCode': '39-4021.00',
#    'Score': 0.330794886861186,
#    'Rank': 51,
#    'Outlook': 'Bright',
#    'AnnualWages': 31160.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Funeral Attendants',
#    'EduCode': 7.0},
#   {'OnetCode': '27-2021.00',
#    'Score': 0.329077378671729,
#    'Rank': 52,
#    'Outlook': 'Bright',
#    'AnnualWages': 94270.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Athletes and Sports Competitors',
#    'EduCode': 9.0},
#   {'OnetCode': '25-2022.00',
#    'Score': 0.326795217568159,
#    'Rank': 53,
#    'Outlook': 'Average',
#    'AnnualWages': 61810.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Middle School Teachers, Except Special and Career/Technical Education',
#    'EduCode': 3.0},
#   {'OnetCode': '29-1125.00',
#    'Score': 0.326485558629528,
#    'Rank': 54,
#    'Outlook': 'Average',
#    'AnnualWages': 51330.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Recreational Therapists',
#    'EduCode': 3.0},
#   {'OnetCode': '35-9011.00',
#    'Score': 0.323014649809788,
#    'Rank': 55,
#    'Outlook': 'Bright',
#    'AnnualWages': 29120.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Dining Room and Cafeteria Attendants and Bartender Helpers',
#    'EduCode': 9.0},
#   {'OnetCode': '37-2012.00',
#    'Score': 0.322701900094856,
#    'Rank': 56,
#    'Outlook': 'Bright',
#    'AnnualWages': 29960.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Maids and Housekeeping Cleaners',
#    'EduCode': 9.0},
#   {'OnetCode': '29-1229.02',
#    'Score': 0.322126585750445,
#    'Rank': 57,
#    'Outlook': 'Below Average',
#    'AnnualWages': 223410.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Hospitalists',
#    'EduCode': 2.0},
#   {'OnetCode': '31-1121.00',
#    'Score': 0.321994867353085,
#    'Rank': 58,
#    'Outlook': 'Bright',
#    'AnnualWages': 30180.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Home Health Aides',
#    'EduCode': 7.0},
#   {'OnetCode': '35-2012.00',
#    'Score': 0.321680453509233,
#    'Rank': 59,
#    'Outlook': 'Average',
#    'AnnualWages': 32510.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Cooks, Institution and Cafeteria',
#    'EduCode': 9.0},
#   {'OnetCode': '29-1141.03',
#    'Score': 0.321332924332497,
#    'Rank': 60,
#    'Outlook': 'Bright',
#    'AnnualWages': 81220.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Critical Care Nurses',
#    'EduCode': 3.0},
#   {'OnetCode': '29-1171.00',
#    'Score': 0.31875782403164604,
#    'Rank': 61,
#    'Outlook': 'Bright',
#    'AnnualWages': 121610.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Nurse Practitioners',
#    'EduCode': 2.0},
#   {'OnetCode': '19-1031.00',
#    'Score': 0.31854221370653596,
#    'Rank': 62,
#    'Outlook': 'Below Average',
#    'AnnualWages': 64460.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Conservation Scientists',
#    'EduCode': 3.0},
#   {'OnetCode': '39-4011.00',
#    'Score': 0.318410267996785,
#    'Rank': 63,
#    'Outlook': 'Average',
#    'AnnualWages': 49910.0,
#    'TypicalEducation': "Associate's degree",
#    'OccupationTitle': 'Embalmers',
#    'EduCode': 4.0},
#   {'OnetCode': '11-1011.03',
#    'Score': 0.31804282694785,
#    'Rank': 64,
#    'Outlook': 'Below Average',
#    'AnnualWages': 189520.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Chief Sustainability Officers',
#    'EduCode': 3.0},
#   {'OnetCode': '25-2023.00',
#    'Score': 0.31590077147843604,
#    'Rank': 65,
#    'Outlook': 'Below Average',
#    'AnnualWages': 62630.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Career/Technical Education Teachers, Middle School',
#    'EduCode': 3.0},
#   {'OnetCode': '29-2035.00',
#    'Score': 0.313636002353578,
#    'Rank': 66,
#    'Outlook': 'Average',
#    'AnnualWages': 80090.0,
#    'TypicalEducation': "Associate's degree",
#    'OccupationTitle': 'Magnetic Resonance Imaging Technologists',
#    'EduCode': 4.0},
#   {'OnetCode': '45-1011.00',
#    'Score': 0.313291360818628,
#    'Rank': 67,
#    'Outlook': 'Average',
#    'AnnualWages': 54490.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'First-Line Supervisors of Farming, Fishing, and Forestry Workers',
#    'EduCode': 7.0},
#   {'OnetCode': '39-5011.00',
#    'Score': 0.313240215303349,
#    'Rank': 68,
#    'Outlook': 'Bright',
#    'AnnualWages': 34990.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Barbers',
#    'EduCode': 6.0},
#   {'OnetCode': '47-2132.00',
#    'Score': 0.31234744686545995,
#    'Rank': 69,
#    'Outlook': 'Below Average',
#    'AnnualWages': 50590.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Insulation Workers, Mechanical',
#    'EduCode': 7.0},
#   {'OnetCode': '39-3012.00',
#    'Score': 0.312144280315726,
#    'Rank': 70,
#    'Outlook': 'Below Average',
#    'AnnualWages': 28940.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Gambling and Sports Book Writers and Runners',
#    'EduCode': 7.0},
#   {'OnetCode': '51-3022.00',
#    'Score': 0.311739971203161,
#    'Rank': 71,
#    'Outlook': 'Below Average',
#    'AnnualWages': 35070.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Meat, Poultry, and Fish Cutters and Trimmers',
#    'EduCode': 9.0},
#   {'OnetCode': '35-3023.00',
#    'Score': 0.311340187808651,
#    'Rank': 72,
#    'Outlook': 'Bright',
#    'AnnualWages': 27930.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Fast Food and Counter Workers',
#    'EduCode': 9.0},
#   {'OnetCode': '35-9021.00',
#    'Score': 0.31027717729335696,
#    'Rank': 73,
#    'Outlook': 'Bright',
#    'AnnualWages': 29080.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Dishwashers',
#    'EduCode': 9.0},
#   {'OnetCode': '11-9179.01',
#    'Score': 0.30771580851662395,
#    'Rank': 74,
#    'Outlook': 'Bright',
#    'AnnualWages': 56090.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Fitness and Wellness Coordinators',
#    'EduCode': 7.0},
#   {'OnetCode': '29-1122.00',
#    'Score': 0.306351990369937,
#    'Rank': 75,
#    'Outlook': 'Bright',
#    'AnnualWages': 93180.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Occupational Therapists',
#    'EduCode': 2.0},
#   {'OnetCode': '21-1022.00',
#    'Score': 0.30574723076442395,
#    'Rank': 76,
#    'Outlook': 'Bright',
#    'AnnualWages': 60280.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Healthcare Social Workers',
#    'EduCode': 2.0},
#   {'OnetCode': '25-2032.00',
#    'Score': 0.305741718532129,
#    'Rank': 77,
#    'Outlook': 'Below Average',
#    'AnnualWages': 62500.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Career/Technical Education Teachers, Secondary School',
#    'EduCode': 3.0},
#   {'OnetCode': '29-2081.00',
#    'Score': 0.304509048116733,
#    'Rank': 78,
#    'Outlook': 'Average',
#    'AnnualWages': 39610.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Opticians, Dispensing',
#    'EduCode': 7.0},
#   {'OnetCode': '19-5011.00',
#    'Score': 0.304061731417321,
#    'Rank': 79,
#    'Outlook': 'Average',
#    'AnnualWages': 78570.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Occupational Health and Safety Specialists',
#    'EduCode': 3.0},
#   {'OnetCode': '25-1193.00',
#    'Score': 0.303527732102293,
#    'Rank': 80,
#    'Outlook': 'Average',
#    'AnnualWages': 72650.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Recreation and Fitness Studies Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '33-3052.00',
#    'Score': 0.302651043883537,
#    'Rank': 81,
#    'Outlook': 'Below Average',
#    'AnnualWages': 69150.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Transit and Railroad Police',
#    'EduCode': 7.0},
#   {'OnetCode': '29-1141.01',
#    'Score': 0.30128066128112696,
#    'Rank': 82,
#    'Outlook': 'Bright',
#    'AnnualWages': 81220.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Acute Care Nurses',
#    'EduCode': 3.0},
#   {'OnetCode': '43-5052.00',
#    'Score': 0.300686492807235,
#    'Rank': 83,
#    'Outlook': 'Below Average',
#    'AnnualWages': 54250.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Postal Service Mail Carriers',
#    'EduCode': 7.0},
#   {'OnetCode': '51-3023.00',
#    'Score': 0.300367677964698,
#    'Rank': 84,
#    'Outlook': 'Below Average',
#    'AnnualWages': 35240.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Slaughterers and Meat Packers',
#    'EduCode': 9.0},
#   {'OnetCode': '51-9123.00',
#    'Score': 0.30019782158449,
#    'Rank': 85,
#    'Outlook': 'Below Average',
#    'AnnualWages': 38270.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Painting, Coating, and Decorating Workers',
#    'EduCode': 9.0},
#   {'OnetCode': '35-9031.00',
#    'Score': 0.300051299178524,
#    'Rank': 86,
#    'Outlook': 'Bright',
#    'AnnualWages': 27720.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop',
#    'EduCode': 9.0},
#   {'OnetCode': '45-2092.00',
#    'Score': 0.299303313551639,
#    'Rank': 87,
#    'Outlook': 'Below Average',
#    'AnnualWages': 33000.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Farmworkers and Laborers, Crop, Nursery, and Greenhouse',
#    'EduCode': 9.0},
#   {'OnetCode': '31-2011.00',
#    'Score': 0.298372595120911,
#    'Rank': 88,
#    'Outlook': 'Bright',
#    'AnnualWages': 64250.0,
#    'TypicalEducation': "Associate's degree",
#    'OccupationTitle': 'Occupational Therapy Assistants',
#    'EduCode': 4.0},
#   {'OnetCode': '19-1031.03',
#    'Score': 0.297545793832647,
#    'Rank': 89,
#    'Outlook': 'Below Average',
#    'AnnualWages': 64460.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Park Naturalists',
#    'EduCode': 3.0},
#   {'OnetCode': '21-1011.00',
#    'Score': 0.29742835517049104,
#    'Rank': 90,
#    'Outlook': 'Bright',
#    'AnnualWages': 49710.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Substance Abuse and Behavioral Disorder Counselors',
#    'EduCode': 3.0},
#   {'OnetCode': '53-2031.00',
#    'Score': 0.296770423416236,
#    'Rank': 91,
#    'Outlook': 'Bright',
#    'AnnualWages': 63760.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Flight Attendants',
#    'EduCode': 7.0},
#   {'OnetCode': '51-6041.00',
#    'Score': 0.29603681110278,
#    'Rank': 92,
#    'Outlook': 'Below Average',
#    'AnnualWages': 32460.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Shoe and Leather Workers and Repairers',
#    'EduCode': 7.0},
#   {'OnetCode': '19-3092.00',
#    'Score': 0.294716983907197,
#    'Rank': 93,
#    'Outlook': 'Below Average',
#    'AnnualWages': 88900.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Geographers',
#    'EduCode': 3.0},
#   {'OnetCode': '29-1151.00',
#    'Score': 0.29462551827401495,
#    'Rank': 94,
#    'Outlook': 'Bright',
#    'AnnualWages': 203090.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Nurse Anesthetists',
#    'EduCode': 2.0},
#   {'OnetCode': '25-2059.01',
#    'Score': 0.294192648876541,
#    'Rank': 95,
#    'Outlook': 'Average',
#    'AnnualWages': 63950.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Adapted Physical Education Specialists',
#    'EduCode': 3.0},
#   {'OnetCode': '53-7064.00',
#    'Score': 0.293330453082354,
#    'Rank': 96,
#    'Outlook': 'Below Average',
#    'AnnualWages': 32920.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Packers and Packagers, Hand',
#    'EduCode': 9.0},
#   {'OnetCode': '39-4031.00',
#    'Score': 0.293179287272178,
#    'Rank': 97,
#    'Outlook': 'Bright',
#    'AnnualWages': 51570.0,
#    'TypicalEducation': "Associate's degree",
#    'OccupationTitle': 'Morticians, Undertakers, and Funeral Arrangers',
#    'EduCode': 4.0},
#   {'OnetCode': '19-3033.00',
#    'Score': 0.29290249536845103,
#    'Rank': 98,
#    'Outlook': 'Bright',
#    'AnnualWages': 90130.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Clinical and Counseling Psychologists',
#    'EduCode': 2.0},
#   {'OnetCode': '13-2071.00',
#    'Score': 0.292226111248115,
#    'Rank': 99,
#    'Outlook': 'Bright',
#    'AnnualWages': 47320.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Credit Counselors',
#    'EduCode': 3.0},
#   {'OnetCode': '39-3093.00',
#    'Score': 0.29173348662015497,
#    'Rank': 100,
#    'Outlook': 'Bright',
#    'AnnualWages': 30210.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Locker Room, Coatroom, and Dressing Room Attendants',
#    'EduCode': 7.0},
#   {'OnetCode': '29-2091.00',
#    'Score': 0.29116560549896003,
#    'Rank': 101,
#    'Outlook': 'Bright',
#    'AnnualWages': 77070.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Orthotists and Prosthetists',
#    'EduCode': 2.0},
#   {'OnetCode': '51-6021.00',
#    'Score': 0.290495126982746,
#    'Rank': 102,
#    'Outlook': 'Below Average',
#    'AnnualWages': 29690.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Pressers, Textile, Garment, and Related Materials',
#    'EduCode': 9.0},
#   {'OnetCode': '47-2042.00',
#    'Score': 0.28999162997864203,
#    'Rank': 103,
#    'Outlook': 'Bright',
#    'AnnualWages': 48870.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Floor Layers, Except Carpet, Wood, and Hard Tiles',
#    'EduCode': 9.0},
#   {'OnetCode': '25-1066.00',
#    'Score': 0.28710092357684,
#    'Rank': 104,
#    'Outlook': 'Bright',
#    'AnnualWages': 78810.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Psychology Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '29-1128.00',
#    'Score': 0.286864923967769,
#    'Rank': 105,
#    'Outlook': 'Bright',
#    'AnnualWages': 51350.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Exercise Physiologists',
#    'EduCode': 3.0},
#   {'OnetCode': '33-9011.00',
#    'Score': 0.28671510416443596,
#    'Rank': 106,
#    'Outlook': 'Average',
#    'AnnualWages': 39320.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Animal Control Workers',
#    'EduCode': 7.0},
#   {'OnetCode': '31-2021.00',
#    'Score': 0.286079403758161,
#    'Rank': 107,
#    'Outlook': 'Bright',
#    'AnnualWages': 62770.0,
#    'TypicalEducation': "Associate's degree",
#    'OccupationTitle': 'Physical Therapist Assistants',
#    'EduCode': 4.0},
#   {'OnetCode': '53-7061.00',
#    'Score': 0.28551071601008904,
#    'Rank': 108,
#    'Outlook': 'Average',
#    'AnnualWages': 31000.0,
#    'TypicalEducation': 'No formal educational credential',
#    'OccupationTitle': 'Cleaners of Vehicles and Equipment',
#    'EduCode': 9.0},
#   {'OnetCode': '27-3091.00',
#    'Score': 0.28539443393378094,
#    'Rank': 109,
#    'Outlook': 'Bright',
#    'AnnualWages': 53640.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Interpreters and Translators',
#    'EduCode': 3.0},
#   {'OnetCode': '39-5012.00',
#    'Score': 0.284989495070333,
#    'Rank': 110,
#    'Outlook': 'Bright',
#    'AnnualWages': 33290.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Hairdressers, Hairstylists, and Cosmetologists',
#    'EduCode': 6.0},
#   {'OnetCode': '29-1229.01',
#    'Score': 0.28376027299126494,
#    'Rank': 111,
#    'Outlook': 'Below Average',
#    'AnnualWages': 223410.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Allergists and Immunologists',
#    'EduCode': 2.0},
#   {'OnetCode': '33-3021.02',
#    'Score': 0.283453471892028,
#    'Rank': 112,
#    'Outlook': 'Below Average',
#    'AnnualWages': 86280.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Police Identification and Records Officers',
#    'EduCode': 7.0},
#   {'OnetCode': '39-9011.00',
#    'Score': 0.282996464214809,
#    'Rank': 113,
#    'Outlook': 'Bright',
#    'AnnualWages': 28520.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Childcare Workers',
#    'EduCode': 7.0},
#   {'OnetCode': '25-1072.00',
#    'Score': 0.282708778055511,
#    'Rank': 114,
#    'Outlook': 'Bright',
#    'AnnualWages': 78580.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Nursing Instructors and Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '39-3092.00',
#    'Score': 0.282367775779519,
#    'Rank': 115,
#    'Outlook': 'Bright',
#    'AnnualWages': 48470.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Costume Attendants',
#    'EduCode': 7.0},
#   {'OnetCode': '51-3092.00',
#    'Score': 0.28153099099407797,
#    'Rank': 116,
#    'Outlook': 'Average',
#    'AnnualWages': 36580.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Food Batchmakers',
#    'EduCode': 7.0},
#   {'OnetCode': '29-2099.08',
#    'Score': 0.281401849123459,
#    'Rank': 117,
#    'Outlook': 'Average',
#    'AnnualWages': 44990.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Patient Representatives',
#    'EduCode': 6.0},
#   {'OnetCode': '29-1071.00',
#    'Score': 0.28078323743286,
#    'Rank': 118,
#    'Outlook': 'Bright',
#    'AnnualWages': 126010.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Physician Assistants',
#    'EduCode': 2.0},
#   {'OnetCode': '19-1012.00',
#    'Score': 0.28060554027235995,
#    'Rank': 119,
#    'Outlook': 'Average',
#    'AnnualWages': 79860.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Food Scientists and Technologists',
#    'EduCode': 3.0},
#   {'OnetCode': '25-1011.00',
#    'Score': 0.279514292798481,
#    'Rank': 120,
#    'Outlook': 'Average',
#    'AnnualWages': 88790.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Business Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '45-2021.00',
#    'Score': 0.279019042048903,
#    'Rank': 121,
#    'Outlook': 'Average',
#    'AnnualWages': 45320.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Animal Breeders',
#    'EduCode': 7.0},
#   {'OnetCode': '31-1132.00',
#    'Score': 0.278713011771642,
#    'Rank': 122,
#    'Outlook': 'Average',
#    'AnnualWages': 34520.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Orderlies',
#    'EduCode': 7.0},
#   {'OnetCode': '47-4051.00',
#    'Score': 0.278481726653635,
#    'Rank': 123,
#    'Outlook': 'Average',
#    'AnnualWages': 44930.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Highway Maintenance Workers',
#    'EduCode': 7.0},
#   {'OnetCode': '25-1123.00',
#    'Score': 0.277085493995978,
#    'Rank': 124,
#    'Outlook': 'Average',
#    'AnnualWages': 74280.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'English Language and Literature Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '25-1126.00',
#    'Score': 0.27633123753947497,
#    'Rank': 125,
#    'Outlook': 'Bright',
#    'AnnualWages': 78780.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Philosophy and Religion Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '39-1022.00',
#    'Score': 0.275500260969582,
#    'Rank': 126,
#    'Outlook': 'Bright',
#    'AnnualWages': 43680.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'First-Line Supervisors of Personal Service Workers',
#    'EduCode': 7.0},
#   {'OnetCode': '29-1031.00',
#    'Score': 0.27530510686840903,
#    'Rank': 127,
#    'Outlook': 'Average',
#    'AnnualWages': 66450.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Dietitians and Nutritionists',
#    'EduCode': 3.0},
#   {'OnetCode': '39-5091.00',
#    'Score': 0.275246857541275,
#    'Rank': 128,
#    'Outlook': 'Average',
#    'AnnualWages': 96370.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Makeup Artists, Theatrical and Performance',
#    'EduCode': 6.0},
#   {'OnetCode': '17-2111.00',
#    'Score': 0.27523649883114704,
#    'Rank': 129,
#    'Outlook': 'Average',
#    'AnnualWages': 100660.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Health and Safety Engineers, Except Mining Safety Engineers and Inspectors',
#    'EduCode': 3.0},
#   {'OnetCode': '51-9051.00',
#    'Score': 0.27503957600612006,
#    'Rank': 130,
#    'Outlook': 'Below Average',
#    'AnnualWages': 44530.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Furnace, Kiln, Oven, Drier, and Kettle Operators and Tenders',
#    'EduCode': 7.0},
#   {'OnetCode': '25-2058.00',
#    'Score': 0.274860564045174,
#    'Rank': 131,
#    'Outlook': 'Average',
#    'AnnualWages': 63560.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Special Education Teachers, Secondary School',
#    'EduCode': 3.0},
#   {'OnetCode': '25-3011.00',
#    'Score': 0.273857873609471,
#    'Rank': 132,
#    'Outlook': 'Below Average',
#    'AnnualWages': 58590.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Adult Basic Education, Adult Secondary Education, and English as a Second Language Instructors',
#    'EduCode': 3.0},
#   {'OnetCode': '25-2031.00',
#    'Score': 0.273391362966268,
#    'Rank': 133,
#    'Outlook': 'Average',
#    'AnnualWages': 62360.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Secondary School Teachers, Except Special and Career/Technical Education',
#    'EduCode': 3.0},
#   {'OnetCode': '39-5094.00',
#    'Score': 0.27252203500951705,
#    'Rank': 134,
#    'Outlook': 'Bright',
#    'AnnualWages': 38060.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Skincare Specialists',
#    'EduCode': 6.0},
#   {'OnetCode': '53-6061.00',
#    'Score': 0.27089648682434003,
#    'Rank': 135,
#    'Outlook': 'Below Average',
#    'AnnualWages': 34630.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Passenger Attendants',
#    'EduCode': 7.0},
#   {'OnetCode': '33-3041.00',
#    'Score': 0.27075658748681203,
#    'Rank': 136,
#    'Outlook': 'Below Average',
#    'AnnualWages': 41570.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Parking Enforcement Workers',
#    'EduCode': 7.0},
#   {'OnetCode': '29-1129.02',
#    'Score': 0.270712236440888,
#    'Rank': 137,
#    'Outlook': 'Bright',
#    'AnnualWages': 60800.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Music Therapists',
#    'EduCode': 3.0},
#   {'OnetCode': '29-9091.00',
#    'Score': 0.26971778921322603,
#    'Rank': 138,
#    'Outlook': 'Bright',
#    'AnnualWages': 53840.0,
#    'TypicalEducation': "Master's degree",
#    'OccupationTitle': 'Athletic Trainers',
#    'EduCode': 2.0},
#   {'OnetCode': '31-1133.00',
#    'Score': 0.268247972734944,
#    'Rank': 139,
#    'Outlook': 'Average',
#    'AnnualWages': 37160.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Psychiatric Aides',
#    'EduCode': 7.0},
#   {'OnetCode': '29-1218.00',
#    'Score': 0.268101971749561,
#    'Rank': 140,
#    'Outlook': 'Below Average',
#    'AnnualWages': 999999.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Obstetricians and Gynecologists',
#    'EduCode': 2.0},
#   {'OnetCode': '25-2012.00',
#    'Score': 0.267002690123006,
#    'Rank': 141,
#    'Outlook': 'Average',
#    'AnnualWages': 60490.0,
#    'TypicalEducation': "Bachelor's degree",
#    'OccupationTitle': 'Kindergarten Teachers, Except Special Education',
#    'EduCode': 3.0},
#   {'OnetCode': '25-1071.00',
#    'Score': 0.266050225559714,
#    'Rank': 142,
#    'Outlook': 'Bright',
#    'AnnualWages': 100300.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Health Specialties Teachers, Postsecondary',
#    'EduCode': 2.0},
#   {'OnetCode': '33-3021.00',
#    'Score': 0.26601336351984,
#    'Rank': 143,
#    'Outlook': 'Below Average',
#    'AnnualWages': 86280.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Detectives and Criminal Investigators',
#    'EduCode': 7.0},
#   {'OnetCode': '33-3051.00',
#    'Score': 0.265718352468633,
#    'Rank': 144,
#    'Outlook': 'Below Average',
#    'AnnualWages': 65790.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': "Police and Sheriff's Patrol Officers",
#    'EduCode': 7.0},
#   {'OnetCode': '29-2057.00',
#    'Score': 0.265428422093241,
#    'Rank': 145,
#    'Outlook': 'Bright',
#    'AnnualWages': 38860.0,
#    'TypicalEducation': 'Postsecondary non-degree award',
#    'OccupationTitle': 'Ophthalmic Medical Technicians',
#    'EduCode': 6.0},
#   {'OnetCode': '29-1022.00',
#    'Score': 0.265294737942695,
#    'Rank': 146,
#    'Outlook': 'Average',
#    'AnnualWages': 999999.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Oral and Maxillofacial Surgeons',
#    'EduCode': 2.0},
#   {'OnetCode': '11-9013.00',
#    'Score': 0.264331124286571,
#    'Rank': 147,
#    'Outlook': 'Below Average',
#    'AnnualWages': 75760.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Farmers, Ranchers, and Other Agricultural Managers',
#    'EduCode': 7.0},
#   {'OnetCode': '41-9021.00',
#    'Score': 0.263696250696732,
#    'Rank': 148,
#    'Outlook': 'Average',
#    'AnnualWages': 62190.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Real Estate Brokers',
#    'EduCode': 7.0},
#   {'OnetCode': '39-3011.00',
#    'Score': 0.263308002545387,
#    'Rank': 149,
#    'Outlook': 'Bright',
#    'AnnualWages': 29120.0,
#    'TypicalEducation': 'High school diploma or equivalent',
#    'OccupationTitle': 'Gambling Dealers',
#    'EduCode': 7.0},
#   {'OnetCode': '29-1131.00',
#    'Score': 0.259798681078428,
#    'Rank': 150,
#    'Outlook': 'Bright',
#    'AnnualWages': 103260.0,
#    'TypicalEducation': 'Doctoral or professional degree',
#    'OccupationTitle': 'Veterinarians',
#    'EduCode': 2.0}],
#  'EduClassList': [{'EduCode': 7.0,
#    'EduTitle': 'High school diploma or equivalent',
#    'Count': 44},
#   {'EduCode': 2.0, 'EduTitle': "Master's degree or higher", 'Count': 32},
#   {'EduCode': 3.0, 'EduTitle': "Bachelor's degree", 'Count': 28},
#   {'EduCode': 9.0, 'EduTitle': 'Some high school', 'Count': 28},
#   {'EduCode': 6.0, 'EduTitle': 'Some college', 'Count': 12},
#   {'EduCode': 4.0, 'EduTitle': "Associate's degree", 'Count': 6}],
#  'RecordCount': 150,
#  'FilterValue': 0}
